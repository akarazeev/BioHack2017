# %%
import requests
import json
from lxml import html
from ncbiumls.authorization import authorization
from time import sleep


class UMLS(authorization):
    def __init__(self, api_key='e9990d5d-ff93-40f1-9f60-29ce7cf2950c'):
        super().__init__(str(api_key))

    def askTerm(self, term, inputType='atom', includeObsolete='false', includeSuppressible='false',
                returnIdType='concept', searchType='words', pageNumber=1, pageSize=25):

#   TODO: Add option like dump, if enabled - save data, current page, page size
#   TODO: Write some messages on succesfull access, like pageNumber etc.

        """
        Description: retrives all records associted with the term, returns list of dicts,
                     each dict have keywords name,uri,ui,rootSource.


        :param term:                A human readable term, such as 'gestatational diabetes', or a code from a source
                                    vocabulary, such as 11687002 from SNOMEDCT_US.

        :param inputType:           Specifies the data type you are using as your search parameter.
                                    Valid values:  'atom', 'code','sourceConcept','sourceDescriptor','sourceUi','tty'
                                    Default value: 'atom'
                                    Usage Note:     Use 'sourceUi' if you aren't sure if the identifier you're providing
                                                    is a code, source concept, or source descriptor. Using 'tty' is for
                                                    advanced use cases and will extract codes from a specified
                                                    vocabulary according to term type.

        :param includeObsolete:     Return content that is a result of matches on obsolete terms.
                                    Valid values:   true or false
                                    Default value: 'false'

        :param includeSuppressible: Return content that is a result of matches on suppressible terms.
                                    Valid values:   true or false
                                    Default value: 'false'

        :param returnIdType:        Specifies the type of identifier you wish to retrieve.
                                    Valid values:   true or false
                                    Default value: 'false'
                                    Usage Note:     Use 'code','sourceConcept', 'sourceDescriptor', or 'sourceUi' if you
                                                    prefer source-asserted identifiers rather than CUIs in your search
                                                    results.

        :param searchType:          Type of search you wish to use.
                                    Valid values:  'exact','words','leftTruncation', 'rightTruncation','approximate',
                                                   'normalizedString'
                                    Default value: 'words'
                                    Usage Note:     Use 'exact' when using inputType = 'code', 'sourceConcept',
                                                   'sourceDescriptor', or 'sourceUi'.

        :param pageNumber:          Whole number that specifies which page of results to fetch
                                    Valid values:   1,2,3, etc
                                    Default value:  1

        :param pageSize:            Whole number that specifies the number of results to include per page.
                                    Valid values:   1,2,3, etc
                                    Default value:  25

        :return:
        """
        # main url and parameters
        url = 'https://uts-ws.nlm.nih.gov/rest/search/current'
        params = {'ticket': '',
                  'string': str(term),
                  'inputType': inputType,
                  'includeObsolete': includeObsolete,
                  'includeSuppressible': includeSuppressible,
                  'returnIdType': returnIdType,
                  'searchType': searchType,
                  'pageNumber': pageNumber,
                  'pageSize': pageSize}

        #varible to store received data
        data = []

        #in case specific page is not provided - grab all results starting from page 1
        if pageNumber == 1:

            #function is guaranteed to return results so ask cycle will roll infinitely
            while True:

                #get a service ticket
                params['ticket'] = self.getST()

                #access page
                get = requests.get(url=url, params=params)
                try:

                    #if all the results obtained return gathered data
                    if get.json()['result'] == {'results': [{'ui': 'NONE', 'name': 'NO RESULTS'}],
                                                  'classType': 'searchResults'}:
                        return data

                    #else grab some more data
                    else:
                        for item in get.json()['result']['results']:
                            data.append(item)
                        params['pageNumber'] += 1

                #if server returned error - try to print that error, wait and retry request
                except Exception as exp:
                    response = html.fromstring(data.text)
                    print(response.xpath('.//p/b[contains(text(),"description")]/following::u')[0].text,
                          ', current page number = ' + str(pageNumber),
                          ', current page size = ' + str(pageSize))

                #to not overlode server pause a bit
                sleep(0.5)

        #else access specific page
        else:
            params['ticket'] = self.getST()
            get = requests.get(url=url, params=params)
            try:
                return get.json()['result']['results']
            except Exception as exp:
                response = html.fromstring(data.text)
                print(response.xpath('.//p/b[contains(text(),"description")]/following::u')[0].text,
                      ', current page number = ' + str(pageNumber),
                      ', current page size = ' + str(pageSize))



class CUI(authorization):
    def __init__(self, api_key='e9990d5d-ff93-40f1-9f60-29ce7cf2950c'):
        super().__init__(api_key=api_key)

    def CUIGeneral(self, cui):
        """
        :param cui: The Concept Unique Identifier for a Metathesaurus concept
        :return: Returns dictionary processed from JSON, example:
                {
                    "pageSize": 25,
                    "pageNumber": 1,
                    "pageCount": 1,
                    "result": {
                        "classType": "Concept",
                        "ui": "C0009044",
                        "suppressible": false,
                        "dateAdded": "09-30-1990",
                        "majorRevisionDate": "08-18-2015",
                        "status": "R",
                        "semanticTypes": [
                            {
                                "name": "Injury or Poisoning",
                                "uri": "https://uts-ws.nlm.nih.gov/rest/semantic-network/2015AB/TUI/T037"
                            }
                        ],
                        "atomCount": 63,
                        "attributeCount": 0,
                        "cvMemberCount": 0,
                        "atoms": "https://uts-ws.nlm.nih.gov/rest/content/2015AB/CUI/C0009044/atoms",
                        "definitions": "NONE",
                        "relations": "https://uts-ws.nlm.nih.gov/rest/content/2015AB/CUI/C0009044/relations",
                        "defaultPreferredAtom": "https://uts-ws.nlm.nih.gov/rest/content/
                                                        2015AB/CUI/C0009044/atoms/preferred",
                        "relationCount": 5,
                        "name": "Closed fracture carpal bone"
                    }
                }
        """
        stTicket = self.getST()
        url = 'https://uts-ws.nlm.nih.gov/rest/content/current/CUI/' + str(cui)
        params = {'ticket': stTicket}
        data = requests.get(url=url, params=params)
        try:
            return data.json()

        except Exception as exp:
            response = html.fromstring(data.text)
            return response.xpath('.//p/b[text()="message"]/u')

    def CUISemanticTypes(self, cui):
        """
        :param cui: The Concept Unique Identifier for a Metathesaurus concept
        :return: Returns dictionary processed from JSON, example:
                {
                    "pageSize": 25,
                    "pageNumber": 1,
                    "pageCount": 1,
                    "result": {
                        "classType": "Concept",
                        "ui": "C0009044",
                        "suppressible": false,
                        "dateAdded": "09-30-1990",
                        "majorRevisionDate": "08-18-2015",
                        "status": "R",
                        "semanticTypes": [
                            {
                                "name": "Injury or Poisoning",
                                "uri": "https://uts-ws.nlm.nih.gov/rest/semantic-network/2015AB/TUI/T037"
                            }
                        ],
                        "atomCount": 63,
                        "attributeCount": 0,
                        "cvMemberCount": 0,
                        "atoms": "https://uts-ws.nlm.nih.gov/rest/content/2015AB/CUI/C0009044/atoms",
                        "definitions": "NONE",
                        "relations": "https://uts-ws.nlm.nih.gov/rest/content/2015AB/CUI/C0009044/relations",
                        "defaultPreferredAtom": "https://uts-ws.nlm.nih.gov/rest/content/
                                                        2015AB/CUI/C0009044/atoms/preferred",
                        "relationCount": 5,
                        "name": "Closed fracture carpal bone"
                    }
                }
        """
        stTicket = self.getST()
        url = 'https://uts-ws.nlm.nih.gov/rest/content/current/CUI/' + str(cui)
        params = {'ticket': stTicket}
        data = requests.get(url=url, params=params)
        try:
            return data.json()['result']['semanticTypes']

        except Exception as exp:
            response = html.fromstring(data.text)
            return response.xpath('.//p/b[text()="message"]/u')

    def CUIAtoms(self, cui, pageNumber=1, pageSize=25):
        stTicket = self.getST()
        url = 'https://uts-ws.nlm.nih.gov/rest/content/current/CUI/' + str(cui) + '/atoms'
        params = {'ticket': stTicket,
                  'pageNumber': pageNumber,
                  'pageSize': pageSize}
        data = requests.get(url=url, params=params)
        pass

    def CUIDefenitions(self, cui, pageNumber=1, pageSize=25):
        stTicket = self.getST()
        url = 'https://uts-ws.nlm.nih.gov/rest/content/current/CUI/' + str(cui) + '/definitions'
        params = {'ticket': stTicket,
                  'pageNumber': pageNumber,
                  'pageSize': pageSize}
        data = requests.get(url=url, params=params)
        pass

    def CUIRelations(self, cui, pageNumber=1, pageSize=25):
        stTicket = self.getST()
        url = 'https://uts-ws.nlm.nih.gov/rest/content/current/CUI/' + str(cui) + '/relations'
        params = {'ticket': stTicket,
                  'pageNumber': pageNumber,
                  'pageSize': pageSize}
        data = requests.get(url=url, params=params)
        pass

# %%
import os

data = {}

for i in os.listdir('data/'):
    print(i)
    year = int(i.split('.')[0])
    with open('data/{}'.format(i)) as data_file:
        data[year] = json.load(data_file)
        for i in ['chemicals', 'mesh_titles']:
            for key, val in data[year][i]:
                data[year][i][key] = val/data[year]['count_articles']
# Out:
# 1990.json
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-04f7d9738b9d> in <module>()
#       9         data[year] = json.load(data_file)
#      10         for i in ['chemicals', 'mesh_titles']:
# ---> 11             for key, val in data[year][i]:
#      12                 data[year][i][key] = val/data[year]['count_articles']
#
# ValueError: too many values to unpack (expected 2)

# %%
data
# Out:
# {'1990': {'chemicals': {' ': 542,
#    '1,25-dihydroxyergocalciferol': 1,
#    '1-(2 (diphenylmethoxy)ethyl)-4-(3-phenylpropyl)piperazine': 1,
#    "2',5'-oligoadenylate synthetase": 2,
#    '2-5a-dependent ribonuclease': 1,
#    '3-iodo-2-hydroxy-6-methoxy-n-((1-ethyl-2-pyrrolidinyl)methyl)benzamide': 1,
#    '4-aminobutyrate transaminase': 1,
#    '4-iodoamphetamine': 2,
#    '4-maleimido-2,2,6,6-tetramethylpiperidinooxyl': 1,
#    '5,5-dimethyl-1-pyrroline-1-oxide': 1,
#    '[': 542,
#    ']': 542,
#    'a': 1626,
#    'acetaminophen': 1,
#    'acetylcarnitine': 2,
#    'acetylcholine': 11,
#    'acetylcholinesterase': 19,
#    'acetylglucosamine': 1,
#    'acid anhydride hydrolases': 1,
#    'acid phosphatase': 1,
#    'acrylic resins': 1,
#    'actins': 1,
#    'acute-phase proteins': 1,
#    'adenosine': 1,
#    'adenosine triphosphate': 1,
#    'adenylyl cyclases': 1,
#    'adrenocorticotropic hormone': 4,
#    'air pollutants, radioactive': 1,
#    'albumins': 1,
#    'albuterol': 1,
#    'alkaline phosphatase': 3,
#    'alpha 1-antichymotrypsin': 5,
#    'alpha-1-microglobulin': 1,
#    'alpha-amino-3-hydroxy-5-methyl-4-isoxazolepropionic acid': 2,
#    'alpha-globulins': 1,
#    'alpha-methyltyrosine': 1,
#    'alpha7 nicotinic acetylcholine receptor': 1,
#    'aluminum': 18,
#    'aluminum hydroxide': 1,
#    "alzheimer's disease antigen": 5,
#    'amantadine': 1,
#    'amino acids': 10,
#    'aminoacridines': 14,
#    'aminopeptidases': 1,
#    'ammonia': 1,
#    'amphetamines': 6,
#    'amyloid': 102,
#    'amyloid beta-peptides': 71,
#    'amyloid beta-protein precursor': 63,
#    'amyloid protein al': 4,
#    'antacids': 1,
#    'anti-bacterial agents': 1,
#    'anti-infective agents': 1,
#    'anti-inflammatory agents': 1,
#    'antibodies': 12,
#    'antibodies, monoclonal': 32,
#    'antibodies, viral': 2,
#    'anticoagulants': 3,
#    'antidepressive agents': 2,
#    'antidepressive agents, tricyclic': 2,
#    'antigen-antibody complex': 1,
#    'antigens': 8,
#    'antigens, cd': 1,
#    'antigens, cd11': 1,
#    'antigens, cd18': 1,
#    'antigens, cd45': 1,
#    'antigens, differentiation': 1,
#    'antigens, heterophile': 1,
#    'antigens, viral': 1,
#    'antioxidants': 1,
#    'antiparkinson agents': 1,
#    'antipsychotic agents': 7,
#    'apomorphine': 1,
#    'apoproteins': 1,
#    'aprotinin': 2,
#    'arecoline': 1,
#    'arginine vasopressin': 2,
#    'argipressin, des-glynh2(9)-': 1,
#    'aspartic acid': 4,
#    'aspartic acid receptor': 1,
#    'atropine': 1,
#    'autoantibodies': 2,
#    'autoantigens': 1,
#    'azo compounds': 1,
#    'b': 542,
#    'baclofen': 1,
#    'benzamides': 3,
#    'beta 2-microglobulin': 1,
#    'beta-endorphin': 1,
#    'bethanechol': 1,
#    'bethanechol compounds': 1,
#    'biogenic monoamines': 1,
#    'biomarkers': 13,
#    'biopterin': 1,
#    'blood glucose': 3,
#    'blood proteins': 5,
#    'bridged bicyclo compounds': 1,
#    'bridged bicyclo compounds, heterocyclic': 1,
#    'bromine': 1,
#    'bromopyruvate': 1,
#    'buflomedil': 1,
#    'bungarotoxins': 1,
#    'butyrylcholinesterase': 4,
#    'ca(2+) mg(2+)-atpase': 1,
#    'cadmium': 1,
#    'calbindins': 1,
#    'calcineurin': 1,
#    'calcitonin': 2,
#    'calcitonin gene-related peptide': 1,
#    'calcium': 6,
#    'calcium channel blockers': 1,
#    'calcium channels': 2,
#    'calcium-binding proteins': 2,
#    'calcium-calmodulin-dependent protein kinases': 1,
#    'calcium-transporting atpases': 2,
#    'calmodulin': 1,
#    'calmodulin-binding proteins': 1,
#    'calpain': 3,
#    'calpastatin': 1,
#    'capsules': 1,
#    'carbachol': 2,
#    'carbamazepine': 4,
#    'carbocysteine': 1,
#    'carbohydrates': 1,
#    'carbon dioxide': 1,
#    'carbon radioisotopes': 2,
#    'carbon-nitrogen ligases': 1,
#    'carbonyl cyanide m-chlorophenyl hydrazone': 1,
#    'carboxylic ester hydrolases': 1,
#    'carnitine': 1,
#    'carrier proteins': 2,
#    'casein kinases': 1,
#    'catalase': 2,
#    'catechol': 1,
#    'catecholamines': 4,
#    'catechols': 1,
#    'cathepsin b': 3,
#    'cathepsin d': 2,
#    'cell adhesion molecules, neuronal': 2,
#    'central nervous system agents': 1,
#    'cerebrosides': 1,
#    'cerebrospinal fluid proteins': 1,
#    'cevimeline': 1,
#    'chga protein, human': 1,
#    'cholecystokinin': 1,
#    'cholesterol': 3,
#    'choline': 8,
#    'choline o-acetyltransferase': 26,
#    'cholinesterase inhibitors': 7,
#    'cholinesterases': 1,
#    'chondroitin sulfate proteoglycans': 1,
#    'chrna7 protein, human': 1,
#    'chrna7 protein, rat': 1,
#    'chromatin': 1,
#    'chromogranin a': 1,
#    'chromogranins': 1,
#    'chymotrypsin': 1,
#    'citalopram': 2,
#    'citrates': 1,
#    'citric acid': 1,
#    'clindamycin': 1,
#    'clu protein, human': 1,
#    'clusterin': 1,
#    'colforsin': 1,
#    'collagen': 2,
#    'complement system proteins': 1,
#    'copper': 1,
#    'corticotropin-releasing hormone': 5,
#    'creatine kinase': 3,
#    'cross-linking reagents': 1,
#    'crystallins': 1,
#    'cst3 protein, human': 1,
#    'culture media': 4,
#    'cycasin': 1,
#    'cyclic amp': 1,
#    'cyclic gmp': 1,
#    'cyclic n-oxides': 2,
#    'cyclophosphamide': 1,
#    'cycloserine': 1,
#    'cystatin c': 1,
#    'cystatins': 1,
#    'cysteamine': 1,
#    'cysteine': 1,
#    'cytochrome reductases': 1,
#    'cytosine': 1,
#    'cytoskeletal proteins': 1,
#    'debrisoquin': 1,
#    'deferoxamine': 1,
#    'dehydroepiandrosterone': 2,
#    'dehydroepiandrosterone sulfate': 2,
#    'delta sleep-inducing peptide': 1,
#    'demecolcine': 1,
#    'deodorants': 1,
#    'deoxy sugars': 1,
#    'deoxyglucose': 4,
#    'deoxyribonuclease ecori': 2,
#    'deoxyribonuclease hpaii': 1,
#    'deoxyribonucleases, type ii site-specific': 2,
#    'dexamethasone': 4,
#    'diazepam binding inhibitor': 1,
#    'dietary carbohydrates': 1,
#    'dietary fats': 1,
#    'dihydroergotoxine': 3,
#    'dipeptidyl-peptidases and tripeptidyl-peptidases': 1,
#    'diphenhydramine': 1,
#    'dna': 16,
#    'dna probes': 6,
#    'dna restriction enzymes': 1,
#    'dna transposable elements': 1,
#    'dna, recombinant': 1,
#    'dna, viral': 2,
#    'dna-binding proteins': 1,
#    'dna-directed dna polymerase': 1,
#    'dolichos biflorus agglutinin': 1,
#    'dopamine': 9,
#    'dopamine agents': 1,
#    'dopamine beta-hydroxylase': 1,
#    'doxorubicin': 1,
#    'e': 542,
#    'electron transport complex iv': 1,
#    'endodeoxyribonuclease mboii': 1,
#    'endopeptidases': 6,
#    'endoribonucleases': 1,
#    'enkephalin, methionine': 3,
#    'enzyme inhibitors': 1,
#    'enzyme reactivators': 1,
#    'epidermal growth factor': 1,
#    'epitopes': 13,
#    'epoprostenol': 1,
#    'erf protein, human': 1,
#    'ergocalciferols': 1,
#    'estrogens': 1,
#    'ethers, cyclic': 1,
#    'ets1 protein, human': 1,
#    'ets2 protein, human': 1,
#    'fatty acid desaturases': 1,
#    'fatty acids': 1,
#    'fatty acids, omega-3': 1,
#    'ferritins': 2,
#    'fetal proteins': 1,
#    'fibrin': 1,
#    'fibrinogen': 1,
#    'fibroblast growth factors': 4,
#    'fibronectins': 1,
#    'fish oils': 1,
#    'fluorescent dyes': 1,
#    'fluorine radioisotopes': 2,
#    'fluorodeoxyglucose f18': 4,
#    "folin's phenol reagent": 1,
#    'food additives': 1,
#    'formates': 2,
#    'formic acid': 2,
#    'free radicals': 4,
#    'g(m1) ganglioside': 4,
#    'galanin': 3,
#    'galantamine': 2,
#    'galanthaminone': 1,
#    'gallium': 3,
#    'gallium radioisotopes': 2,
#    'gamma-aminobutyric acid': 1,
#    'gangliosides': 3,
#    'gap-43 protein': 1,
#    'genetic markers': 6,
#    'glial fibrillary acidic protein': 12,
#    'glucosamine': 1,
#    'glucose': 8,
#    'glutamate decarboxylase': 1,
#    'glutamate dehydrogenase': 1,
#    'glutamate-ammonia ligase': 1,
#    'glutamates': 14,
#    'glutamic acid': 8,
#    'glutathione peroxidase': 2,
#    'glycerophosphoethanolamine': 1,
#    'glycerylphosphorylcholine': 1,
#    'glycoproteins': 1,
#    'glycopyrrolate': 1,
#    'glycosaminoglycans': 1,
#    'gonadotropin-releasing hormone': 1,
#    'granisetron': 1,
#    'growth hormone': 3,
#    'growth hormone-releasing hormone': 2,
#    'growth substances': 1,
#    'gtp-binding proteins': 1,
#    'haloperidol': 1,
#    'heparan sulfate proteoglycans': 1,
#    'heparitin sulfate': 2,
#    'hexokinase': 2,
#    'histocompatibility antigens': 1,
#    'hla-dr antigens': 5,
#    'homovanillic acid': 10,
#    'hormones': 3,
#    'horseradish peroxidase': 1,
#    'hydrocortisone': 11,
#    'hydroxydopamines': 2,
#    'hydroxyindoleacetic acid': 9,
#    'i': 542,
#    'ibotenic acid': 4,
#    'imipramine': 1,
#    'immune sera': 8,
#    'immunoglobulin g': 4,
#    'immunoglobulin lambda-chains': 1,
#    'immunoglobulin light chains': 2,
#    'immunoglobulin m': 2,
#    'immunoglobulins': 3,
#    'indazoles': 1,
#    'indicators and reagents': 2,
#    'indoles': 1,
#    'inosine pranobex': 1,
#    'inositol': 1,
#    'insulin': 1,
#    'insulin-like growth factor i': 1,
#    'interferon type i': 1,
#    'interferon-gamma': 1,
#    'interleukin-1': 1,
#    'interleukin-2': 1,
#    'interleukin-6': 1,
#    'intermediate filament proteins': 10,
#    'iodine radioisotopes': 8,
#    'iodobenzenes': 1,
#    'iofetamine': 4,
#    'iron': 2,
#    'isoenzymes': 7,
#    'isoniazid': 1,
#    'isoquinolines': 1,
#    'kainic acid': 4,
#    'kallikreins': 2,
#    'ketanserin': 1,
#    'ketoglutarate dehydrogenase complex': 1,
#    'l': 1084,
#    'l-lactate dehydrogenase': 3,
#    'lactates': 1,
#    'lactic acid': 1,
#    'laminin': 2,
#    'lectins': 1,
#    'leucyl aminopeptidase': 1,
#    'leukocyte migration-inhibitory factors': 1,
#    'leupeptin': 1,
#    'leupeptins': 1,
#    'ligands': 1,
#    'ligases': 1,
#    'linoleoyl-coa desaturase': 1,
#    'lipid peroxides': 3,
#    'lipids': 1,
#    'lipoproteins': 2,
#    'lipoproteins, hdl': 1,
#    'lithostathine': 1,
#    'lr white': 1,
#    'luteinizing hormone': 1,
#    'lymphokines': 1,
#    'macromolecular substances': 2,
#    'magnesium': 2,
#    'malonates': 1,
#    'malondialdehyde': 1,
#    'mapt protein, human': 4,
#    'melanins': 1,
#    'melatonin': 1,
#    'membrane glycoproteins': 2,
#    'membrane lipids': 1,
#    'membrane proteins': 7,
#    'mercury': 1,
#    'mestranol': 1,
#    'metallothionein': 1,
#    'metals': 2,
#    'methacholine compounds': 1,
#    'methenamine': 1,
#    'methionine': 1,
#    'methoxyhydroxyphenylglycol': 3,
#    'methoxytryptophol': 1,
#    'methyltransferases': 2,
#    'methyltyrosines': 1,
#    'microtubule proteins': 2,
#    'microtubule-associated protein 1b': 1,
#    'microtubule-associated proteins': 39,
#    'mitogens': 1,
#    'moclobemide': 1,
#    'molecular chaperones': 1,
#    'molybdenum': 1,
#    'monoacylglycerol lipases': 1,
#    'monoamine oxidase': 5,
#    'monoamine oxidase inhibitors': 1,
#    'monosaccharide transport proteins': 1,
#    'n': 542,
#    'n(6)-cyclohexyladenosine': 1,
#    "n,n,n'-trimethyl-n'-(2-hydroxy-3-methyl-5-iodobenzyl)-1,3-propanediamine": 1,
#    'n-amino-n,n-dimethylaminoethanol': 2,
#    'n-methylaspartate': 4,
#    'n-n-propylnorapomorphine': 1,
#    'nad': 1,
#    'nadh dehydrogenase': 1,
#    'nafronyl': 1,
#    'nerve growth factors': 20,
#    'nerve tissue proteins': 47,
#    'neurofilament protein h': 1,
#    'neurofilament proteins': 8,
#    'neuromuscular depolarizing agents': 2,
#    'neuropeptide k': 1,
#    'neuropeptide y': 6,
#    'neuropeptides': 12,
#    'neurophysins': 1,
#    'neurotensin': 2,
#    'neurotoxins': 5,
#    'neurotransmitter agents': 23,
#    'nicotine': 5,
#    'nimodipine': 4,
#    'nitriles': 1,
#    'norepinephrine': 2,
#    'nucleoside-diphosphatase': 1,
#    'nucleosomes': 1,
#    'o': 542,
#    'o(6)-methylguanine-dna methyltransferase': 1,
#    'okadaic acid': 1,
#    'oligoclonal bands': 1,
#    'oligonucleotide probes': 4,
#    'omega-conotoxin gvia': 1,
#    'oncogene proteins v-ets': 1,
#    'oncogene proteins v-myb': 1,
#    'organophosphorus compounds': 1,
#    'organotechnetium compounds': 9,
#    'oxadiazoles': 1,
#    'oxazepam': 1,
#    'oxazoles': 1,
#    'oxidopamine': 2,
#    'oximes': 9,
#    'oxiracetam': 2,
#    'oxygen': 1,
#    'papain': 1,
#    'parasympatholytics': 1,
#    'parasympathomimetics': 7,
#    'parathyroid hormone': 2,
#    'pentetic acid': 1,
#    'peptide fragments': 7,
#    'peptide hydrolases': 4,
#    'peptides': 6,
#    'peptides, cyclic': 1,
#    'peroxides': 1,
#    'phencyclidine': 4,
#    'phenethylamines': 1,
#    'phenylethanolamine n-methyltransferase': 1,
#    'phenylmethylsulfonyl fluoride': 1,
#    'phenytoin': 1,
#    'phorbol 12,13-dibutyrate': 1,
#    'phosphates': 1,
#    'phosphatidylcholines': 6,
#    'phosphatidylethanolamines': 1,
#    'phosphatidylserines': 1,
#    'phosphofructokinase-1': 1,
#    'phospholipids': 3,
#    'phosphopeptides': 1,
#    'phosphoprotein phosphatases': 1,
#    'phosphoribosylamine-glycine ligase': 1,
#    'phosphoric monoester hydrolases': 2,
#    'phosphoserine': 2,
#    'physostigmine': 12,
#    'phytohemagglutinins': 1,
#    'piperazines': 1,
#    'piperidines': 3,
#    'pirenzepine': 1,
#    'pk 11195': 1,
#    'placebos': 7,
#    'plant lectins': 1,
#    'platelet-derived growth factor': 1,
#    'poly a': 2,
#    'poly adenosine diphosphate ribose': 1,
#    'poly u': 1,
#    'potassium': 2,
#    'potassium channels': 1,
#    'prealbumin': 1,
#    'pregnatrienes': 1,
#    'preprocholecystokinin': 1,
#    'prions': 1,
#    'pro-opiomelanocortin': 1,
#    'prolactin': 2,
#    'prolyl oligopeptidase': 1,
#    'protease inhibitors': 20,
#    'protease nexins': 1,
#    'protein kinase c': 4,
#    'protein kinases': 3,
#    'protein precursors': 70,
#    'proteins': 2,
#    'proteoglycans': 1,
#    'proto-oncogene protein c-ets-1': 1,
#    'proto-oncogene protein c-ets-2': 1,
#    'proto-oncogene proteins': 1,
#    'proto-oncogene proteins c-ets': 1,
#    'proto-oncogene proteins c-myb': 1,
#    'protriptyline': 1,
#    'prp 27-30 protein': 1,
#    'prpsc proteins': 2,
#    'psychotropic drugs': 6,
#    'pyridostigmine bromide': 1,
#    'pyridoxine': 1,
#    'pyrrolidines': 4,
#    'pyruvate dehydrogenase complex': 2,
#    'pyruvates': 1,
#    'quinine': 2,
#    'quinuclidines': 2,
#    'quinuclidinyl benzilate': 5,
#    'quinuclidinyl benzilate receptor': 1,
#    'quisqualic acid': 2,
#    'radon': 1,
#    'receptors, amino acid': 2,
#    'receptors, ampa': 4,
#    'receptors, cell surface': 9,
#    'receptors, cholinergic': 10,
#    'receptors, corticotropin-releasing hormone': 1,
#    'receptors, dopamine': 7,
#    'receptors, dopamine d2': 1,
#    'receptors, fc': 1,
#    'receptors, gaba-a': 3,
#    'receptors, glucocorticoid': 1,
#    'receptors, glutamate': 3,
#    'receptors, igg': 1,
#    'receptors, kainic acid': 3,
#    'receptors, leukocyte-adhesion': 1,
#    'receptors, muscarinic': 9,
#    'receptors, n-methyl-d-aspartate': 5,
#    'receptors, nerve growth factor': 2,
#    'receptors, neuropeptide y': 2,
#    'receptors, neurotensin': 1,
#    'receptors, neurotransmitter': 15,
#    'receptors, nicotinic': 5,
#    'receptors, opioid': 1,
#    'receptors, phencyclidine': 2,
#    'receptors, purinergic': 2,
#    'receptors, serotonin': 4,
#    'receptors, somatostatin': 1,
#    'receptors, transferrin': 1,
#    'receptors, very late antigen': 1,
#    'recombinant fusion proteins': 1,
#    'recombinant proteins': 9,
#    'repressor proteins': 1,
#    'retroviridae proteins, oncogenic': 1,
#    'ribonucleotides': 1,
#    'rna': 4,
#    'rna precursors': 1,
#    'rna probes': 3,
#    'rna, antisense': 1,
#    'rna, heterogeneous nuclear': 1,
#    'rna, messenger': 31,
#    'rna, neoplasm': 1,
#    'rna, viral': 1,
#    's-adenosylmethionine': 1,
#    's100 calcium binding protein g': 1,
#    's100 proteins': 1,
#    'sapropterin': 1,
#    'scopolamine hydrobromide': 2,
#    'selegiline': 5,
#    'serine': 1,
#    'serine endopeptidases': 2,
#    'serine proteinase inhibitors': 3,
#    'serotonin': 7,
#    'serotonin antagonists': 1,
#    'serpin e2': 1,
#    'serpine2 protein, human': 1,
#    'serum albumin': 2,
#    'serum amyloid a protein': 2,
#    'serum amyloid p-component': 2,
#    'silver': 1,
#    'sodium': 1,
#    'sodium dodecyl sulfate': 1,
#    'sodium-potassium-exchanging atpase': 1,
#    'somatomedins': 1,
#    'somatostatin': 7,
#    'spectrin': 1,
#    'spin labels': 3,
#    'staphylococcal protein a': 1,
#    'substance p': 5,
#    'sulfamethazine': 1,
#    'sulfates': 1,
#    'superoxide dismutase': 4,
#    'synaptin': 1,
#    'synaptophysin': 4,
#    't': 542,
#    'tachykinins': 1,
#    'tacrine': 20,
#    'taq polymerase': 1,
#    'tau proteins': 40,
#    'technetium tc 99m exametazime': 9,
#    'tenocyclidine': 2,
#    'tetradecanoylphorbol acetate': 1,
#    'theophylline': 1,
#    'thiazoles': 2,
#    'thiobarbiturates': 1,
#    'thiobarbituric acid': 1,
#    'thioflavin t': 2,
#    'thiol s-methyltransferase': 1,
#    'thiolester hydrolases': 1,
#    'thiophenes': 1,
#    'thrombin': 1,
#    'thymus hormones': 1,
#    'thyroglobulin': 1,
#    'thyroid hormones': 1,
#    'thyrotropin': 2,
#    'thyrotropin-releasing hormone': 1,
#    'thyroxine': 1,
#    'tissue extracts': 1,
#    'tolonium chloride': 1,
#    'toothpastes': 2,
#    'tosylarginine methyl ester hydrolase': 2,
#    'trace elements': 2,
#    'trans-activators': 1,
#    'transcription factors': 2,
#    'transferrin': 4,
#    'transforming growth factors': 2,
#    'transketolase': 2,
#    'tretinoin': 2,
#    'triglycerides': 1,
#    'triiodothyronine': 1,
#    'tritium': 5,
#    'tropomyosin': 1,
#    'trypsin': 3,
#    'trypsin inhibitor, kunitz soybean': 1,
#    'trypsin inhibitors': 1,
#    'tryptophan': 1,
#    'tryptophan hydroxylase': 1,
#    'tubulin': 3,
#    'tungsten': 1,
#    'tungsten compounds': 1,
#    'tyrosine 3-monooxygenase': 2,
#    'u 74500a': 1,
#    'ubiquitin thiolesterase': 1,
#    'ubiquitins': 11,
#    'v': 542,
#    'vasoconstrictor agents': 1,
#    'vasodilator agents': 1,
#    'velnacrine': 2,
#    'verapamil': 1,
#    'vesamicol': 3,
#    'vimentin': 1,
#    'viral proteins': 3,
#    'viral structural proteins': 1,
#    'vitamin b 12': 1,
#    'vitamin d': 1,
#    'vitamins': 1,
#    'water': 1,
#    'wheat germ agglutinins': 1,
#    'xanthine oxidase': 1,
#    'xanthinol niacinate': 1,
#    'xenobiotics': 1,
#    'zacopride': 1,
#    'zinc': 5},
#   'count_articles': 1150,
#   'mesh_titles': {'mitogens/pharmacology': 1,
#    'transcription factors/genetics': 2,
#    'bipolar disorder/genetics': 1,
#    'carbon dioxide': 1,
#    'verbal behavior': 3,
#    'cerebral cortex/growth & development': 1,
#    'central nervous system/drug effects': 1,
#    'connective tissue/metabolism': 1,
#    'nails/metabolism': 1,
#    'tomography, emission-computed, single-photon': 19,
#    'galantamine/administration & dosage': 2,
#    'microtubule-associated proteins/chemistry': 2,
#    'chromatography, affinity': 1,
#    'body temperature/drug effects': 2,
#    'models, genetic': 3,
#    'inclusion bodies/metabolism': 2,
#    'serum amyloid a protein/immunology': 1,
#    'neurotic disorders/etiology': 1,
#    'calcium/physiology': 3,
#    'homemaker services': 1,
#    'baltimore': 1,
#    'choroid plexus/diagnostic imaging': 1,
#    'dementia/prevention & control': 2,
#    'nimodipine/adverse effects': 1,
#    'amyloid/metabolism': 45,
#    'microtubules/metabolism': 3,
#    'microtubule proteins/analysis': 2,
#    'headache/etiology': 1,
#    'antidepressive agents, tricyclic/therapeutic use': 2,
#    'carrier proteins/physiology': 1,
#    'london': 1,
#    'memory disorders/etiology': 4,
#    'urinary incontinence/complications': 1,
#    'mood disorders/physiopathology': 1,
#    'enkephalin, methionine/pharmacology': 1,
#    'protein binding': 4,
#    'deoxyglucose/analogs & derivatives': 4,
#    'erythrocyte membrane/metabolism': 2,
#    'receptors, dopamine/physiology': 1,
#    'neuroglia/physiology': 2,
#    'parkinson disease/epidemiology': 1,
#    'ammonia/metabolism': 1,
#    'mammals/metabolism': 1,
#    'london/epidemiology': 1,
#    'alzheimer disease/epidemiology': 51,
#    'body weight/drug effects': 1,
#    'gene expression regulation/drug effects': 2,
#    'anxiety': 1,
#    'quisqualic acid/metabolism': 1,
#    'multivariate analysis': 1,
#    'subacute sclerosing panencephalitis/pathology': 1,
#    'serum albumin/metabolism': 1,
#    'phosphates/pharmacology': 1,
#    'amyloid beta-peptides/pharmacology': 3,
#    'mouth, edentulous/complications': 1,
#    'registries/statistics & numerical data': 2,
#    'glutamate dehydrogenase/metabolism': 1,
#    'thalamus/physiopathology': 1,
#    'amnesia/diagnosis': 1,
#    'food, fortified': 1,
#    'somatosensory cortex/pathology': 1,
#    'periodicals as topic': 1,
#    'stress, psychological/psychology': 4,
#    'xanthinol niacinate/therapeutic use': 1,
#    'quinine/therapeutic use': 1,
#    'galanthus': 1,
#    'somatomedins/physiology': 1,
#    'dietary carbohydrates': 1,
#    'immunoglobulin lambda-chains': 1,
#    'rna, messenger/biosynthesis': 5,
#    'pyridoxine/urine': 1,
#    'hippocampus/immunology': 1,
#    'united kingdom': 1,
#    'immunoglobulins/cerebrospinal fluid': 1,
#    'cholesterol/blood': 2,
#    'temporal lobe/pathology': 11,
#    'membrane fluidity/physiology': 1,
#    'socioeconomic factors': 3,
#    'muscle contraction': 1,
#    'seizures/epidemiology': 1,
#    'dementia/metabolism': 24,
#    'glycopyrrolate/administration & dosage': 1,
#    'family therapy': 1,
#    'dementia/drug therapy': 8,
#    'aminoacridines/pharmacology': 3,
#    'sleep stages/physiology': 1,
#    'dementia/diagnostic imaging': 17,
#    'delivery of health care/organization & administration': 1,
#    'retroviridae/immunology': 1,
#    'brain diseases/immunology': 1,
#    'capillary permeability': 1,
#    'temporal lobe/metabolism': 4,
#    'amino acids/cerebrospinal fluid': 1,
#    'genes, dominant': 4,
#    'hospitalization': 7,
#    'delusions/epidemiology': 1,
#    'chile/epidemiology': 1,
#    'hybrid cells/cytology': 1,
#    'pineal gland/diagnostic imaging': 1,
#    'copper/metabolism': 1,
#    'motor neurons': 1,
#    'mental status schedule/statistics & numerical data': 1,
#    'cognition/drug effects': 10,
#    'microtubule proteins/metabolism': 1,
#    'huntington disease/cerebrospinal fluid': 1,
#    'dogs': 1,
#    'peptide fragments/toxicity': 1,
#    'patient selection': 1,
#    'cerebrospinal fluid proteins/metabolism': 1,
#    'accidents, traffic/prevention & control': 1,
#    'phosphatidylethanolamines/metabolism': 1,
#    'hospices/organization & administration': 2,
#    'pattern recognition, visual': 7,
#    'acute-phase proteins/metabolism': 1,
#    'amygdala/pathology': 10,
#    'superoxide dismutase/genetics': 1,
#    'cerebral cortex/embryology': 1,
#    'casein kinases': 1,
#    'brain/pathology': 156,
#    'formates/pharmacology': 2,
#    'referral and consultation': 3,
#    'acetylcarnitine/adverse effects': 2,
#    'dementia, multi-infarct/diagnostic imaging': 8,
#    'neutrophils/immunology': 1,
#    'papain/metabolism': 1,
#    'retinal ganglion cells/pathology': 2,
#    'dopamine/physiology': 1,
#    'creatine kinase/blood': 1,
#    'recombinant proteins/toxicity': 1,
#    'catecholamines/physiology': 2,
#    'substance-related disorders/epidemiology': 1,
#    'dementia/enzymology': 4,
#    'cathepsin d/analysis': 1,
#    'huntington disease/physiopathology': 4,
#    'aging/blood': 3,
#    'corticotropin-releasing hormone/metabolism': 3,
#    'aminopeptidases/metabolism': 1,
#    'corticotropin-releasing hormone/cerebrospinal fluid': 2,
#    'luteinizing hormone/blood': 1,
#    'immunoglobulin m/analysis': 1,
#    'oxadiazoles': 1,
#    'nerve tissue proteins/isolation & purification': 3,
#    'hallucinations/diagnosis': 1,
#    'serine endopeptidases': 1,
#    'limbic system/physiology': 1,
#    'immunoglobulins/biosynthesis': 1,
#    'leukoencephalopathy, progressive multifocal/diagnosis': 1,
#    'rna, messenger/analysis': 10,
#    'medical history taking': 1,
#    'gerstmann-straussler-scheinker disease/pathology': 2,
#    'paired-associate learning': 1,
#    'thrombocytopenia/drug therapy': 1,
#    'basal ganglia/metabolism': 1,
#    'tacrine/adverse effects': 9,
#    'terminology as topic': 6,
#    'synaptic vesicles/ultrastructure': 1,
#    'medical records': 3,
#    'basal ganglia/blood supply': 1,
#    'immune system/drug effects': 1,
#    'nad/metabolism': 1,
#    'automobile driving/legislation & jurisprudence': 2,
#    'receptors, cell surface/drug effects': 1,
#    'craniocerebral trauma/diagnosis': 1,
#    'health services for the aged/organization & administration': 1,
#    'survival rate': 2,
#    'amygdala/enzymology': 1,
#    'dna restriction enzymes': 1,
#    'societies, medical': 1,
#    'peptide mapping': 1,
#    'delirium/psychology': 2,
#    'tacrine/therapeutic use': 13,
#    'trace elements/metabolism': 2,
#    'arterioles/metabolism': 1,
#    'hypertension/complications': 1,
#    'quinuclidinyl benzilate': 1,
#    'receptors, somatostatin': 1,
#    'nerve growth factors/physiology': 9,
#    'astrocytes/metabolism': 4,
#    'history, 20th century': 1,
#    'models, theoretical': 3,
#    'endoplasmic reticulum/enzymology': 1,
#    'schizophrenia/rehabilitation': 1,
#    'health services for the aged': 1,
#    'rna, neoplasm/genetics': 1,
#    'pheochromocytoma/pathology': 2,
#    'staining and labeling/methods': 1,
#    'recombinant proteins/genetics': 2,
#    'protein precursors/biosynthesis': 6,
#    'polymorphism, restriction fragment length': 5,
#    'neurocognitive disorders/drug therapy': 3,
#    'sleep/physiology': 1,
#    'home care services/organization & administration': 2,
#    'dementia, vascular/psychology': 4,
#    'methenamine': 1,
#    'organophosphorus compounds/adverse effects': 1,
#    'tumor cells, cultured/metabolism': 2,
#    'netherlands': 2,
#    'electroencephalography/statistics & numerical data': 2,
#    'cystatin c': 1,
#    'superoxide dismutase/blood': 2,
#    'brain diseases/diagnostic imaging': 4,
#    'thalamus/metabolism': 1,
#    'frontal lobe/pathology': 9,
#    'adenosine triphosphate/metabolism': 1,
#    'automobile driving': 1,
#    'axons/physiology': 4,
#    'babesiosis/drug therapy': 1,
#    'repetitive sequences, nucleic acid': 1,
#    'anthropometry': 1,
#    'tryptophan/therapeutic use': 1,
#    'psychometrics': 29,
#    'mitochondria, muscle/pathology': 1,
#    'phenethylamines/therapeutic use': 1,
#    'dementia/blood': 3,
#    'butyrylcholinesterase/metabolism': 3,
#    'suicide': 2,
#    'speech perception': 2,
#    'neuroimmunomodulation/physiology': 1,
#    'paraventricular hypothalamic nucleus': 1,
#    'flow cytometry': 1,
#    'tumor cells, cultured': 4,
#    'cyclic gmp/physiology': 1,
#    'ethics, pharmacy': 1,
#    'nursing homes/legislation & jurisprudence': 1,
#    'infant': 6,
#    'australia': 2,
#    'hexokinase/analysis': 1,
#    'receptors, cell surface/genetics': 3,
#    'specimen handling/methods': 1,
#    'pyridoxine/therapeutic use': 1,
#    'chemistry': 1,
#    'pitch discrimination/physiology': 1,
#    'basal ganglia diseases/pathology': 1,
#    'autoimmune diseases/immunology': 1,
#    'nerve degeneration/drug effects': 1,
#    'social isolation/psychology': 1,
#    'drug design': 1,
#    'patient discharge/statistics & numerical data': 2,
#    'research design': 4,
#    'neurons/metabolism': 12,
#    'parkinson disease/classification': 1,
#    'supranuclear palsy, progressive/psychology': 1,
#    'synapses/pathology': 3,
#    'enzyme-linked immunosorbent assay': 9,
#    'oxidation-reduction': 2,
#    'locus coeruleus/pathology': 2,
#    'protease inhibitors/pharmacology': 2,
#    'blotting, southern': 6,
#    'confusion/etiology': 2,
#    'creatine kinase/deficiency': 2,
#    'parasympathomimetics/therapeutic use': 5,
#    'magnesium/blood': 1,
#    'mental status schedule': 16,
#    'hippocampus/ultrastructure': 2,
#    'phencyclidine/analogs & derivatives': 3,
#    'poly a/analysis': 1,
#    'frozen sections': 1,
#    'epilepsies, partial/drug therapy': 1,
#    'attention/physiology': 6,
#    'hydrocephalus/diagnosis': 3,
#    'neurofibrils/metabolism': 16,
#    'cause of death': 5,
#    'education': 1,
#    'nervous system diseases/physiopathology': 1,
#    'microscopy, immunoelectron': 6,
#    'professional-family relations': 3,
#    'calcium-transporting atpases/metabolism': 1,
#    'alzheimer disease/metabolism': 243,
#    'carbon radioisotopes': 2,
#    'thrombocytopenia/chemically induced': 1,
#    'aluminum/metabolism': 5,
#    'extracellular space/cytology': 1,
#    'peripheral nerve injuries': 1,
#    'cricetinae': 2,
#    'social isolation': 2,
#    'carbon-nitrogen ligases': 1,
#    'reproducibility of results': 6,
#    'data interpretation, statistical': 1,
#    'antibodies/analysis': 2,
#    'ribonucleotides/metabolism': 1,
#    'lymphocyte subsets/drug effects': 1,
#    'pancreas/physiology': 1,
#    'cerebrovascular disorders/nursing': 1,
#    'occipital lobe/diagnostic imaging': 1,
#    'heterozygote': 1,
#    'nerve fibers, myelinated/pathology': 1,
#    'psychiatric nursing': 1,
#    'immunoassay': 2,
#    'huntington disease/psychology': 4,
#    'lactates/metabolism': 1,
#    'asthma/drug therapy': 1,
#    'arousal': 3,
#    'activities of daily living/psychology': 8,
#    'bridged bicyclo compounds, heterocyclic': 1,
#    'pyrrolidines/blood': 1,
#    'defense mechanisms': 1,
#    'slow virus diseases/complications': 1,
#    'palliative care': 1,
#    'long-term care/organization & administration': 2,
#    'brain damage, chronic/psychology': 4,
#    'costs and cost analysis': 1,
#    'indicators and reagents': 2,
#    'myelin sheath/pathology': 1,
#    'chromatography, thin layer': 2,
#    'nictitating membrane/drug effects': 1,
#    'multigene family': 1,
#    'substance p/immunology': 1,
#    'cerebral cortex/ultrastructure': 9,
#    'neuropeptides/metabolism': 4,
#    'retrospective studies': 12,
#    'individuation': 2,
#    'peptide fragments/metabolism': 2,
#    'neutron activation analysis': 1,
#    'central nervous system diseases/etiology': 1,
#    'frontal lobe/physiopathology': 4,
#    'corpus striatum/drug effects': 1,
#    'immunoglobulins/chemistry': 1,
#    'language disorders/classification': 1,
#    'interleukin-1/pharmacology': 1,
#    'autonomic nervous system diseases/physiopathology': 1,
#    'brain/drug effects': 12,
#    'dementia/rehabilitation': 2,
#    'cognition disorders/genetics': 1,
#    'mast cells/metabolism': 1,
#    'nervous system diseases/metabolism': 1,
#    'nerve growth factors/biosynthesis': 1,
#    'huntington disease/enzymology': 1,
#    'selegiline/adverse effects': 2,
#    'receptors, neurotransmitter/metabolism': 9,
#    'aging': 15,
#    'chemical and drug induced liver injury/etiology': 2,
#    'seizures/etiology': 1,
#    'pituitary-adrenal system/physiopathology': 6,
#    'amyloid beta-peptides/metabolism': 12,
#    'cognition': 12,
#    'orientation': 6,
#    'hippocampus/chemistry': 2,
#    'epidermal growth factor/physiology': 1,
#    'nervous system diseases/pathology': 3,
#    'memory disorders/physiopathology': 3,
#    'monoamine oxidase/analysis': 1,
#    'pregnatrienes/pharmacology': 1,
#    'potassium channels/drug effects': 1,
#    'psychotherapy/methods': 1,
#    'respite care/organization & administration': 1,
#    'neurofibrils/ultrastructure': 26,
#    'behavior, animal/drug effects': 2,
#    'psychiatric status rating scales/statistics & numerical data': 1,
#    'lymphocyte activation': 2,
#    'schizophrenia/physiopathology': 1,
#    'recombinant proteins': 2,
#    'interferon type i/pharmacology': 1,
#    'isoniazid/therapeutic use': 1,
#    'mental recall/drug effects': 3,
#    'brain neoplasms/metabolism': 1,
#    'systems theory': 1,
#    'protein kinase c/analysis': 1,
#    'fluorodeoxyglucose f18': 4,
#    'europe': 3,
#    'neuropeptides/pharmacology': 1,
#    'mercury/metabolism': 1,
#    'cholinesterase inhibitors/metabolism': 1,
#    'glutamates/metabolism': 7,
#    'ferritins/analysis': 1,
#    'communication aids for disabled': 1,
#    'neutrophils/drug effects': 1,
#    'protein precursors/chemistry': 2,
#    'calpain/genetics': 1,
#    'receptors, cell surface': 1,
#    'immunoelectrophoresis, two-dimensional': 1,
#    'peptide fragments/blood': 1,
#    'lymphocyte activation/drug effects': 2,
#    'dementia/complications': 13,
#    'self-help devices': 1,
#    'dna transposable elements': 1,
#    'nurse-patient relations': 2,
#    'creatine kinase/metabolism': 1,
#    'mass spectrometry': 1,
#    'rna probes': 3,
#    'stress, physiological/physiopathology': 1,
#    'deoxyribonuclease hpaii': 1,
#    'pyruvates/pharmacology': 1,
#    'antidepressive agents/therapeutic use': 1,
#    'calcium channels/drug effects': 1,
#    'consumer behavior': 1,
#    'subcellular fractions/enzymology': 1,
#    'amyloid/analysis': 28,
#    'aphasia/etiology': 2,
#    'parkinson disease/mortality': 1,
#    'communication': 1,
#    'receptors, cholinergic/metabolism': 2,
#    'conditioning, classical/drug effects': 1,
#    'carbocysteine/metabolism': 1,
#    'dendrites/drug effects': 1,
#    'molecular biology': 1,
#    'omega-conotoxin gvia': 1,
#    'self concept': 3,
#    'viral proteins/analysis': 2,
#    'radiation injuries/diagnostic imaging': 1,
#    'down syndrome/diagnostic imaging': 1,
#    'memory disorders/complications': 1,
#    'calcium/metabolism': 2,
#    'nursing assessment': 4,
#    'cell survival': 9,
#    'pyramidal tracts/pathology': 5,
#    'cohort studies': 4,
#    'mental disorders/diagnosis': 2,
#    'attitude of health personnel': 2,
#    'molecular probe techniques': 1,
#    'dementia, multi-infarct/classification': 1,
#    'boston/epidemiology': 1,
#    'blotting, northern': 9,
#    'home care services/manpower': 1,
#    'receptors, neurotransmitter/physiology': 2,
#    'feeding behavior/drug effects': 2,
#    'memory': 22,
#    'cholinesterase inhibitors/therapeutic use': 4,
#    'galanin': 3,
#    'receptors, igg': 1,
#    'antidepressive agents, tricyclic/adverse effects': 1,
#    'hormones/physiology': 2,
#    'nerve tissue/pathology': 2,
#    'gallium/blood': 2,
#    'terminal care/psychology': 1,
#    'pancreatic neoplasms/nursing': 1,
#    'delirium/diagnosis': 4,
#    'mental recall': 22,
#    'day care, medical/manpower': 1,
#    'lipoproteins, hdl/blood': 1,
#    'piperidines': 2,
#    'odds ratio': 1,
#    'wheat germ agglutinins/metabolism': 1,
#    'arecoline/pharmacology': 1,
#    'ataxia/physiopathology': 1,
#    's100 proteins/metabolism': 1,
#    'genetic vectors': 1,
#    'neurons/analysis': 2,
#    'parkinson disease/blood': 3,
#    'chromosome aberrations': 2,
#    'skin/enzymology': 4,
#    'adenosine/metabolism': 1,
#    'alleles': 3,
#    't-lymphocytes/immunology': 1,
#    'oxidopamine': 2,
#    'pituitary-adrenal system/physiology': 1,
#    'basal ganglia/physiology': 1,
#    'curriculum': 1,
#    'membrane proteins/metabolism': 5,
#    'mice, mutant strains': 1,
#    'cerebrovascular circulation/drug effects': 2,
#    'huntington disease/pathology': 2,
#    'visual perception/physiology': 2,
#    'feeding behavior/psychology': 1,
#    'pyridoxine/administration & dosage': 1,
#    'dementia, vascular/prevention & control': 3,
#    'affective symptoms/drug therapy': 1,
#    'dexamethasone/pharmacology': 1,
#    'confusion/nursing': 1,
#    'calpain/metabolism': 2,
#    'malondialdehyde/metabolism': 1,
#    'seizures/diagnosis': 1,
#    'cerebrovascular circulation/physiology': 7,
#    'depressive disorder/mortality': 1,
#    'dehydroepiandrosterone/analogs & derivatives': 2,
#    'fibroblasts/enzymology': 6,
#    'taste disorders/physiopathology': 1,
#    'crime': 1,
#    'health status': 1,
#    'serine proteinase inhibitors': 1,
#    'hla-dr antigens/analysis': 3,
#    'astrocytoma/enzymology': 1,
#    'substance-related disorders/metabolism': 1,
#    'transcription, genetic': 6,
#    'population surveillance': 1,
#    'telephone': 1,
#    'consciousness disorders/complications': 1,
#    'superoxide dismutase/analysis': 1,
#    'phencyclidine/analysis': 1,
#    'pacific islands': 1,
#    'affective symptoms/psychology': 2,
#    'erythrocytes/metabolism': 1,
#    'disease susceptibility': 1,
#    'organizations': 1,
#    'erectile dysfunction/etiology': 1,
#    'sleep stages': 1,
#    'reference values': 46,
#    'asthma/complications': 1,
#    'n-methylaspartate': 2,
#    'dystonia/diagnosis': 1,
#    'progeria/pathology': 1,
#    'autoantibodies/immunology': 1,
#    'bethanechol compounds/therapeutic use': 1,
#    'space perception/physiology': 1,
#    'autistic disorder/metabolism': 1,
#    'pregnancy': 4,
#    'trans-activators': 1,
#    'substantia innominata/pathology': 7,
#    'awareness': 1,
#    'periodicity': 2,
#    'diphenhydramine/therapeutic use': 1,
#    'databases, bibliographic': 1,
#    'neurosecretory systems/physiopathology': 1,
#    'serum albumin/analysis': 1,
#    'karyotyping': 1,
#    'hypothyroidism/complications': 1,
#    'atropine/pharmacology': 1,
#    'mental recall/physiology': 7,
#    'neurotensin/metabolism': 2,
#    'gallium/metabolism': 3,
#    'pyrrolidines/therapeutic use': 2,
#    'magnetic resonance imaging': 25,
#    'brain tissue transplantation/pathology': 1,
#    'tritium': 5,
#    'hippocampus/transplantation': 1,
#    'motor neurons/physiology': 1,
#    'capillary permeability/physiology': 1,
#    'microtubule-associated proteins/physiology': 1,
#    'hippocampus/drug effects': 2,
#    'electrophoresis, polyacrylamide gel': 13,
#    'amyloid/secretion': 1,
#    'cerebrovascular disorders/prevention & control': 1,
#    'chromatin/analysis': 1,
#    'calcium-calmodulin-dependent protein kinases': 1,
#    'men': 1,
#    'ubiquitins/metabolism': 6,
#    'time factors': 11,
#    'actins/genetics': 1,
#    'melanins/analysis': 1,
#    'bender-gestalt test': 1,
#    'dementia/mortality': 2,
#    'hospital units/economics': 1,
#    'receptors, muscarinic/metabolism': 7,
#    'tropomyosin/immunology': 1,
#    'adenosine/analogs & derivatives': 1,
#    'dental care for disabled/economics': 1,
#    'sensory thresholds/physiology': 1,
#    'antiparkinson agents/adverse effects': 1,
#    'intracranial arteriosclerosis/drug therapy': 1,
#    'mental disorders/physiopathology': 2,
#    'hispanic americans/psychology': 1,
#    'health surveys': 3,
#    'hemiplegia/physiopathology': 2,
#    'killer cells, natural/physiology': 1,
#    'amyotrophic lateral sclerosis/physiopathology': 2,
#    'cerebral cortex/physiopathology': 8,
#    'cadmium/metabolism': 1,
#    'gtp-binding proteins/metabolism': 1,
#    'phonetics': 1,
#    'dementia/epidemiology': 26,
#    'parkinson disease/complications': 8,
#    'life change events': 3,
#    'research support as topic': 3,
#    'intracranial aneurysm/diagnosis': 1,
#    'electric stimulation': 3,
#    'random allocation': 2,
#    'carrier proteins/isolation & purification': 1,
#    'protriptyline/therapeutic use': 1,
#    'cerebral cortex/drug effects': 5,
#    'dopamine agents/metabolism': 1,
#    'health maintenance organizations/economics': 1,
#    'brain/immunology': 10,
#    'cerebellar cortex/enzymology': 1,
#    'anxiety, separation/therapy': 2,
#    'locus coeruleus/physiopathology': 1,
#    'protein precursors/physiology': 2,
#    'neoplasms/therapy': 1,
#    'spouse abuse/pathology': 1,
#    'centromere': 1,
#    'deferoxamine/therapeutic use': 1,
#    'mutation': 5,
#    'amyloid beta-protein precursor': 63,
#    'psychotropic drugs/adverse effects': 1,
#    'amyloidosis/etiology': 2,
#    'protein-energy malnutrition/etiology': 1,
#    'cerebellar nuclei/physiopathology': 1,
#    'lymphocytes/metabolism': 3,
#    'immunodiffusion': 2,
#    'intelligence tests/methods': 1,
#    'neuromuscular diseases/enzymology': 1,
#    'indoles/metabolism': 1,
#    'dominance, cerebral/physiology': 8,
#    'neuropeptides/cerebrospinal fluid': 1,
#    'gangliosides/analysis': 1,
#    'reaction time': 5,
#    'ticks': 1,
#    'tacrine/urine': 1,
#    'leukocyte migration-inhibitory factors/biosynthesis': 1,
#    'animals, newborn': 1,
#    'astrocytes/chemistry': 1,
#    'receptors, neurotransmitter/ultrastructure': 1,
#    'nucleosomes/analysis': 1,
#    'institutionalization': 5,
#    'mental disorders/pathology': 2,
#    'cerebrovascular disorders/diagnostic imaging': 2,
#    'peptides/analysis': 1,
#    'aluminum/administration & dosage': 1,
#    'genetic predisposition to disease': 1,
#    'dental care for disabled': 4,
#    'vacuoles/ultrastructure': 1,
#    'hla-dr antigens/immunology': 2,
#    'protein precursors/analysis': 10,
#    'glutamates/toxicity': 1,
#    'optic nerve diseases/etiology': 1,
#    'cerebellum/analysis': 1,
#    'age factors': 32,
#    'membrane lipids/metabolism': 1,
#    'apoproteins/blood': 1,
#    'telencephalon/metabolism': 1,
#    'antigens/immunology': 1,
#    'cathepsin b/analysis': 1,
#    'beneficence': 1,
#    's100 calcium binding protein g/genetics': 1,
#    'receptors, n-methyl-d-aspartate': 1,
#    'pursuit, smooth/drug effects': 1,
#    'alzheimer disease/immunology': 31,
#    'glial fibrillary acidic protein/immunology': 1,
#    'gtp-binding proteins/drug effects': 1,
#    'conditioning, classical/physiology': 4,
#    'injections, intraventricular': 2,
#    'housing': 1,
#    'cell line, transformed': 1,
#    'learning/drug effects': 1,
#    'depressive disorder/complications': 2,
#    'psychoanalytic therapy': 1,
#    'alpha 1-antichymotrypsin/immunology': 1,
#    'myotonic dystrophy/pathology': 2,
#    'drug stability': 1,
#    'cricetulus': 1,
#    'alzheimer disease/rehabilitation': 5,
#    'basal ganglia/anatomy & histology': 1,
#    'hospital units/organization & administration': 1,
#    'peptide hydrolases/physiology': 2,
#    'electrophoresis, polyacrylamide gel/methods': 1,
#    'psychomotor performance/physiology': 3,
#    'massachusetts': 2,
#    'proto-oncogene protein c-ets-2': 1,
#    'dendrites/metabolism': 1,
#    'nerve tissue proteins/biosynthesis': 2,
#    'discrimination learning/physiology': 1,
#    'neurocognitive disorders/metabolism': 1,
#    'molybdenum': 1,
#    'indiana': 1,
#    'cerebral ventriculography': 2,
#    'staining and labeling': 29,
#    'choline/cerebrospinal fluid': 1,
#    'simplexvirus/genetics': 1,
#    'isoenzymes/immunology': 1,
#    'cognition/physiology': 6,
#    'cell differentiation': 2,
#    'myoclonus/epidemiology': 1,
#    'chromogranin a': 1,
#    'glycopyrrolate/pharmacology': 1,
#    'endopeptidases/metabolism': 4,
#    'central nervous system/physiology': 3,
#    'gerstmann-straussler-scheinker disease/immunology': 1,
#    'nicotine/metabolism': 1,
#    'fetal tissue transplantation/pathology': 1,
#    'nerve growth factors/administration & dosage': 1,
#    'hypothalamo-hypophyseal system/physiopathology': 7,
#    'antipsychotic agents/adverse effects': 2,
#    'molecular chaperones': 1,
#    'endopeptidases/pharmacology': 1,
#    'neuroblastoma/immunology': 1,
#    'dementia/pathology': 40,
#    'dementia, multi-infarct/pathology': 3,
#    'receptors, neurotransmitter/drug effects': 2,
#    'frontal lobe/metabolism': 5,
#    'altruism': 1,
#    'peptide hydrolases/metabolism': 3,
#    'models, neurological': 9,
#    'aspartic acid/metabolism': 2,
#    'rats': 40,
#    'adrenal gland neoplasms/analysis': 1,
#    'alcoholism/drug therapy': 1,
#    'synaptic transmission/drug effects': 2,
#    "physician's role": 3,
#    'beta-endorphin/cerebrospinal fluid': 1,
#    'receptors, glucocorticoid/metabolism': 1,
#    'metals/toxicity': 1,
#    'china/epidemiology': 1,
#    'recombinant proteins/isolation & purification': 1,
#    'hydrogen-ion concentration': 3,
#    'confounding factors (epidemiology)': 2,
#    'babesiosis/complications': 1,
#    'antigens, cd45': 1,
#    'cell membrane/metabolism': 2,
#    'monoamine oxidase inhibitors/administration & dosage': 1,
#    'peptides, cyclic/metabolism': 1,
#    'myelin sheath/enzymology': 1,
#    'pituitary-adrenal system/drug effects': 2,
#    'spindle apparatus/drug effects': 1,
#    'microtubule-associated proteins/immunology': 14,
#    'culture media': 3,
#    'nucleic acid hybridization': 19,
#    'personality disorders/etiology': 1,
#    'aids dementia complex/pathology': 1,
#    'receptors, dopamine d2': 1,
#    'cerebrovascular disorders/diagnosis': 3,
#    'scandinavian and nordic countries': 1,
#    'triiodothyronine/metabolism': 1,
#    'chemical phenomena': 1,
#    'psychiatric status rating scales': 37,
#    'bonding, human-pet': 1,
#    'aggression': 1,
#    'amyloid beta-peptides/cerebrospinal fluid': 1,
#    'suprachiasmatic nucleus/physiopathology': 1,
#    'atrophy': 17,
#    'tubulin/metabolism': 1,
#    'central nervous system agents/administration & dosage': 1,
#    'substance p/genetics': 1,
#    'respite care': 4,
#    'pseudogenes': 1,
#    'dietary fats': 1,
#    'cerebellar neoplasms/enzymology': 1,
#    'nerve degeneration/physiology': 13,
#    'tau proteins': 39,
#    'n-methylaspartate/toxicity': 1,
#    'neural pathways/physiopathology': 2,
#    'retention (psychology)/physiology': 1,
#    'accidents, traffic/legislation & jurisprudence': 1,
#    'quality control': 1,
#    'capsules': 1,
#    'alzheimer disease/etiology': 56,
#    'cognition disorders/diagnosis': 17,
#    'antacids/adverse effects': 1,
#    'false positive reactions': 1,
#    'anomia/diagnosis': 4,
#    'speech production measurement': 2,
#    'erythrocytes/chemistry': 1,
#    'radiotherapy/adverse effects': 1,
#    'galantamine/adverse effects': 1,
#    'pyramidal tracts/metabolism': 1,
#    'aged, 80 and over': 305,
#    'government': 1,
#    'neurofibrillary tangles/chemistry': 1,
#    'antioxidants/metabolism': 1,
#    'epitopes/analysis': 6,
#    'injections, intravenous': 1,
#    'dementia': 3,
#    'somatostatin/metabolism': 6,
#    'depression/epidemiology': 1,
#    'cytoskeletal proteins/genetics': 1,
#    'parkinson disease/metabolism': 14,
#    'nervous system diseases/diagnosis': 1,
#    'thyroxine/metabolism': 1,
#    'memory disorders/genetics': 1,
#    'tacrine/metabolism': 1,
#    'glycosaminoglycans/metabolism': 1,
#    'receptors, purinergic/metabolism': 2,
#    'gene library': 2,
#    'toothpastes/analysis': 2,
#    'biopsy': 3,
#    'sodium dodecyl sulfate': 1,
#    'hydroxydopamines': 2,
#    'limbic system/pathology': 4,
#    'neurites/pathology': 1,
#    'microtubules/chemistry': 1,
#    'schizophrenia/diagnostic imaging': 1,
#    'brain diseases/pathology': 3,
#    'discriminant analysis': 2,
#    'metabolic diseases/diagnosis': 1,
#    'financing, government': 1,
#    'vision disorders/diagnosis': 4,
#    'myelin sheath/chemistry': 1,
#    'dementia/diagnosis': 57,
#    'oxygen/metabolism': 1,
#    'ibotenic acid': 1,
#    'demyelinating diseases/complications': 1,
#    'heparitin sulfate/analysis': 1,
#    'parasympatholytics/pharmacology': 1,
#    'coronary disease/pathology': 1,
#    'dementia, multi-infarct/cerebrospinal fluid': 1,
#    'zinc/metabolism': 3,
#    'creutzfeldt-jakob syndrome/classification': 1,
#    'alzheimer disease': 30,
#    'subcellular fractions/metabolism': 2,
#    'amyotrophic lateral sclerosis/genetics': 2,
#    'terminal care': 2,
#    'parietal lobe/pathology': 3,
#    'receptors, cholinergic/drug effects': 2,
#    'irritable mood': 1,
#    'muscle rigidity/metabolism': 1,
#    'nerve fibers/metabolism': 1,
#    'binding sites': 4,
#    'microtubule-associated proteins/biosynthesis': 1,
#    'cerebral cortex/metabolism': 22,
#    'dyskinesia, drug-induced/physiopathology': 1,
#    'cholinergic fibers/metabolism': 3,
#    'parotid gland/secretion': 1,
#    'citalopram/therapeutic use': 1,
#    'blood-brain barrier': 8,
#    'amantadine/administration & dosage': 1,
#    'tissue distribution': 7,
#    'cognition disorders/pathology': 2,
#    'nitriles/pharmacology': 1,
#    'reference standards': 1,
#    'zinc/blood': 1,
#    'dementia/physiopathology': 25,
#    'acetaminophen/metabolism': 1,
#    'psychomotor disorders/drug therapy': 1,
#    'dementia, vascular/diagnosis': 15,
#    'hypothyroidism/immunology': 1,
#    'neuronal plasticity': 4,
#    'cerebral hemorrhage/complications': 1,
#    'hydrocortisone/blood': 10,
#    'immunochemistry': 2,
#    'visual cortex/physiopathology': 1,
#    'cross-linking reagents': 1,
#    'macaca mulatta/physiology': 1,
#    'motor neurons/metabolism': 1,
#    'cognition disorders/epidemiology': 1,
#    'scopolamine hydrobromide/pharmacology': 1,
#    'nerve regeneration': 3,
#    'semantics': 11,
#    'brain diseases/psychology': 1,
#    'rna/genetics': 3,
#    'comorbidity': 1,
#    'models, molecular': 1,
#    'nervous system/metabolism': 1,
#    'gliosis/pathology': 2,
#    'hippocampus/growth & development': 2,
#    'hypersensitivity/physiopathology': 1,
#    'demyelinating diseases/diagnosis': 1,
#    'glycerylphosphorylcholine/metabolism': 1,
#    'laminin/physiology': 1,
#    'transfection': 5,
#    'neuromuscular diseases/blood': 1,
#    'thiophenes': 1,
#    'chromosome mapping': 10,
#    'psycholinguistics': 1,
#    'genetic markers': 6,
#    'citalopram/adverse effects': 1,
#    'motor neurons/pathology': 1,
#    'pressure ulcer/etiology': 1,
#    'vasoconstrictor agents': 1,
#    'calcium channels/metabolism': 1,
#    'immunoblotting/methods': 1,
#    'parkinson disease/surgery': 3,
#    'receptors, opioid/metabolism': 1,
#    'epoprostenol/pharmacology': 1,
#    'choline o-acetyltransferase/metabolism': 19,
#    'aminoacridines/administration & dosage': 1,
#    'dementia/cerebrospinal fluid': 3,
#    'liver diseases/pathology': 1,
#    'taste disorders/etiology': 1,
#    'chorea/chemically induced': 1,
#    'optic nerve/ultrastructure': 1,
#    'anxiety, separation/psychology': 1,
#    'nutritional status': 1,
#    'erythrocytes/analysis': 1,
#    'blood vessels/pathology': 3,
#    'nerve growth factors/therapeutic use': 4,
#    'amygdala/physiology': 1,
#    'right to die': 1,
#    'ultrasonography': 1,
#    'diazepam binding inhibitor': 1,
#    'brain neoplasms/diagnostic imaging': 1,
#    'pituitary gland/metabolism': 1,
#    'alkaline phosphatase/blood': 1,
#    'community mental health centers': 1,
#    'adrenal medulla/transplantation': 2,
#    'retina/ultrastructure': 1,
#    'intelligence tests': 6,
#    'creutzfeldt-jakob syndrome/transmission': 1,
#    'platelet count/drug effects': 1,
#    'technology assessment, biomedical': 1,
#    'cognition disorders/physiopathology': 7,
#    'evoked potentials, auditory/physiology': 5,
#    'united states food and drug administration': 1,
#    'neurotransmitter agents/physiology': 7,
#    'brain/physiology': 11,
#    'fecal incontinence/complications': 1,
#    'bridged bicyclo compounds': 1,
# ...
#    'membrane transport proteins/metabolism': 6,
#    'atrial fibrillation/drug therapy': 1,
#    'multiple sclerosis/drug therapy': 2,
#    'orientation': 4,
#    'post-dural puncture headache/etiology': 1,
#    'microglia/ultrastructure': 1,
#    'chromosomes/metabolism': 2,
#    'receptors, serotonin/metabolism': 2,
#    'ergosterol/metabolism': 1,
#    'fibronectins/genetics': 1,
#    'nervous system diseases/pathology': 1,
#    'quality assurance, health care/legislation & jurisprudence': 1,
#    'internet/organization & administration': 1,
#    'memory disorders/physiopathology': 38,
#    'acquired immunodeficiency syndrome/genetics': 1,
#    'receptors, retinoic acid/genetics': 2,
#    'intermediate care facilities/supply & distribution': 1,
#    'video recording': 2,
#    'sweden': 10,
#    'methylphenidate/administration & dosage': 1,
#    'communication disorders/etiology': 1,
#    'neovascularization, pathologic/pathology': 1,
#    'behavior, animal/drug effects': 17,
#    'father-child relations': 1,
#    'uridine monophosphate/metabolism': 1,
#    'receptor, muscarinic m3/genetics': 1,
#    'psychiatric status rating scales/statistics & numerical data': 5,
#    'pulmonary disease, chronic obstructive/immunology': 1,
#    'antibodies/therapeutic use': 11,
#    'photic stimulation/methods': 11,
#    'plaque, amyloid/enzymology': 2,
#    'pyridines/therapeutic use': 3,
#    'hyperemia/metabolism': 1,
#    'benzeneacetamides/pharmacology': 1,
#    'psychomotor agitation/prevention & control': 1,
#    'diabetes mellitus, type 2/blood': 1,
#    'mental recall/drug effects': 1,
#    'blood-brain barrier/immunology': 1,
#    'amyloid beta-peptides/antagonists & inhibitors': 59,
#    'ovarian cysts/diagnostic imaging': 1,
#    'basal ganglia diseases/genetics': 1,
#    'aziridines/toxicity': 1,
#    'antibody specificity/immunology': 1,
#    'imaging, three-dimensional/methods': 26,
#    'kentucky/epidemiology': 1,
#    'siderosis/physiopathology': 1,
#    'clinical trials as topic/economics': 2,
#    'protein kinase c-alpha/metabolism': 1,
#    'data collection/economics': 1,
#    'amyloid beta-peptides/urine': 2,
#    'family conflict/psychology': 3,
#    'vascular diseases/metabolism': 2,
#    'sigmoid diseases/surgery': 1,
#    'alum compounds/toxicity': 1,
#    'myocardial perfusion imaging/methods': 1,
#    'glycosides/chemical synthesis': 1,
#    'transcription factors/blood': 1,
#    'endoplasmic reticulum/pathology': 2,
#    'perceptual disorders/physiopathology': 2,
#    'genome-wide association study/standards': 1,
#    'pharmaceutical preparations/economics': 1,
#    'pericytes/secretion': 1,
#    'cognitive dysfunction/diagnostic imaging': 1,
#    'nervous system/immunology': 1,
#    'nerve regeneration/drug effects': 1,
#    'protein precursors/chemistry': 1,
#    'protein interaction domains and motifs/physiology': 1,
#    'personhood': 3,
#    'matrix metalloproteinase 2/cerebrospinal fluid': 1,
#    'malnutrition/psychology': 1,
#    'transcription factors/biosynthesis': 1,
#    'prions/genetics': 9,
#    'encephalitis/chemically induced': 2,
#    'rna, untranslated': 1,
#    'up-regulation': 21,
#    'peptide fragments/blood': 25,
#    'lymphocyte activation/drug effects': 1,
#    'peptide fragments/secretion': 2,
#    'insulin resistance/physiology': 5,
#    'oligopeptides/metabolism': 1,
#    't-lymphocyte subsets/immunology': 1,
#    'nurse-patient relations': 11,
#    'reflex/drug effects': 1,
#    'mass spectrometry': 10,
#    'neuropeptides/drug effects': 1,
#    'hla-dr antigens/metabolism': 4,
#    'citric acid cycle/drug effects': 1,
#    'pulmonary alveoli/chemistry': 1,
#    'dentures/psychology': 1,
#    'fluorescent dyes': 5,
#    'down syndrome/diagnosis': 1,
#    'practice (psychology)': 1,
#    'frontotemporal lobar degeneration/physiopathology': 1,
#    'nitric oxide/biosynthesis': 4,
#    'neurons/classification': 1,
#    'rna processing, post-transcriptional': 1,
#    'neural pathways/metabolism': 5,
#    'psychomotor agitation/genetics': 1,
#    'cannabinoids/pharmacology': 1,
#    'aphasia/etiology': 1,
#    'parkinson disease/mortality': 1,
#    'prednisone/adverse effects': 1,
#    'wine/analysis': 1,
#    'immunoglobulins/cerebrospinal fluid': 1,
#    'proto-oncogene proteins c-bcl-2/metabolism': 5,
#    'chlamydophila infections/microbiology': 1,
#    'calcium-calmodulin-dependent protein kinase type 4/metabolism': 1,
#    'crocus/chemistry': 1,
#    'receptors, cholinergic/metabolism': 2,
#    'conditioning, classical/drug effects': 2,
#    'vitamins/pharmacology': 1,
#    'medicine in literature': 1,
#    'hmgb1 protein/metabolism': 1,
#    'mastication/physiology': 1,
#    'caspase 8/immunology': 1,
#    'oxygen/chemistry': 2,
#    'caenorhabditis elegans/ultrastructure': 1,
#    'self concept': 9,
#    'somatostatin/blood': 1,
#    'evidence-based practice/ethics': 1,
#    'chromatography, liquid/methods': 6,
#    'epilepsy/pathology': 1,
#    'raphe nuclei/pathology': 3,
#    'beta-mannosidase/cerebrospinal fluid': 1,
#    'temporal lobe/pathology': 41,
#    'calcium/metabolism': 40,
#    'antimycin a/pharmacology': 1,
#    'republic of korea': 3,
#    'cognition': 78,
#    'pyramidal tracts/pathology': 1,
#    'cell nucleus/metabolism': 10,
#    'urine/chemistry': 1,
#    'vitamin d/analysis': 1,
#    'grape seed extract/administration & dosage': 1,
#    'trinucleotide repeat expansion/genetics': 1,
#    'psychotropic drugs/administration & dosage': 1,
#    'lewy body disease/etiology': 2,
#    'schizophrenia/epidemiology': 1,
#    'protein kinase c-epsilon/metabolism': 2,
#    'boston/epidemiology': 1,
#    'chemistry, pharmaceutical': 3,
#    'tnf receptor-associated factor 2/analysis': 1,
#    'diabetes mellitus, experimental/physiopathology': 2,
#    'focus groups/methods': 1,
#    'antigens, cd40/metabolism': 1,
#    'ubiquitin thiolesterase/metabolism': 1,
#    'apolipoproteins e/genetics': 108,
#    'apolipoproteins e/secretion': 1,
#    'growth hormone/therapeutic use': 1,
#    'spirochaetales/isolation & purification': 1,
#    'teaching': 1,
#    'temporal lobe/diagnostic imaging': 8,
#    'independent living/psychology': 1,
#    'trans fatty acids/metabolism': 1,
#    'recombinant fusion proteins/pharmacology': 1,
#    'sarcoplasmic reticulum calcium-transporting atpases/antagonists & inhibitors': 1,
#    'fatty acids, unsaturated/administration & dosage': 1,
#    'health promotion/organization & administration': 1,
#    'metabolomics/methods': 1,
#    'antigens, cd11/metabolism': 1,
#    'leucine/genetics': 3,
#    'intracranial arteriosclerosis/physiopathology': 3,
#    'injections, intralesional': 1,
#    'irritable mood/drug effects': 2,
#    'researcher-subject relations': 1,
#    'delirium/therapy': 2,
#    'microscopy, electron, scanning': 1,
#    'catalase/biosynthesis': 1,
#    'randomized controlled trials as topic/psychology': 1,
#    'mental recall': 28,
#    'adrenergic uptake inhibitors/therapeutic use': 2,
#    'vasoconstriction/physiology': 1,
#    'emergency service, hospital': 1,
#    'quercetin/pharmacology': 2,
#    'suramin/pharmacology': 1,
#    'cognition disorders/enzymology': 4,
#    'plasma membrane calcium-transporting atpases/antagonists & inhibitors': 1,
#    'health services needs and demand/statistics & numerical data': 1,
#    'threonine/metabolism': 5,
#    'odds ratio': 40,
#    'long-term care/trends': 1,
#    'intercellular signaling peptides and proteins/blood': 6,
#    'software': 10,
#    'orphan nuclear receptors/metabolism': 1,
#    'arabs': 1,
#    'personality assessment/statistics & numerical data': 3,
#    'pituitary gland/growth & development': 1,
#    'dementia/drug therapy': 27,
#    'dipeptidases/cerebrospinal fluid': 1,
#    'serotonin plasma membrane transport proteins/metabolism': 2,
#    'meningeal arteries/metabolism': 1,
#    'neuropeptides/administration & dosage': 1,
#    'endopeptidase k/metabolism': 1,
#    'recognition (psychology)/physiology': 21,
#    'patient participation': 3,
#    'hiv infections/enzymology': 1,
#    'continuity of patient care/statistics & numerical data': 1,
#    'gene expression regulation, enzymologic/genetics': 3,
#    'peptide hydrolases/chemistry': 1,
#    'geriatrics/trends': 2,
#    'thiazoles/blood': 1,
#    'hypercholesterolemia/etiology': 1,
#    'risk reduction behavior': 13,
#    'alleles': 63,
#    'dietary fats/administration & dosage': 1,
#    'immunoglobulin g/immunology': 2,
#    'neurosciences/ethics': 1,
#    'bradycardia/chemically induced': 1,
#    'th2 cells/transplantation': 1,
#    'amnesia/complications': 6,
#    'anilides/pharmacology': 2,
#    'heparitin sulfate/physiology': 1,
#    'attention deficit disorder with hyperactivity/metabolism': 1,
#    'insurance claim reporting/economics': 1,
#    'ibuprofen/pharmacokinetics': 1,
#    'drug hypersensitivity/etiology': 1,
#    'dopamine agents/administration & dosage': 1,
#    'fatty liver/epidemiology': 1,
#    'aquaporin 4/metabolism': 1,
#    'receptors, dopamine/genetics': 1,
#    'proteome/metabolism': 1,
#    'antigens/metabolism': 2,
#    'rural population': 3,
#    'asian americans/genetics': 1,
#    'albumins/analysis': 1,
#    'language disorders/diagnosis': 6,
#    'isoflurane/pharmacology': 1,
#    'tnf-related apoptosis-inducing ligand/blood': 1,
#    'gtp-binding protein alpha subunits, gi-go/metabolism': 1,
#    'occludin': 1,
#    'ferric compounds/pharmacokinetics': 1,
#    'mice, mutant strains': 5,
#    'biosensing techniques': 2,
#    'huntington disease/pathology': 5,
#    'gyrus cinguli/physiology': 1,
#    'psychotherapy, group/methods': 1,
#    'deoxyguanosine/analogs & derivatives': 5,
#    'tumor necrosis factor-alpha/genetics': 7,
#    'diabetes complications': 3,
#    'syntaxin 1/metabolism': 1,
#    'essential tremor/genetics': 1,
#    'affective symptoms/drug therapy': 1,
#    'dna-binding proteins/biosynthesis': 1,
#    'drug delivery systems/methods': 16,
#    'ethylene glycols/chemistry': 1,
#    'fluoresceins/chemistry': 2,
#    'golgi apparatus/metabolism': 2,
#    'memantine/adverse effects': 10,
#    'catechol o-methyltransferase/genetics': 1,
#    'microdialysis': 1,
#    'microscopy, confocal/methods': 1,
#    'phospholipids/isolation & purification': 1,
#    'microglia/pathology': 23,
#    'balneology': 1,
#    'hydrogen peroxide/chemistry': 1,
#    'surface plasmon resonance/methods': 4,
#    'lactams/chemical synthesis': 1,
#    'nerve net/pathology': 12,
#    'attention deficit disorder with hyperactivity/etiology': 2,
#    'peptides/immunology': 3,
#    'indans/therapeutic use': 58,
#    'cell nucleolus/pathology': 1,
#    'asthma/metabolism': 2,
#    'health status': 12,
#    'iron/toxicity': 2,
#    'extracellular matrix/metabolism': 2,
#    'encephalitis/surgery': 1,
#    'threonine/chemistry': 1,
#    'proteins/toxicity': 1,
#    'electron transport complex iv/analysis': 1,
#    'needs assessment': 6,
#    'depressive disorder, major/metabolism': 2,
#    'colony-forming units assay': 1,
#    'taurine/analogs & derivatives': 3,
#    'atrophy/genetics': 3,
#    'phytoestrogens/adverse effects': 1,
#    'nerve growth factors/genetics': 2,
#    'superoxide dismutase/analysis': 1,
#    'herpes simplex/drug therapy': 1,
#    'excitatory amino acid agonists/pharmacology': 3,
#    'hemostatics/pharmacology': 1,
#    'chemical precipitation': 1,
#    'ginsenosides/chemistry': 1,
#    'disclosure': 2,
#    'ppar gamma/metabolism': 5,
#    'dinoprostone/metabolism': 1,
#    'population surveillance/methods': 2,
#    'transgenes/physiology': 1,
#    'heparin/analogs & derivatives': 1,
#    "practice patterns, physicians'": 3,
#    'alzheimer vaccines/genetics': 1,
#    'cyclin-dependent kinase 4/metabolism': 1,
#    'copper/analysis': 2,
#    'nuclear family': 1,
#    'complement c1q/metabolism': 1,
#    'oral hygiene': 1,
#    'magnetic resonance angiography/methods': 1,
#    'antibodies, monoclonal/metabolism': 6,
#    'meningitis/cerebrospinal fluid': 1,
#    'vitamin k 2/analogs & derivatives': 1,
#    'cross-linking reagents/pharmacology': 1,
#    'biological transport/drug effects': 3,
#    'parietal lobe/chemistry': 1,
#    'maxillofacial injuries/complications': 1,
#    'map kinase signaling system': 1,
#    'constipation/complications': 1,
#    'multiple system atrophy/pathology': 1,
#    'genes, dominant': 3,
#    'n-acetylneuraminic acid/metabolism': 2,
#    'crohn disease/immunology': 1,
#    'antihypertensive agents/therapeutic use': 14,
#    'sodium selenite/pharmacology': 1,
#    'protein isoforms/toxicity': 2,
#    'immunohistochemistry/methods': 3,
#    'protein kinase c-alpha/physiology': 1,
#    'age distribution': 19,
#    'delusions/therapy': 1,
#    'neurons': 2,
#    'hospitalization': 6,
#    'microvessels/ultrastructure': 1,
#    'chromosomes, human, pair 8/genetics': 1,
#    'l-lactate dehydrogenase/drug effects': 1,
#    'angiogenesis inhibitors/antagonists & inhibitors': 1,
#    'infection/physiopathology': 1,
#    'nerve tissue proteins/agonists': 2,
#    'morpholines/pharmacology': 2,
#    'entorhinal cortex/chemistry': 1,
#    'magnetic resonance imaging': 201,
#    'escherichia coli proteins/genetics': 1,
#    'peptide fragments/antagonists & inhibitors': 22,
#    'scopolamine hydrobromide/antagonists & inhibitors': 2,
#    'memantine/therapeutic use': 36,
#    'densitometry/methods': 1,
#    'neurology': 3,
#    'bioethical issues': 2,
#    'tritium': 2,
#    'tumor necrosis factor-alpha/blood': 5,
#    'fluorodeoxyglucose f18/metabolism': 3,
#    'absorptiometry, photon/methods': 1,
#    'synaptic transmission/physiology': 13,
#    'cognitive dysfunction': 1,
#    'genomic instability/drug effects': 1,
#    'cyclic amp response element-binding protein/physiology': 1,
#    'hiv infections/metabolism': 2,
#    'glutathione reductase/metabolism': 2,
#    'golgi apparatus': 1,
#    'electrophoresis, polyacrylamide gel': 7,
#    'pain/drug therapy': 2,
#    'nerve degeneration/prevention & control': 10,
#    'antibodies, monoclonal/genetics': 1,
#    'dynamin i/metabolism': 1,
#    'computational biology': 5,
#    'receptor, serotonin, 5-ht1a/metabolism': 3,
#    'cognitive dysfunction/genetics': 2,
#    'paranoid disorders/drug therapy': 1,
#    'malnutrition/metabolism': 5,
#    'time factors': 134,
#    'homeodomain proteins/physiology': 1,
#    'chromans/pharmacology': 1,
#    'neurofibrillary tangles/enzymology': 2,
#    'receptors, muscarinic/metabolism': 3,
#    'neuroglia/pathology': 7,
#    'psychophysics': 1,
#    'nerve tissue proteins/blood': 1,
#    'mental recall/radiation effects': 1,
#    'folic acid deficiency/drug therapy': 1,
#    'mental status schedule/statistics & numerical data': 19,
#    'cathepsin b/metabolism': 1,
#    'imidazoles/chemical synthesis': 1,
#    'magnetoencephalography': 3,
#    'health surveys': 10,
#    'mosaicism': 1,
#    'fatty acids, unsaturated/chemistry': 1,
#    'macrophage activation/physiology': 1,
#    'darkness': 1,
#    'dose-response relationship, immunologic': 1,
#    'proteins/genetics': 3,
#    'glucose/chemistry': 1,
#    'homocysteine/metabolism': 8,
#    'species specificity': 16,
#    'atherosclerosis/etiology': 1,
#    'diabetes mellitus, experimental/metabolism': 1,
#    'dementia/epidemiology': 48,
#    'butyrylcholinesterase/chemistry': 3,
#    'parkinson disease/complications': 10,
#    'life change events': 3,
#    'biological assay/methods': 1,
#    'hypokinesia/etiology': 1,
#    'chromatography, micellar electrokinetic capillary/methods': 1,
#    'tetrazoles/administration & dosage': 1,
#    'quality assurance, health care/standards': 3,
#    'housing, animal': 3,
#    'aspirin/administration & dosage': 1,
#    'poverty/psychology': 1,
#    'mental disorders/classification': 2,
#    'tissue distribution/drug effects': 1,
#    'research support as topic/trends': 3,
#    'drugs, investigational/pharmacology': 2,
#    'optic nerve diseases/pathology': 1,
#    'sirtuins/metabolism': 2,
#    'hospitals, university': 2,
#    'exons/genetics': 7,
#    'smoking/pathology': 2,
#    'prostatic neoplasms/genetics': 1,
#    'protein kinase c/drug effects': 1,
#    'chromogranin a/toxicity': 1,
#    'ribosomal proteins/metabolism': 1,
#    'histidine/metabolism': 2,
#    'locus coeruleus/physiopathology': 1,
#    'cytokines/immunology': 2,
#    'risk assessment/statistics & numerical data': 1,
#    'toll-like receptors/physiology': 1,
#    'bacterial proteins/metabolism': 1,
#    'excitatory postsynaptic potentials/drug effects': 4,
#    'problem solving/physiology': 5,
#    'brain injuries/drug therapy': 3,
#    'diagnostic imaging/methods': 12,
#    'interferon-gamma/toxicity': 1,
#    'mutation': 110,
#    'geriatric psychiatry/education': 1,
#    ...}}}

# %%
def get_sorted(p_dict):
    return sorted(p_dict.items(), key=lambda x: x[1], reverse=True)

# %%
get_sorted(data[2003]['chemicals'])
# Out:
# [('a', 2649),
#  ('l', 1766),
#  ('b', 883),
#  ('t', 883),
#  ('n', 883),
#  (']', 883),
#  ('o', 883),
#  ('[', 883),
#  (' ', 883),
#  ('e', 883),
#  ('v', 883),
#  ('i', 883),
#  ('amyloid beta-peptides', 440),
#  ('amyloid beta-protein precursor', 205),
#  ('apolipoproteins e', 183),
#  ('cholinesterase inhibitors', 182),
#  ('peptide fragments', 177),
#  ('membrane proteins', 138),
#  ('tau proteins', 136),
#  ('amyloid beta-protein (1-42)', 91),
#  ('presenilin-1', 91),
#  ('amyloid precursor protein secretases', 85),
#  ('endopeptidases', 84),
#  ('aspartic acid endopeptidases', 84),
#  ('psen1 protein, human', 76),
#  ('biomarkers', 75),
#  ('bace1 protein, human', 70),
#  ('neuroprotective agents', 69),
#  ('indans', 68),
#  ('piperidines', 67),
#  ('nerve tissue proteins', 67),
#  ('apolipoprotein e4', 64),
#  ('donepezil', 63),
#  ('amyloid beta-protein (1-40)', 60),
#  ('rna, messenger', 53),
#  ('cholesterol', 51),
#  ('nootropic agents', 50),
#  ('anti-inflammatory agents, non-steroidal', 45),
#  ('antioxidants', 42),
#  ('memantine', 41),
#  ('enzyme inhibitors', 38),
#  ('carbamates', 37),
#  ('antipsychotic agents', 35),
#  ('radiopharmaceuticals', 34),
#  ('galantamine', 33),
#  ('phenylcarbamates', 32),
#  ('rivastigmine', 32),
#  ('presenilin-2', 31),
#  ('proteins', 30),
#  ('antibodies, monoclonal', 27),
#  ('peptides', 27),
#  ('estrogens', 27),
#  ('psen2 protein, human', 27),
#  ('synucleins', 26),
#  ('membrane glycoproteins', 26),
#  ('acetylcholinesterase', 26),
#  ('amyloid', 26),
#  ('excitatory amino acid antagonists', 25),
#  ('mitogen-activated protein kinases', 25),
#  ('carrier proteins', 24),
#  ('protein isoforms', 24),
#  ('glucose', 24),
#  ('homocysteine', 23),
#  ('recombinant proteins', 21),
#  ('receptors, n-methyl-d-aspartate', 20),
#  ('hydroxymethylglutaryl-coa reductase inhibitors', 20),
#  ('reactive oxygen species', 20),
#  ('antibodies', 20),
#  ('glutamic acid', 19),
#  ('acetylcholine', 19),
#  ('transcription factors', 19),
#  ('bace1 protein, mouse', 19),
#  ('fluorodeoxyglucose f18', 18),
#  ('thiazoles', 18),
#  ('plant extracts', 18),
#  ('copper', 18),
#  ('alpha-synuclein', 18),
#  ('isoenzymes', 17),
#  ('snca protein, human', 17),
#  ('glycogen synthase kinase 3', 17),
#  ('tumor necrosis factor-alpha', 16),
#  ('caspases', 16),
#  ('vitamin e', 16),
#  ('alzheimer vaccines', 16),
#  ('free radicals', 16),
#  ('choline o-acetyltransferase', 16),
#  ('interleukin-1', 16),
#  ('placebos', 16),
#  ('cyclooxygenase inhibitors', 15),
#  ('macromolecular substances', 15),
#  ('ligands', 15),
#  ('neurotransmitter agents', 14),
#  ('protein-serine-threonine kinases', 14),
#  ('iodine radioisotopes', 14),
#  ('prostaglandin-endoperoxide synthases', 14),
#  ('iron', 13),
#  ('dna', 13),
#  ('cyclooxygenase 2', 13),
#  ('cyclin-dependent kinases', 13),
#  ('anticholesteremic agents', 13),
#  ('cytokines', 12),
#  ('recombinant fusion proteins', 12),
#  ('insulin', 12),
#  ('psychotropic drugs', 12),
#  ('cysteine endopeptidases', 12),
#  ('intracellular signaling peptides and proteins', 12),
#  ('epitopes', 12),
#  ('zinc', 12),
#  ('dna-binding proteins', 12),
#  ('fluorescent dyes', 11),
#  ('ptgs2 protein, human', 11),
#  ('folic acid', 11),
#  ('nuclear proteins', 11),
#  ('jnk mitogen-activated protein kinases', 11),
#  ('membrane transport proteins', 11),
#  ('risperidone', 11),
#  ('receptors, notch', 11),
#  ('calcium', 11),
#  ('genetic markers', 11),
#  ('glial fibrillary acidic protein', 11),
#  ('aspartic acid', 11),
#  ('cyclooxygenase 2 inhibitors', 11),
#  ('nicastrin protein', 11),
#  ('serotonin uptake inhibitors', 10),
#  ('estradiol', 10),
#  ('nitric oxide', 10),
#  ('dopamine agents', 10),
#  ('ubiquitin', 10),
#  ('apolipoprotein e3', 10),
#  ('dna, complementary', 10),
#  ('serotonin', 10),
#  ('proto-oncogene proteins', 10),
#  ('serine', 10),
#  ('neprilysin', 10),
#  ('peptide hydrolases', 10),
#  ('multienzyme complexes', 10),
#  ('receptors, muscarinic', 10),
#  ('proteasome endopeptidase complex', 10),
#  ('nitric oxide synthase', 10),
#  ('luminescent proteins', 10),
#  ('receptors, nicotinic', 10),
#  ('nerve growth factors', 10),
#  ('benzodiazepines', 10),
#  ('neurofilament proteins', 9),
#  ('fatty acids, unsaturated', 9),
#  ('muscarinic agonists', 9),
#  ('chelating agents', 9),
#  ('thioflavin t', 9),
#  ('glycosylation end products, advanced', 9),
#  ('anti-inflammatory agents', 9),
#  ('amyloid beta-protein (25-35)', 9),
#  ('p38 mitogen-activated protein kinases', 9),
#  ('microtubule-associated proteins', 9),
#  ('protease inhibitors', 9),
#  ('melatonin', 9),
#  ('n-acetylaspartate', 9),
#  ('vitamin b 12', 9),
#  ('blood glucose', 8),
#  ('anticonvulsants', 8),
#  ('cyclin-dependent kinase 5', 8),
#  ('tacrine', 8),
#  ('neurotoxins', 8),
#  ('interleukin-6', 8),
#  ('aluminum', 8),
#  ('lipopolysaccharides', 8),
#  ('apolipoproteins', 8),
#  ('neuropeptides', 8),
#  ('prions', 8),
#  ('dopamine', 8),
#  ('glutathione', 8),
#  ('vaccines', 8),
#  ('green fluorescent proteins', 8),
#  ('fatty acids, omega-3', 8),
#  ('hydrogen peroxide', 8),
#  ('humanin', 8),
#  ('arginine', 8),
#  ('clioquinol', 7),
#  ('peptidylprolyl isomerase', 7),
#  ('bace2 protein, human', 7),
#  ('receptors, estrogen', 7),
#  ('lactones', 7),
#  ('adaptor proteins, signal transducing', 7),
#  ('lithium', 7),
#  ('butyrylcholinesterase', 7),
#  ('muscarinic antagonists', 7),
#  ('n-methylaspartate', 7),
#  ('trans-activators', 7),
#  ('dehydroepiandrosterone', 7),
#  ('transferrin', 7),
#  ('pirenzepine', 7),
#  ('immunoglobulin g', 7),
#  ('peptidyl-dipeptidase a', 7),
#  ('technetium tc 99m exametazime', 7),
#  ('dietary fats', 7),
#  ('rna', 7),
#  ('estrogen receptor alpha', 7),
#  ('insulysin', 7),
#  ('inositol', 7),
#  ('estrogens, conjugated (usp)', 7),
#  ('dna primers', 7),
#  ('autoantibodies', 7),
#  ('synaptophysin', 7),
#  ('heat-shock proteins', 7),
#  ('naproxen', 7),
#  ('drugs, chinese herbal', 7),
#  ('water', 7),
#  ('phosphatidylcholines', 7),
#  ('choline', 6),
#  ('testosterone', 6),
#  ('nima-interacting peptidylprolyl isomerase', 6),
#  ('rofecoxib', 6),
#  ('serotonin plasma membrane transport proteins', 6),
#  ('oligopeptides', 6),
#  ('ginkgo biloba extract', 6),
#  ('mitogen-activated protein kinase kinases', 6),
#  ('heme oxygenase (decyclizing)', 6),
#  ('receptor, muscarinic m1', 6),
#  ('pin1 protein, human', 6),
#  ('receptors, cytoplasmic and nuclear', 6),
#  ('molecular chaperones', 6),
#  ('phosphoproteins', 6),
#  ('metalloendopeptidases', 6),
#  ('steroid hydroxylases', 6),
#  ('aspirin', 6),
#  ('threonine', 6),
#  ('cholesterol, ldl', 6),
#  ('selegiline', 6),
#  ('fatty acids', 6),
#  ('24-hydroxycholesterol', 6),
#  ('4-hydroxy-2-nonenal', 6),
#  ('protein kinase c', 6),
#  ('sulfones', 6),
#  ('superoxide dismutase', 6),
#  ('aldehydes', 6),
#  ('flavonoids', 6),
#  ('receptors, serotonin', 6),
#  ('cysteine', 6),
#  ('protein subunits', 6),
#  ('hydroxycholesterols', 6),
#  ('culture media, conditioned', 6),
#  ('polymers', 6),
#  ('electron transport complex iv', 5),
#  ('codon', 5),
#  ('plant preparations', 5),
#  ('apolipoprotein e2', 5),
#  ('serine endopeptidases', 5),
#  ('calcium-binding proteins', 5),
#  ('olanzapine', 5),
#  ('tritium', 5),
#  ('nerve growth factor', 5),
#  ('lipoproteins', 5),
#  ('phosphoprotein phosphatases', 5),
#  ('alkaloids', 5),
#  ('phosphotransferases', 5),
#  ('wnt proteins', 5),
#  ('acetylcarnitine', 5),
#  ('lovastatin', 5),
#  ('cdk5 protein, human', 5),
#  ('sth protein, human', 5),
#  ('norepinephrine', 5),
#  ('caspase 3', 5),
#  ('methionine', 5),
#  ('protein precursors', 5),
#  ('cholesterol 24-hydroxylase', 5),
#  ('tyrosine', 5),
#  ('glycosaminoglycans', 5),
#  ('cytoskeletal proteins', 5),
#  ('glycogen synthase kinase 3 beta', 5),
#  ('antihypertensive agents', 5),
#  ('nicotinic agonists', 5),
#  ('alpha-macroglobulins', 5),
#  ('alanine', 5),
#  ('amino acids', 5),
#  ('calcium channels', 5),
#  ('transforming growth factor beta', 5),
#  ('glutamine', 4),
#  ('cysteine proteinase inhibitors', 4),
#  ('hypolipidemic agents', 4),
#  ('glycoproteins', 4),
#  ('phosphatidylinositol 3-kinases', 4),
#  ('an-1792', 4),
#  ('cyclooxygenase 1', 4),
#  ('cholinergic antagonists', 4),
#  ('receptor, nerve growth factor', 4),
#  ('nf-kappa b', 4),
#  ('cell adhesion molecules, neuronal', 4),
#  ('ubiquitins', 4),
#  ('gtp phosphohydrolases', 4),
#  ('heparin', 4),
#  ('cell cycle proteins', 4),
#  ('hydrocortisone', 4),
#  ('aph1a protein, human', 4),
#  ('psenen protein, human', 4),
#  ('chrna7 protein, human', 4),
#  ('ion channels', 4),
#  ('proto-oncogene proteins c-akt', 4),
#  ('apolipoproteins d', 4),
#  ('ibuprofen', 4),
#  ('gsk3b protein, human', 4),
#  ('free radical scavengers', 4),
#  ('luciferases', 4),
#  ('triglycerides', 4),
#  ('tissue extracts', 4),
#  ('sphingomyelins', 4),
#  ('adrenergic beta-antagonists', 4),
#  ('peptide library', 4),
#  ('cholesterol, hdl', 4),
#  ('arachidonic acid', 4),
#  ('lipids', 4),
#  ('antidepressive agents', 4),
#  ('gamma-aminobutyric acid', 4),
#  ('reelin protein', 4),
#  ('simvastatin', 4),
#  ('drugs, investigational', 4),
#  ('alpha7 nicotinic acetylcholine receptor', 4),
#  ('sulfonamides', 4),
#  ('gtp-binding proteins', 4),
#  ('plasminogen', 4),
#  ('monoamine oxidase', 4),
#  ("3' untranslated regions", 4),
#  ('docosahexaenoic acids', 4),
#  ('brain-derived neurotrophic factor', 4),
#  ('zebrafish proteins', 4),
#  ('cyclins', 4),
#  ('vitamins', 4),
#  ('ascorbic acid', 4),
#  ('tryptophan', 4),
#  ('thioctic acid', 4),
#  ('chemokine ccl2', 4),
#  ('phosphopyruvate hydratase', 4),
#  ('receptors, glutamate', 4),
#  ('extracellular matrix proteins', 4),
#  ('metals', 4),
#  ('ptgs1 protein, human', 4),
#  ('adam proteins', 4),
#  ('receptors, nerve growth factor', 4),
#  ('vitamin b 6', 4),
#  ('leucine', 4),
#  ('receptors, gaba-a', 4),
#  ('eicosapentaenoic acid', 3),
#  ('heparan sulfate proteoglycans', 3),
#  ('progestins', 3),
#  ('polyglutamine', 3),
#  ('aplp1 protein, human', 3),
#  ('phosphothreonine', 3),
#  ('tau-protein kinase', 3),
#  ('proline', 3),
#  ('hypnotics and sedatives', 3),
#  ('receptors, serotonin, 5-ht4', 3),
#  ('interferon-gamma', 3),
#  ('quinuclidinyl benzilate', 3),
#  ('angiogenesis inhibitors', 3),
#  ('physostigmine', 3),
#  ('cst3 protein, human', 3),
#  ('intercellular adhesion molecule-1', 3),
#  ('superoxides', 3),
#  ('monoamine oxidase inhibitors', 3),
#  ('phospholipids', 3),
#  ('dipeptides', 3),
#  ('cholinergic agents', 3),
#  ('glucocorticoids', 3),
#  ('antisense elements (genetics)', 3),
#  ('cations, divalent', 3),
#  ('nitrates', 3),
#  ('cyclic amp response element-binding protein', 3),
#  ('glyceraldehyde-3-phosphate dehydrogenases', 3),
#  ('cerebrolysin', 3),
#  ('casp9 protein, human', 3),
#  ('scopolamine hydrobromide', 3),
#  ('pyrazoles', 3),
#  ('mitogen-activated protein kinase 1', 3),
#  ('peroxidase', 3),
#  ('valproic acid', 3),
#  ('kainic acid', 3),
#  ('adrenal cortex hormones', 3),
#  ('nad', 3),
#  ('dinoprostone', 3),
#  ('alpha 1-antichymotrypsin', 3),
#  ('ceramides', 3),
#  ('cystatins', 3),
#  ('rab5 gtp-binding proteins', 3),
#  ('protein phosphatase 2', 3),
#  ('transforming growth factor beta1', 3),
#  ('deferoxamine', 3),
#  ('pravastatin', 3),
#  ('medroxyprogesterone acetate', 3),
#  ('calpain', 3),
#  ('slc6a4 protein, human', 3),
#  ('antiparkinson agents', 3),
#  ('receptors, dopamine d2', 3),
#  ('acetates', 3),
#  ('huperzine a', 3),
#  ('s100 calcium binding protein beta subunit', 3),
#  ('receptors, cholinergic', 3),
#  ('tubulin', 3),
#  ('apoptosis regulatory proteins', 3),
#  ('slc6a4 protein, rat', 3),
#  ('tgfb1 protein, human', 3),
#  ('slc6a4 protein, mouse', 3),
#  ('adenosine triphosphate', 3),
#  ('potassium channels', 3),
#  ('pyridines', 3),
#  ('estrogen receptor beta', 3),
#  ('nadph oxidase', 3),
#  ('excitatory amino acid agonists', 3),
#  ('map kinase kinase 4', 3),
#  ('mitogen-activated protein kinase 3', 3),
#  ('vinca alkaloids', 3),
#  ('map kinase kinase kinases', 3),
#  ('creatine', 3),
#  ('nicotine', 3),
#  ('carbon isotopes', 3),
#  ('indoles', 3),
#  ('cdk5 protein, mouse', 3),
#  ('kinesin', 3),
#  ('dna, mitochondrial', 3),
#  ('fibroblast growth factor 2', 3),
#  ('alpha-sapp protein, human', 3),
#  ('tropanes', 3),
#  ('lipid bilayers', 3),
#  ('quercetin', 3),
#  ('protons', 3),
#  ('akt1 protein, human', 3),
#  ('receptor, serotonin, 5-ht2a', 3),
#  ('adam17 protein', 3),
#  ('adam17 protein, human', 3),
#  ('cathepsin d', 3),
#  ('organotechnetium compounds', 3),
#  ('phospholipases a2', 3),
#  ('progesterone congeners', 3),
#  ('vinpocetine', 3),
#  ('dopamine antagonists', 3),
#  ('poly(adp-ribose) polymerases', 3),
#  ('ceruloplasmin', 3),
#  ('nitriles', 3),
#  ('cystatin c', 3),
#  ('repressor proteins', 3),
#  ('cadherins', 3),
#  ('phosphatidylserines', 3),
#  ('hormones', 3),
#  ('dopamine plasma membrane transport proteins', 3),
#  ('autoantigens', 3),
#  ('caspase 9', 3),
#  ('sulfoglycosphingolipids', 3),
#  ('tumor suppressor protein p53', 3),
#  ('muscle proteins', 3),
#  ('tumor suppressor proteins', 3),
#  ('glutathione transferase', 3),
#  ('nitric oxide synthase type iii', 3),
#  ('phf-1 monoclonal antibody', 3),
#  ('lysine', 3),
#  ('1-methyl-4-phenyl-1,2,3,6-tetrahydropyridine', 3),
#  ('drosophila proteins', 3),
#  ('nos3 protein, human', 3),
#  ('oxidants', 3),
#  ('s100 proteins', 3),
#  ('vitamin a', 3),
#  ('serum amyloid p-component', 3),
#  ('congo red', 3),
#  ('(n-propargyl-(3r) aminoindan-5-yl)-ethyl methyl carbamate', 3),
#  ('phospholipases a', 3),
#  ('2-carbomethoxy-8-(3-fluoropropyl)-3-(4-iodophenyl)tropane', 3),
#  ('casp3 protein, human', 3),
#  ('interleukin-10', 3),
#  ('phosphatidylinositols', 3),
#  ('sex hormone-binding globulin', 3),
#  ('telomerase', 3),
#  ('acetylcysteine', 3),
#  ('antigens, cd95', 3),
#  ('tissue plasminogen activator', 3),
#  ('sesquiterpenes', 3),
#  ('yellow fluorescent protein, bacteria', 2),
#  ('triazoles', 2),
#  ('detergents', 2),
#  ('fatty acids, essential', 2),
#  ('faslg protein, human', 2),
#  ('abca1 protein, human', 2),
#  ('dna, viral', 2),
#  ('stilbenes', 2),
#  ('bacterial proteins', 2),
#  ('iofetamine', 2),
#  ('aconitine', 2),
#  ('cytochrome p-450 enzyme system', 2),
#  ('somatostatin', 2),
#  ('aripiprazole', 2),
#  ('complement c1q', 2),
#  ('excitatory amino acid agents', 2),
#  ('polyethylene glycols', 2),
#  ('codon, nonsense', 2),
#  ('ras proteins', 2),
#  ('dinoprost', 2),
#  ('rho gtp-binding proteins', 2),
#  ('hypoxia-inducible factor 1, alpha subunit', 2),
#  ('protein kinase inhibitors', 2),
#  ('von willebrand factor', 2),
#  ('prostaglandins', 2),
#  ('urokinase-type plasminogen activator', 2),
#  ('receptors, ldl', 2),
#  ('amyloid beta-protein (35-25)', 2),
#  ('amyloid beta-protein (10-43)', 2),
#  ('pon1 protein, human', 2),
#  ('cerebrospinal fluid proteins', 2),
#  ('rna splice sites', 2),
#  ('eif-2 kinase', 2),
#  ('hypoxia-inducible factor 1', 2),
#  ('creatinine', 2),
#  ('synaptotagmins', 2),
#  ('immunoglobulins', 2),
#  ('immunoglobulin fragments', 2),
#  ('proto-oncogene proteins c-bcl-2', 2),
#  ('quinolones', 2),
#  ('haloperidol', 2),
#  ('acetaminophen', 2),
#  ('furans', 2),
#  ('nitric oxide synthase type ii', 2),
#  ('acrolein', 2),
#  ('phosphatidylethanolamines', 2),
#  ('thiolester hydrolases', 2),
#  ('thymine', 2),
#  ('coloring agents', 2),
#  ('gap-43 protein', 2),
#  ('2-(2-amino-3-methoxyphenyl)-4h-1-benzopyran-4-one', 2),
#  ('afdx 384', 2),
#  ('carbon radioisotopes', 2),
#  ('tfcp2 protein, human', 2),
#  ('antigens, cd', 2),
#  ('receptors, neuropeptide', 2),
#  ('rna-binding proteins', 2),
#  ('prion proteins', 2),
#  ('antidepressive agents, second-generation', 2),
#  ('3-nitrotyrosine', 2),
#  ('beta-d-galactoside alpha 2-6-sialyltransferase', 2),
#  ('receptors, transferrin', 2),
#  ('dietary carbohydrates', 2),
#  ('neuronal cdk5 activator (p25-p35)', 2),
#  ('synaptotagmin i', 2),
#  ('src-family kinases', 2),
#  ('protein kinases', 2),
#  ('amines', 2),
#  ('prnp protein, human', 2),
#  ('vaccines, synthetic', 2),
#  ('proteoglycans', 2),
#  ('galanin', 2),
#  ('drug combinations', 2),
#  ('liposomes', 2),
#  ('caspase 8', 2),
#  ('methyllycaconitine', 2),
#  ('membranes, artificial', 2),
#  ('advanced glycosylation end product-specific receptor', 2),
#  ('esterases', 2),
#  ('chromosomal proteins, non-histone', 2),
#  ('triterpenes', 2),
#  ('ferritins', 2),
#  ('photoaffinity labels', 2),
#  ('cocaine', 2),
#  ('c-reactive protein', 2),
#  ('carbachol', 2),
#  ('thiazolyl blue', 2),
#  ('hemochromatosis protein', 2),
#  ('lithium compounds', 2),
#  ('flotillins', 2),
#  ('quetiapine fumarate', 2),
#  ('cyclin-dependent kinase inhibitor p27', 2),
#  ('androgens', 2),
#  ('calcium channel blockers', 2),
#  ('calcium-calmodulin-dependent protein kinases', 2),
#  ('lipoproteins, ldl', 2),
#  ('piperazines', 2),
#  ('phenylhydrazines', 2),
#  ('dehydroepiandrosterone sulfate', 2),
#  ('radioisotopes', 2),
#  ('serotonin receptor agonists', 2),
#  ('amides', 2),
#  ('celecoxib', 2),
#  ('formic acid', 2),
#  ('anti-bacterial agents', 2),
#  ('ribosomal protein s6 kinases, 70-kda', 2),
#  ('prealbumin', 2),
#  ('aniline compounds', 2),
#  ('hif1a protein, rat', 2),
#  ('dna transposable elements', 2),
#  ('iron chelating agents', 2),
#  ('nicotinic antagonists', 2),
#  ('rna, small interfering', 2),
#  ('fish oils', 2),
#  ('g(m1) ganglioside', 2),
#  ('paroxetine', 2),
#  ('dibenzothiazepines', 2),
#  ('ubiquinone', 2),
#  ('endoribonucleases', 2),
#  ('piracetam', 2),
#  ('chromogranin a', 2),
#  ('integrins', 2),
#  ('3-iodobenzylguanidine', 2),
#  ('luteinizing hormone', 2),
#  ('proteome', 2),
#  ('f2-isoprostanes', 2),
#  ('complement system proteins', 2),
#  ('lectins', 2),
#  ('culture media, serum-free', 2),
#  ('proto-oncogene proteins c-sis', 2),
#  ('gonadotropins', 2),
#  ('map kinase kinase 1', 2),
#  ('histones', 2),
#  ('dental amalgam', 2),
#  ('map kinase kinase kinase 5', 2),
#  ('culture media', 2),
#  ('xanthines', 2),
#  ('staurosporine', 2),
#  ('bace protein, rat', 2),
#  ('casp8 protein, human', 2),
#  ('tyrosine 3-monooxygenase', 2),
#  ('plasmalogens', 2),
#  ('map3k5 protein, mouse', 2),
#  ('carotenoids', 2),
#  ('phenols', 2),
#  ("alzheimer's disease antigen", 2),
#  ('potassium chloride', 2),
#  ('antigen-antibody complex', 2),
#  ('chemokines', 2),
#  ('transcobalamins', 2),
#  ('mannosidases', 2),
#  ('dietary fats, unsaturated', 2),
#  ('membrane lipids', 2),
#  ('peroxynitrous acid', 2),
#  ('chromogranins', 2),
#  ('angiotensin-converting enzyme inhibitors', 2),
#  ("2-(4'-dimethylaminophenyl)-6-iodobenzothiazole", 2),
#  ('tropicamide', 2),
#  ('8,12-iso-isoprostane f2alpha-vi', 2),
#  ('cross-linking reagents', 2),
#  ('mevalonic acid', 2),
#  ('ganstigmine', 2),
#  ('cathepsins', 2),
#  ('hydroxymethylglutaryl coa reductases', 2),
#  ('inflammation mediators', 2),
#  ('heterotrimeric gtp-binding proteins', 2),
#  ('glycine', 2),
#  ('imidazoles', 2),
#  ('receptor, epidermal growth factor', 2),
#  ('intercellular signaling peptides and proteins', 2),
#  ('pyruvate dehydrogenase complex', 2),
#  ('oxides', 2),
#  ('thiazolidinediones', 2),
#  ('receptors, immunologic', 2),
#  ('quinolinic acid', 2),
#  ('alkaline phosphatase', 2),
#  ('sterol o-acyltransferase', 2),
#  ('neoplasm proteins', 2),
#  ('raclopride', 2),
#  ('type c phospholipases', 2),
#  ('albumins', 2),
#  ('neuregulin-1', 2),
#  ('oxygen', 2),
#  ('heme oxygenase-1', 2),
#  ('filipin', 2),
#  ('formates', 2),
#  ('serum amyloid a protein', 2),
#  ('cation transport proteins', 2),
#  ('prpc proteins', 2),
#  ('bradykinin', 2),
#  ('okadaic acid', 2),
#  ('macrophage-1 antigen', 2),
#  ('receptors, ampa', 2),
#  ('methylenetetrahydrofolate reductase (nadph2)', 2),
#  ('hmga1a protein', 2),
#  ('ctnnb1 protein, human', 2),
#  ('benzylamines', 2),
#  ('metallothionein', 2),
#  ('cytotoxins', 2),
#  ('ldl-receptor related proteins', 2),
#  ('dextrans', 2),
#  ('stearoyl-coa desaturase', 2),
#  ('cholinergic agonists', 2),
#  ('antithrombin iii', 2),
#  ('phosphoserine', 2),
#  ("5' untranslated regions", 2),
#  ('anti-anxiety agents', 2),
#  ('hmox1 protein, human', 2),
#  ('nicotinic acetylcholine receptor alpha4 subunit', 2),
#  ('quaternary ammonium compounds', 2),
#  ('receptors, dopamine', 2),
#  ('oximes', 2),
#  ('graphite', 2),
#  ('sialyltransferases', 2),
#  ('cholesterol, dietary', 2),
#  ('thiophenes', 2),
#  ('lorazepam', 2),
#  ('aryldialkylphosphatase', 2),
#  ('chloramphenicol o-acetyltransferase', 2),
#  ('blood proteins', 2),
#  ('isoprostanes', 2),
#  ('histocompatibility antigens class i', 2),
#  ('u 0126', 2),
#  ('carnosine', 2),
#  ('caffeine', 2),
#  ('valine', 2),
#  ('microfilament proteins', 2),
#  ('low density lipoprotein receptor-related protein-1', 2),
#  ('hfe protein, human', 2),
#  ('progesterone', 2),
#  ('mixed function oxygenases', 2),
#  ('prostate apoptosis response-4 protein', 2),
#  ('receptor, trka', 2),
#  ('tetrazolium salts', 2),
#  ('fluoxetine', 2),
#  ('hif1a protein, human', 2),
#  ('2,4-dinitrophenylhydrazine', 2),
#  ('ligases', 2),
#  ('atp binding cassette transporter 1', 2),
#  ('receptors, complement', 2),
#  ('bcl-2-associated x protein', 2),
#  ('genistein', 2),
#  ('quinuclidines', 2),
#  ('beta catenin', 2),
#  ('fibrinolysin', 2),
#  ('citalopram', 2),
#  ('carbamazepine', 2),
#  ("6-iodo-2-(4'-dimethylamino-)phenyl-imidazo(1,2-a)pyridine", 2),
#  ('glycogen synthase kinase 3 alpha', 2),
#  ('peroxides', 2),
#  ('oligosaccharides', 2),
#  ('antigens, cd3', 2),
#  ('central nervous system agents', 2),
#  ('technetium tc 99m bicisate', 2),
#  ('thyrotropin', 2),
#  ('fatty acids, omega-6', 2),
#  ('cholinesterases', 2),
#  ('casp3 protein, mouse', 2),
#  ('rac gtp-binding proteins', 2),
#  ('nedd8 protein, human', 2),
#  ('solutions', 2),
#  ('l-lactate dehydrogenase', 2),
#  ('antigens', 2),
#  ('ethanol', 2),
#  ('tretinoin', 2),
#  ('map3k5 protein, human', 2),
#  ('receptors, chemokine', 2),
#  ('butadienes', 2),
#  ('alpha-tocopherol', 2),
#  ('niacin', 2),
#  ('ferrosoferric oxide', 2),
#  ('fas ligand protein', 2),
#  ('mapk8ip1 protein, human', 2),
#  ('vitamin b complex', 2),
#  ('thrombin', 2),
#  ('adjuvants, immunologic', 2),
#  ('cyclic amp', 2),
#  ('ctsl protein, rat', 1),
#  ('atf6 protein, human', 1),
#  ('calmodulin', 1),
#  ('cflar protein, mouse', 1),
#  ('solvents', 1),
#  ('ribonucleoproteins', 1),
#  ('morpholines', 1),
#  ('dihydro-beta-erythroidine', 1),
#  ('antigens, cd45', 1),
#  ('glycerylphosphorylcholine', 1),
#  ('adaptor proteins, vesicular transport', 1),
#  ('17-hydroxysteroid dehydrogenases', 1),
#  ('nefiracetam', 1),
#  ('chromatin assembly factor-1', 1),
#  ('adenine', 1),
#  ('immunoglobulins, thyroid-stimulating', 1),
#  ('sod1 protein, human', 1),
#  ('hsd11b1 protein, human', 1),
#  ('ap 2238', 1),
#  ("guanosine 5'-o-(3-thiotriphosphate)", 1),
#  ('ctsl protein, mouse', 1),
#  ('potassium channel blockers', 1),
#  ('peroxiredoxins', 1),
#  ('eicosanoic acids', 1),
#  ('glucagon', 1),
#  ('srsf2 protein, human', 1),
#  ('crebbp protein, human', 1),
#  ('ctnna3 protein, human', 1),
#  ('antifungal agents', 1),
#  ('complement c6', 1),
#  ('wnt3a protein', 1),
#  ('trpm2 protein, human', 1),
#  ('protein synthesis inhibitors', 1),
#  ('carbon dioxide', 1),
#  ('dexamethasone', 1),
#  ('micelles', 1),
#  ('cationic amino acid transporter 1', 1),
#  ('per3 protein, human', 1),
#  ('gtp gamma-4-azidoanilide', 1),
#  ('maprotiline', 1),
#  ('colostrinine', 1),
#  ('amyloid beta-protein (1-15)', 1),
#  ('nf-kappa b p50 subunit', 1),
#  ('phospholipase d', 1),
#  ('amyloid beta-protein precursor 770 (301-323)', 1),
#  ('lymphokines', 1),
#  ('furin', 1),
#  ('paxillin', 1),
#  ('benzopyrans', 1),
#  ('endothelin-1', 1),
#  ('elk1 protein, human', 1),
#  ('sphingolipids', 1),
#  ('gtp-binding protein regulators', 1),
#  ('serum albumin', 1),
#  ('nadolol', 1),
#  ('14-3-3 proteins', 1),
#  ('food additives', 1),
#  ('insulin-like growth factor binding protein 3', 1),
#  ('epinephrine', 1),
#  ('glycoconjugates', 1),
#  ('acetylglucosamine', 1),
#  ('aif1 protein, rat', 1),
#  ('3-hydroxy-3-methylglutaryl-coenzyme a', 1),
#  ('pulmonary surfactants', 1),
#  ('ctgf protein, human', 1),
#  ('pde7a protein, human', 1),
#  ('n-(2-cyclohexyloxy-4-nitrophenyl)methanesulfonamide', 1),
#  ('ptpn12 protein, rat', 1),
#  ('mipa compound', 1),
#  ('cyp7b1 protein, mouse', 1),
#  ('p2rx7 protein, rat', 1),
#  ('receptors, serotonin, 5-ht2', 1),
#  ('estrone', 1),
#  ('thyroid hormones', 1),
#  ('plaur protein, human', 1),
#  ('octanols', 1),
#  ('benzoquinones', 1),
#  ('cevimeline', 1),
#  ('hydroxyindoleacetic acid', 1),
#  ('rna, catalytic', 1),
#  ('ece1 protein, mouse', 1),
#  ('glucuronyl glucosamine glycan sulfate', 1),
#  ('mecamylamine', 1),
#  ('bh3 interacting domain death agonist protein', 1),
#  ('receptors, purinergic p2x7', 1),
#  ('cholera toxin', 1),
#  ('alpha catenin', 1),
#  ('dolichol', 1),
#  ('meclofenamic acid', 1),
#  ('pxn protein, rat', 1),
#  ('neural cell adhesion molecules', 1),
#  ('fatty acid-binding proteins', 1),
#  ('dithiothreitol', 1),
#  ('receptors, igg', 1),
#  ('serotonin antagonists', 1),
#  ('etv1 protein, human', 1),
#  ('thromboxanes', 1),
#  ('gadolinium dtpa', 1),
#  ('erbb4 protein, mouse', 1),
#  ('gels', 1),
#  ('hemoglobin a, glycosylated', 1),
#  ('immediate-early proteins', 1),
#  ('6,6-dimethyl-3-(2-hydroxyethyl)thio-1-(thiazol-2-yl)-6,7-dihydro-2-benzothiophen-4(5h)-one',
#   1),
#  ('polystyrenes', 1),
#  ('alpha-onocerin', 1),
#  ('receptors, galanin', 1),
#  ('propanols', 1),
#  ('calcineurin', 1),
#  ('fabp5 protein, human', 1),
#  ('melanins', 1),
#  ('matrix metalloproteinase 2', 1),
#  ('wnt3 protein', 1),
#  ('fatty acids, monounsaturated', 1),
#  ('tissue inhibitor of metalloproteinase-2', 1),
#  ('tacrolimus binding proteins', 1),
#  ('angiotensin ii', 1),
#  ('vacuolar proton-translocating atpases', 1),
#  ('myricetin', 1),
#  ('environmental pollutants', 1),
#  ('fumarates', 1),
#  ('3-quinuclidinyl-4-iodobenzilate', 1),
#  ('lactic acid', 1),
#  ('p2rx7 protein, mouse', 1),
#  ('reg1a protein, human', 1),
#  ('fructose-bisphosphatase', 1),
#  ('enzyme activators', 1),
#  ('follicle stimulating hormone', 1),
#  ('drug carriers', 1),
#  ('apba1 protein, mouse', 1),
#  ('fasl protein, mouse', 1),
#  ('c21orf2 protein, human', 1),
#  ('glucagon-like peptide 1', 1),
#  ('proto-oncogene proteins c-jun', 1),
#  ('27-hydroxycholesterol', 1),
#  ('1-iodo-2,5-bis-(3-hydroxycarbonyl-4-methoxy)styryl-benzene', 1),
#  ('bacterial outer membrane proteins', 1),
#  ('antigens, cd13', 1),
#  ('ece2 protein, mouse', 1),
#  ('ginkgolide b', 1),
#  ('vasopressins', 1),
#  ('basic helix-loop-helix transcription factors', 1),
#  ('tnfsf6 protein, rat', 1),
#  ('protein o-methyltransferase', 1),
#  ('fura-2-am', 1),
#  ('receptor, adenosine a2a', 1),
#  ('neurofilament protein l', 1),
#  ('radioactive tracers', 1),
#  ('trypsin', 1),
#  ('bleomycin hydrolase', 1),
#  ('lead', 1),
#  ('receptors, presynaptic', 1),
#  ('complement c5', 1),
#  ('protein kinase c-alpha', 1),
#  ('amphotericin b', 1),
#  ('e2f transcription factors', 1),
#  ('chromogenic compounds', 1),
#  ('proto-oncogene proteins c-fos', 1),
#  ('baysilon', 1),
#  ('phosphatidylglycerols', 1),
#  ('gtp-binding protein alpha subunits, gs', 1),
#  ('alpha-linolenic acid', 1),
#  ('trazodone', 1),
#  ('rhodamines', 1),
#  ('fabp7 protein, human', 1),
#  ('pyrrolidinones', 1),
#  ('biogenic amines', 1),
#  ('fatty-acid amide hydrolase', 1),
#  ('dextropropoxyphene', 1),
#  ('protein sorting signals', 1),
#  ('indicators and reagents', 1),
#  ('mannose', 1),
#  ('fatty acid desaturases', 1),
#  ('trimethyloxamine', 1),
#  ('sulfur', 1),
#  ('naphthalenesulfonates', 1),
#  ('ammonium sulfate', 1),
#  ('cyclohexanecarboxylic acids', 1),
#  ('probucol', 1),
#  ('wnt3a protein, mouse', 1),
#  ('anions', 1),
#  ('anemoside a3', 1),
#  ('tgfb1 protein, mouse', 1),
#  ('growth inhibitory factor', 1),
#  ('receptor, muscarinic m2', 1),
#  ('integrin alpha4beta1', 1),
#  ('dna-(apurinic or apyrimidinic site) lyase', 1),
#  ('brain-derived neurotrophic factor precursor', 1),
#  ('p2rx7 protein, human', 1),
#  ('contrast media', 1),
#  ('gtp-binding protein alpha subunits, gi-go', 1),
#  ('amyloid beta-protein (12-28)', 1),
#  ('col25a1 protein, human', 1),
#  ('analgesics, non-narcotic', 1),
#  ('n-(1-methyl-2-phenylethyl)adenosine', 1),
#  ('map kinase kinase 2', 1),
#  ('nicotinic receptor subunit alpha3', 1),
#  ('pulsatilloside a', 1),
#  ('antigens, nuclear', 1),
#  ('alkenes', 1),
#  ('ubiquitin thiolesterase', 1),
#  ('mark4 protein, human', 1),
#  ('pyrazolanthrone', 1),
#  ('salivary proteins and peptides', 1),
#  ('analgesics, opioid', 1),
#  ('tat-dota', 1),
#  ('neopterin', 1),
#  ('retinoblastoma protein', 1),
#  ('immunoglobulin variable region', 1),
#  ('dab1 protein, mouse', 1),
#  ('glutamate receptor ionotropic, ampa 2', 1),
#  ('plasminogen activator inhibitor 1', 1),
#  ('glutathione peroxidase', 1),
#  ('edrophonium', 1),
#  ('fatty acid-binding protein 7', 1),
#  ('cyclopentanes', 1),
#  ('apigenin', 1),
#  ('capsid proteins', 1),
#  ('metalloproteases', 1),
#  ('receptors, cell surface', 1),
#  ('androstenediol', 1),
#  ('propentofylline', 1),
#  ('collagen type i', 1),
#  ('complement c1r', 1),
#  ('proprotein convertases', 1),
#  ('perk kinase', 1),
#  ('vascular cell adhesion molecule-1', 1),
#  ('wiskott-aldrich syndrome protein family', 1),
#  ('ern2 protein, human', 1),
#  ('peroxiredoxin vi', 1),
#  ('cytochrome p-450 cyp2d6', 1),
#  ('ctnnb1 protein, mouse', 1),
#  ('surface-active agents', 1),
#  ('1,3-dipropyl-8-cyclopentylxanthine', 1),
#  ('amebicides', 1),
#  ('adenylyl cyclases', 1),
#  ('fibrin fibrinogen degradation products', 1),
#  ('fluoresceins', 1),
#  ('sodium channels', 1),
#  ('rs 1178', 1),
#  ('nckipsd protein, human', 1),
#  ('acid rain', 1),
#  ('complement c3', 1),
#  ('mitochondrial proton-translocating atpases', 1),
#  ('methionine adenosyltransferase', 1),
#  ('e2f1 transcription factor', 1),
#  ('aplp2 protein, human', 1),
#  ('chaf1b protein, human', 1),
#  ('fluorine radioisotopes', 1),
#  ('proliferating cell nuclear antigen', 1),
#  ('cflar protein, human', 1),
#  ('app protein, human', 1),
#  ('hexosaminidases', 1),
#  ...]

# %%
data_umls = UMLS()

print(data_umls.getST())
print(data_umls.tgt.split('/')[-1])
# Out:
# ST-2449248-9MBklLIB7AdLMulMIpEy-cas
# TGT-1008454-keND7cN9krcD45QJg4kuACxvpGosWDk4QcMFqcAXXTctomz31R-cas

# %%
data[2006]
# Out:
# {'chemicals': {'tetralones': 1,
#   'toll-like receptors': 1,
#   'guanine': 1,
#   'aqp1 protein, human': 1,
#   'escherichia coli proteins': 1,
#   'tramiprosate': 2,
#   'rho-associated kinases': 3,
#   'solvents': 4,
#   'estrogens': 25,
#   'alanine transaminase': 1,
#   'yellow fluorescent protein, bacteria': 1,
#   'triazoles': 1,
#   'colec12 protein, human': 1,
#   'detergents': 2,
#   'calnexin': 2,
#   'morpholines': 1,
#   'polyglutamine': 3,
#   'mitochondrial permeability transition pore': 1,
#   'abca1 protein, human': 3,
#   'neuroprotective agents': 105,
#   'metabotropic glutamate receptor 2': 1,
#   'cib1 protein, rat': 1,
#   'iron': 21,
#   'dyrk kinase': 1,
#   'glutamine': 1,
#   'blood glucose': 2,
#   'acetylcholine': 33,
#   'adaptor proteins, vesicular transport': 3,
#   'nestin': 2,
#   'myelin basic protein': 1,
#   'transcription factor ap-1': 1,
#   'adam19 protein, human': 1,
#   'dna, viral': 1,
#   'cysteine proteinase inhibitors': 3,
#   'receptors, death domain': 1,
#   'methadone': 2,
#   'tlr4 protein, mouse': 1,
#   'receptor, igf type 1': 2,
#   'apolipoprotein a-v': 1,
#   'rhapontigenin': 1,
#   'stilbenes': 6,
#   'mtor protein, human': 1,
#   'rhapontin': 1,
#   'adenine': 1,
#   'superoxides': 1,
#   'sod1 protein, human': 1,
#   'bacterial proteins': 1,
#   'sodium dodecyl sulfate': 1,
#   '3-nitropropionic acid': 1,
#   'bryostatins': 1,
#   'antiviral agents': 2,
#   'ngfr protein, human': 1,
#   'furin protein, human': 1,
#   'vitamin k': 1,
#   'rna, antisense': 1,
#   'heparan sulfate proteoglycans': 1,
#   'electron transport complex iv': 4,
#   'symporters': 1,
#   'diphenylhexatriene': 1,
#   'secretagogins': 1,
#   'insulin': 25,
#   'nin protein, mouse': 1,
#   'somatostatin': 4,
#   'histone acetyltransferases': 1,
#   'aripiprazole': 3,
#   'bridged-ring compounds': 3,
#   'adra1d protein, human': 1,
#   'glutamic acid': 21,
#   'apolipoproteins e': 202,
#   'prostate apoptosis response-4 protein': 1,
#   'kmi-420': 1,
#   'miotics': 1,
#   'flavones': 1,
#   'synaptosomal-associated protein 25': 1,
#   'complement factor h, human': 1,
#   'antineoplastic agents, phytogenic': 1,
#   'ras proteins': 2,
#   'phosphatidylinositol 3-kinases': 9,
#   'isoenzymes': 5,
#   'dinoprost': 1,
#   'rho gtp-binding proteins': 1,
#   'rtn3 protein, human': 2,
#   'aldosterone': 1,
#   'grk5 protein, human': 1,
#   'src homology 2 domain-containing, transforming protein 3': 1,
#   'recombinant fusion proteins': 9,
#   'receptor, serotonin, 5-ht1a': 2,
#   'orexins': 1,
#   'sulfates': 1,
#   'ldl-receptor related proteins': 5,
#   'sapropterin': 1,
#   'amyloid beta-protein (16-22)': 1,
#   'dexamethasone': 5,
#   'benzoxazoles': 1,
#   '2,3,4,5-tetrahydro-7,8-dihydroxy-1-phenyl-1h-3-benzazepine': 1,
#   'htt protein, human': 2,
#   'plasminogen': 1,
#   'immunosuppressive agents': 1,
#   'concanavalin a': 1,
#   'aspartate aminotransferases': 1,
#   'propidium': 1,
#   'gene products, env': 1,
#   'iron regulatory protein 2': 1,
#   'hsp104 protein, s cerevisiae': 1,
#   'tlr4 protein, human': 1,
#   'an-1792': 1,
#   'beta-thromboglobulin': 1,
#   'peptide fragments': 196,
#   'clioquinol': 8,
#   'snca protein, human': 1,
#   'colostrinine': 1,
#   'heparin lyase': 1,
#   'carbohydrates': 2,
#   'serum albumin, bovine': 1,
#   'phospholipase d': 3,
#   'cyclin e': 1,
#   'urokinase-type plasminogen activator': 2,
#   'sterols': 1,
#   'thiophenol': 1,
#   'receptors, ldl': 12,
#   'furin': 1,
#   'organometallic compounds': 5,
#   'leucine-rich repeat serine-threonine protein kinase-2': 2,
#   'receptor, galanin, type 3': 1,
#   'aplp1 protein, human': 2,
#   'calgranulin a': 1,
#   'bay 11-7085': 1,
#   'actin depolymerizing factors': 2,
#   'neramexane': 1,
#   '5-amino-7-(2-phenylethyl)-2-(2-furyl)pyrazolo(4,3-e)-1,2,4-triazolo(1,5-c)pyrimidine': 1,
#   'sphingolipids': 1,
#   'acetylglucosaminidase': 1,
#   'serum albumin': 2,
#   'nuclear receptor subfamily 4, group a, member 2': 1,
#   '14-3-3 proteins': 3,
#   'metals, heavy': 1,
#   '2-(morpholin-4-yl)benzo(h)chromen-4-one': 1,
#   'adamantane': 2,
#   'serotonin uptake inhibitors': 10,
#   'cyclic gmp': 1,
#   'cyclin-dependent kinase inhibitor p21': 1,
#   'estradiol': 11,
#   'amino acid transport system y+': 1,
#   'epinephrine': 2,
#   'hyperforin': 1,
#   'quinones': 1,
#   'hypochlorous acid': 1,
#   'pon1 protein, human': 2,
#   'cerebrospinal fluid proteins': 3,
#   'hippocampal cholinergic neurostimulating peptide': 1,
#   'eif-2 kinase': 3,
#   'phosphothreonine': 2,
#   'lamp2 protein, human': 1,
#   'mmp3 protein, human': 1,
#   'cytokines': 24,
#   'nr1h2 protein, human': 1,
#   'tlr9 protein, mouse': 1,
#   'n-(2-cyclohexyloxy-4-nitrophenyl)methanesulfonamide': 1,
#   'enzyme inhibitors': 47,
#   'benzene derivatives': 1,
#   'plant preparations': 3,
#   'tau-protein kinase': 2,
#   'p2rx7 protein, rat': 1,
#   'choline': 2,
#   'gene products, tat': 1,
#   'phenserine': 4,
#   'immunologic factors': 2,
#   'nitric oxide': 14,
#   'amino acid chloromethyl ketones': 2,
#   'testosterone': 11,
#   'thyroid hormones': 1,
#   'proline': 2,
#   'dendrimers': 1,
#   'ethylamines': 2,
#   '(n-methyl-c-11)-2-(4-methylamino-phenyl)-6-hydroxybenzothiazole': 1,
#   'vitamin d': 1,
#   'phosphoproteins': 2,
#   'hydroxyindoleacetic acid': 1,
#   'nudt1 protein, mouse': 1,
#   'threonyl-glycyl-glutamyl-asparaginyl-histidylarginine': 1,
#   'interleukin-2': 1,
#   'nimodipine': 3,
#   'plant extracts': 22,
#   'tropanes': 1,
#   'oleic acid': 1,
#   'dopamine agents': 19,
#   'pkc-3 protein': 1,
#   'pten-induced putative kinase': 1,
#   'receptors, glucocorticoid': 1,
#   'peptidylprolyl isomerase': 11,
#   'mitogen-activated protein kinase 3': 6,
#   'antineoplastic agents': 7,
#   'dsp 4': 1,
#   'quinolones': 3,
#   'mecamylamine': 1,
#   'receptors, serotonin, 5-ht4': 1,
#   'haloperidol': 3,
#   'elements': 1,
#   'calcium-calmodulin-dependent protein kinases': 5,
#   'il1rn protein, human': 1,
#   'kynurenine-oxoglutarate transaminase': 1,
#   'receptors, purinergic p2x7': 1,
#   'isoindoles': 2,
#   'protein disulfide-isomerases': 2,
#   '10-o-deacetylpaclitaxel 10-monosuccinyl ester': 1,
#   'receptor, igf type 2': 2,
#   'amidohydrolases': 1,
#   'pilocarpine': 1,
#   'cdkn1a protein, human': 1,
#   'app protein, human': 6,
#   'polycyclic compounds': 2,
#   'neural cell adhesion molecules': 1,
#   'receptor, notch3': 1,
#   'parkin protein': 1,
#   'receptors, pituitary adenylate cyclase-activating polypeptide, type i': 1,
#   'cxcl10 protein, human': 2,
#   'ethyl phenylacetyl-pro-gly': 1,
#   'receptor, nerve growth factor': 2,
#   'pregnenolone': 2,
#   'thromboxane b2': 1,
#   'snap25 protein, rat': 1,
#   'angiogenesis inhibitors': 1,
#   'nes protein, human': 2,
#   '3-beta-(2-(diethylamino)ethoxy)androst-5-en-17-one': 1,
#   'antibodies, bacterial': 1,
#   'cymserine': 1,
#   'hexosaminidase c': 1,
#   'tetracaine': 1,
#   '6-cyano-7-nitroquinoxaline-2,3-dione': 1,
#   'hemoglobin a, glycosylated': 2,
#   'antigens, cd11b': 1,
#   'nitric oxide synthase type ii': 5,
#   'benzoyl-l-arg-l-his-(d-asp)-ch(2)cl': 1,
#   'extracellular matrix proteins': 5,
#   'allyl compounds': 1,
#   'propanols': 1,
#   'collapsin response mediator protein-2': 3,
#   'nicotinic acids': 1,
#   'toll-like receptor 2': 2,
#   'melanins': 4,
#   'rna, ribosomal': 1,
#   'cannabinoid receptor modulators': 1,
#   'alpha-crystallins': 1,
#   'catechol o-methyltransferase': 4,
#   'blood proteins': 4,
#   'hif1a protein, human': 1,
#   'phosphatidylethanolamines': 1,
#   'glycogen synthase kinase 3': 31,
#   'nima-interacting peptidylprolyl isomerase': 11,
#   'morphine': 2,
#   'dna-binding proteins': 7,
#   'cyclooxygenase inhibitors': 4,
#   'naphthols': 1,
#   'xeroderma pigmentosum group f protein': 1,
#   'catechin': 1,
#   'notch3 protein, human': 1,
#   'apolipoprotein e3': 8,
#   'nerve tissue proteins': 91,
#   'beta-adrenergic receptor kinases': 2,
#   'bace1 protein, human': 62,
#   'rofecoxib': 3,
#   'bace2 protein, human': 3,
#   'thymine': 1,
#   'dna, complementary': 11,
#   'cholesterol ester transfer proteins': 1,
#   'hepatic lipase, human': 1,
#   'lactic acid': 2,
#   'dimethylargininase': 1,
#   'proteasome endopeptidase complex': 21,
#   'alanine': 5,
#   'glial cell line-derived neurotrophic factors': 1,
#   'endopeptidases': 67,
#   '1,2-dilinolenoyl-3-(4-aminobutyryl)propane-1,2,3-triol': 1,
#   'iodide peroxidase': 1,
#   'enzyme activators': 1,
#   'calf thymus dna': 1,
#   'oxycodone': 1,
#   'phospholipids': 4,
#   'oxidants': 3,
#   'norepinephrine plasma membrane transport proteins': 1,
#   'indans': 89,
#   'luxol fast blue mbs': 1,
#   'neurotrophin 3': 2,
#   'drug carriers': 1,
#   'apba1 protein, mouse': 2,
#   'phosphotransferases (alcohol group acceptor)': 1,
#   'eicosapentaenoic acid': 1,
#   'receptors, g-protein-coupled': 3,
#   'dsc1 protein, human': 1,
#   'oncogene proteins': 3,
#   'glucagon-like peptide 1': 1,
#   '27-hydroxycholesterol': 2,
#   'gluconates': 1,
#   'serotonin 5-ht4 receptor agonists': 1,
#   'nf-kappa b': 7,
#   '2-(2-amino-3-methoxyphenyl)-4h-1-benzopyran-4-one': 1,
#   'sodium sulfate': 1,
#   'gpi-linked proteins': 3,
#   'antigens, cd13': 1,
#   'serotonin plasma membrane transport proteins': 7,
#   'oligopeptides': 6,
#   'ions': 2,
#   'calgranulin b': 1,
#   'vasopressins': 3,
#   'interferon-gamma': 3,
#   'cytosine': 3,
#   'antigens, cd11c': 1,
#   'coat protein complex i': 1,
#   'receptor, adenosine a2a': 1,
#   'factor xa': 1,
#   'interleukin-6': 11,
#   'radioactive tracers': 1,
#   'trypsin': 4,
#   'proteasome inhibitors': 4,
#   'matrigel': 2,
#   'muscarinic agonists': 1,
#   'nitric oxide synthase type iii': 4,
#   'uchl1 protein, mouse': 2,
#   'amyloid beta-protein (1-38)': 1,
#   'amyloid beta-protein (25-36)': 1,
#   'mefenamic acid': 1,
#   'scyllitol': 1,
#   'benzyloxycarbonylvalyl-alanyl-aspartyl fluoromethyl ketone': 2,
#   'buthionine sulfoximine': 1,
#   'opioid peptides': 2,
#   'nitro compounds': 1,
#   'receptors, presynaptic': 1,
#   'cholinergic agents': 4,
#   'receptors, estrogen': 4,
#   'leucine-rich repeat proteins': 1,
#   'amines': 1,
#   'benzofuran': 1,
#   'b': 1076,
#   'ace protein, human': 1,
#   'lactones': 3,
#   'palmitic acid': 1,
#   'glucocorticoids': 3,
#   'cell adhesion molecules, neuronal': 4,
#   'vasoactive intestinal peptide': 1,
#   'nr4a2 protein, human': 1,
#   'limk1 protein, rat': 1,
#   'lysosome-associated membrane glycoproteins': 1,
#   'proto-oncogene proteins c-fos': 2,
#   'adaptor proteins, signal transducing': 9,
#   'synaptotagmins': 1,
#   'fatty alcohols': 1,
#   'trazodone': 1,
#   'epigallocatechin gallate': 1,
#   'pyrrolidinones': 1,
#   'apolipoprotein e2': 3,
#   'adrenocorticotropic hormone': 1,
#   '1-palmitoyl-2-oleoylphosphatidylcholine': 1,
#   'pro-brain natriuretic peptide (1-76)': 1,
#   'bone density conservation agents': 1,
#   'tor serine-threonine kinases': 1,
#   'schizandrin b': 1,
#   'bridged bicyclo compounds, heterocyclic': 3,
#   'medroxyprogesterone': 1,
#   'diallyl disulfide': 1,
#   'monoamine oxidase inhibitors': 6,
#   'daxx protein, human': 1,
#   'receptors, formyl peptide': 1,
#   'apbb2 protein, human': 1,
#   'protein sorting signals': 2,
#   'mapt protein, human': 26,
#   'rna-binding proteins': 2,
#   'indicators and reagents': 4,
#   'antigens, cd': 3,
#   'shc1 protein, human': 1,
#   'glutathione reductase': 2,
#   'neurotransmitter agents': 13,
#   'triiodothyronine, reverse': 1,
#   'ubiquitins': 1,
#   'tyramine': 2,
#   'bcl2l11 protein, mouse': 1,
#   'antidepressive agents, second-generation': 3,
#   'isoproterenol': 4,
#   'anions': 1,
#   'lithium': 1,
#   'tgfb1 protein, mouse': 1,
#   'growth inhibitory factor': 5,
#   'malondialdehyde': 2,
#   'alpha karyopherins': 1,
#   '3-nitrotyrosine': 6,
#   'antimetabolites, antineoplastic': 1,
#   'cholesterol': 69,
#   'neuroserpin': 1,
#   'abca2 protein, human': 2,
#   'cyclin-dependent kinase 5': 8,
#   'viral fusion proteins': 1,
#   'erythromycin': 1,
#   'syndecans': 1,
#   'cations, divalent': 2,
#   'receptor, notch2': 1,
#   'dosage forms': 1,
#   'serine endopeptidases': 6,
#   'sp1 transcription factor': 2,
#   'contrast media': 4,
#   'nucleocytoplasmic transport proteins': 1,
#   'amyloid beta-protein (12-28)': 2,
#   'paroxetine': 2,
#   'factor xa inhibitors': 1,
#   "1,4-bis(4'-hydroxystyryl)-2-methoxybenzene": 1,
#   'aqp4 protein, human': 1,
#   'receptor, galanin, type 1': 1,
#   'nitrates': 4,
#   'quartz': 1,
#   'pepstatins': 1,
#   'i': 1076,
#   'receptors, purinergic p1': 1,
#   'pyrones': 3,
#   'immunoglobulin fc fragments': 1,
#   'pyrophosphatases': 1,
#   'benzodiazepines': 9,
#   'immunotoxins': 1,
#   'ngfrap1 protein, human': 1,
#   'alkenes': 2,
#   'antiparasitic agents': 1,
#   'ubiquitin thiolesterase': 8,
#   'glyceraldehyde-3-phosphate dehydrogenases': 2,
#   'thiobarbituric acid reactive substances': 2,
#   'tryptophan-trna ligase': 1,
#   'cerebrolysin': 4,
#   'chromones': 1,
#   'transforming growth factor-beta type ii receptor': 1,
#   'chlorpyrifos': 1,
#   'calpain': 5,
#   'neopterin': 1,
#   'gpr37 receptor, human': 1,
#   'phosphatidic acids': 1,
#   'fluorodeoxyglucose f18': 27,
#   'lipase': 2,
#   'pyruvate kinase': 2,
#   'dapk1 protein, human': 1,
#   'isoleucine': 3,
#   'retinoblastoma protein': 2,
#   '3-hydroxy-4-pyridone': 1,
#   'receptor, muscarinic m2': 2,
#   'tumor necrosis factor receptor-associated peptides and proteins': 1,
#   'dnmbp protein, human': 1,
#   'toll-like receptor 3': 1,
#   'amyloid beta-protein (1-40)': 45,
#   'txn protein, human': 1,
#   'formaldehyde': 1,
#   'glutathione peroxidase': 2,
#   'thioflavin t': 14,
#   'metalloproteins': 1,
#   'neuronal cdk5 activator (p25-p35)': 3,
#   'caspase 1': 1,
#   'peptide-n4-(n-acetyl-beta-glucosaminyl) asparagine amidase': 1,
#   'adenosine triphosphatases': 4,
#   'glutamates': 2,
#   'antibodies, monoclonal': 21,
#   'butyrylcholinesterase': 15,
#   'leucine': 2,
#   'salicylates': 1,
#   'cyclopentanes': 1,
#   'artemisinine': 1,
#   'glucose transporter type 1': 1,
#   'oncogene protein v-akt': 1,
#   'metalloproteases': 1,
#   '2,3-dihydro-1h-imidazo(1,2-b)pyrazole': 1,
#   'tacrine': 14,
#   'phosphatidylethanolamine binding protein': 4,
#   'thiazolyl blue': 3,
#   'convulxin': 1,
#   'plastics': 1,
#   'phosphatidylethanolamine': 1,
#   'buspirone': 1,
#   'egtazic acid': 1,
#   'chromans': 1,
#   'perk kinase': 1,
#   'fluorescent dyes': 9,
#   'smad proteins': 2,
#   'atp2a1 protein, rat': 1,
#   'lipa protein, human': 1,
#   'ddit3 protein, human': 1,
#   'mitogen-activated protein kinase kinases': 1,
#   'src-family kinases': 1,
#   'nuclear proteins': 11,
#   's100 proteins': 7,
#   'cytochrome p-450 cyp2d6': 2,
#   'casp9 protein, human': 1,
#   'surface-active agents': 1,
#   'bace1 protein, mouse': 28,
#   'adra1a protein, human': 1,
#   'poly(a)-binding proteins': 1,
#   'kynurenine': 1,
#   '2-methoxyidazoxan': 1,
#   'adenylyl cyclases': 2,
#   'retinol-binding proteins': 1,
#   'ntf2 protein, rat': 1,
#   'fibrin fibrinogen degradation products': 4,
#   'protein isoforms': 16,
#   'prnp protein, human': 2,
#   'fluoresceins': 3,
#   'sodium channels': 2,
#   'glial fibrillary acidic protein': 20,
#   'amyloid beta-peptide (5-40)': 1,
#   'sirolimus': 2,
#   'scopolamine hydrobromide': 2,
#   'myelin proteins': 5,
#   'pyrazoles': 4,
#   'poloxalene': 1,
#   'reactive nitrogen species': 1,
#   'clusterin': 3,
#   'jnk mitogen-activated protein kinases': 2,
#   'scgn protein, human': 1,
#   'ubqln1 protein, human': 7,
#   'xanthine oxidase': 1,
#   'terpenes': 2,
#   'aplp2 protein, human': 4,
#   'protein synthesis inhibitors': 2,
#   'receptors, growth factor': 1,
#   'calb1 protein, mouse': 1,
#   'lipoproteins': 4,
#   'lipoprotein(a)': 1,
#   'fluorine radioisotopes': 3,
#   'proliferating cell nuclear antigen': 1,
#   'galanin': 3,
#   '5-hydroxycytosine': 1,
#   '1,4-dihydropyridine': 1,
#   'wortmannin': 2,
#   'drug combinations': 5,
#   'beta-d-galactoside alpha 2-6-sialyltransferase': 1,
#   'cisplatin': 1,
#   'fluvoxamine': 1,
#   'mitogen-activated protein kinase 1': 7,
#   'vgf protein, human': 1,
#   'enzymes': 3,
#   'liposomes': 3,
#   'peroxidase': 3,
#   'adam17 protein': 2,
#   'metallothionein': 2,
#   'valproic acid': 2,
#   'piperidines': 95,
#   'crotalid venoms': 1,
#   'oxidoreductases': 1,
#   'antibodies, anti-idiotypic': 1,
#   'heme oxygenase (decyclizing)': 2,
#   'carbolines': 1,
#   'mef2a protein, human': 1,
#   'chemokines, cxc': 2,
#   'clofibric acid': 1,
#   'sodium carbonate': 1,
#   'esters': 2,
#   'nos2 protein, rat': 1,
#   'carbon': 1,
#   'clu protein, human': 1,
#   'rtn4r protein, mouse': 1,
#   'ono2506': 2,
#   'diflunisal': 1,
#   'aminopeptidases': 1,
#   'membranes, artificial': 1,
#   'hypoxia-inducible factor 1, alpha subunit': 1,
#   'dynorphins': 1,
#   'milnacipran': 1,
#   'macrolides': 1,
#   'lvv-hemorphin-7': 1,
#   'cytarabine': 1,
#   't': 1076,
#   'titermax': 1,
#   'epibatidine': 1,
#   'dinoprostone': 4,
#   'creb1 protein, human': 1,
#   'mcp protein, mouse': 1,
#   'triazines': 1,
#   'lactoylglutathione lyase': 2,
#   'muscarinic antagonists': 6,
#   'pebp1 protein, human': 2,
#   'n-ethylmaleimide-sensitive proteins': 1,
#   'sirtuin 1': 4,
#   'extracellular signal-regulated map kinases': 9,
#   'prothrombin': 2,
#   'caspase 9': 1,
#   'phosphoprotein phosphatases': 3,
#   'thapsigargin': 1,
#   'amyloid beta-protein (25-35)': 12,
#   'ferritins': 3,
#   'cathepsin b': 3,
#   'lrrk2 protein, human': 2,
#   'parathyroid hormone (1-31)amide, human': 1,
#   '1-(2-methoxyphenyl)-4-(4-(2-phthalimido)butyl)piperazine': 1,
#   'gangliosides': 2,
#   'serum amyloid a protein': 3,
#   'conotoxins': 1,
#   'adam9 protein, human': 1,
#   'tocopherols': 1,
#   'cystatins': 4,
#   'phenothiazines': 1,
#   'interleukin-1alpha': 1,
#   'nociceptin': 1,
#   'potassium': 3,
#   'caprylates': 2,
#   'proto-oncogene proteins c-fyn': 2,
#   'dynamin i': 2,
#   'cocaine': 1,
#   'paclitaxel': 3,
#   'formic acid': 2,
#   'map2k1 protein, human': 1,
#   'c-reactive protein': 10,
#   'bilirubin': 1,
#   'taurochenodeoxycholic acid': 1,
#   'caspases': 27,
#   'platelet-derived growth factor': 1,
#   'peptide hormones': 2,
#   'acute-phase proteins': 1,
#   'pyridazines': 1,
#   'cyclic amp response element-binding protein': 4,
#   'cd68 antigen, human': 1,
#   'protein kinase inhibitors': 6,
#   'fibrinolysin': 2,
#   'anti-anxiety agents': 4,
#   'serine proteinase inhibitors': 1,
#   'membrane transport proteins': 4,
#   'neurotoxins': 14,
#   'endorphins': 1,
#   'maprotiline': 1,
#   'glatiramer acetate': 1,
#   'hydrocortisone': 9,
#   'receptor, muscarinic m1': 5,
#   'hemochromatosis protein': 4,
#   "3' untranslated regions": 3,
#   'benzoates': 1,
#   'arachidonate 5-lipoxygenase': 1,
#   'nr2b nmda receptor': 2,
#   's-allylcysteine': 1,
#   'nad(p)h dehydrogenase (quinone)': 1,
#   'aph1a protein, human': 1,
#   'epoxide hydrolases': 1,
#   'lrp1 protein, mouse': 1,
#   'adenosine': 3,
#   'n-methylaspartate': 3,
#   'hallucinogens': 1,
#   'lithium compounds': 1,
#   'psenen protein, human': 2,
#   'gsk3b protein, mouse': 5,
#   'benzothiazoles': 4,
#   'serotonin': 9,
#   'biopolymers': 6,
#   'ercc2 protein, human': 1,
#   'chrna7 protein, human': 4,
#   'antihypertensive agents': 12,
#   'proto-oncogene proteins': 1,
#   'adam17 protein, mouse': 1,
#   'adenosine a2 receptor antagonists': 1,
#   'sodium-potassium-exchanging atpase': 1,
#   'carbamates': 3,
#   'superoxide dismutase': 10,
#   'peroxisome proliferator-activated receptors': 1,
#   'beta-n-acetylhexosaminidases': 1,
#   'thiazoles': 25,
#   'dehydroepiandrosterone': 2,
#   'quetiapine fumarate': 7,
#   '8-hydroxyguanosine': 2,
#   'doublecortin protein': 2,
#   'ginsenosides': 1,
#   'hemopexin': 1,
#   'trans fatty acids': 1,
#   "gadolinium 1,4,7,10-tetraazacyclododecane-n,n',n'',n'''-tetraacetate": 1,
#   'risperidone': 11,
#   'inositol 1,4,5-trisphosphate': 1,
#   'matrix metalloproteinase 3': 3,
#   'ciliary neurotrophic factor': 1,
#   'androgens': 4,
#   'tritium': 1,
#   'molecular chaperone grp78': 2,
#   'syvn1 protein, human': 1,
#   'superoxide dismutase 2': 1,
#   'transforming growth factor beta1': 4,
#   'amyloid beta-protein (17-42)': 1,
#   'enterotoxins': 1,
#   'hexafluoroisopropanol': 1,
#   'alcohol dehydrogenase': 1,
#   'fyn protein, human': 1,
#   'transferrin': 3,
#   'synucleins': 1,
#   'amyloid beta-protein (1-42)': 106,
#   'tmp21 protein, human': 1,
#   'calcium channel blockers': 3,
#   'receptors, notch': 6,
#   '2-(1-(6-((2-fluoroethyl)(methyl)amino)-2-naphthyl)ethylidene)malononitrile': 2,
#   'deferoxamine': 1,
#   'pravastatin': 2,
#   'alkaloids': 11,
#   'lysosomal-associated membrane protein 1': 1,
#   'biological products': 1,
#   'pin1 protein, human': 10,
#   'serine': 18,
#   'cysteine endopeptidases': 1,
#   'niacinamide': 1,
#   'lipoproteins, ldl': 1,
#   'nr1 nmda receptor': 1,
#   'piperazines': 7,
#   'eno1 protein, human': 1,
#   'serotonin antagonists': 2,
#   'pyridones': 1,
#   'medroxyprogesterone acetate': 1,
#   'eukaryotic initiation factor-2': 3,
#   'triiodothyronine': 3,
#   'polylactic acid-polyglycolic acid copolymer': 1,
#   'neprilysin': 10,
#   'sirt1 protein, mouse': 1,
#   'tap2 protein, human': 1,
#   'hsp70 heat-shock proteins': 3,
#   'quillaja saponins': 1,
#   'polyglycolic acid': 1,
#   'antigens, cd40': 1,
#   'diarylpropionitrile': 1,
#   'avidin': 1,
#   'androstenes': 1,
#   'chemokine ccl3': 1,
#   'presenilin-2': 26,
#   'dehydroepiandrosterone sulfate': 3,
#   '1,4-bis(3-carboxy-4-hydroxyphenylethenyl)-benzene': 1,
#   'bcl-2-like protein 11': 1,
#   'hormone antagonists': 4,
#   'transforming growth factor beta': 8,
#   'limonins': 1,
#   'nerve growth factor': 15,
#   'factor xiii': 1,
#   'prion proteins': 2,
#   'epitopes, t-lymphocyte': 2,
#   'alkynes': 1,
#   'rtn4 protein, mouse': 1,
#   'ccl2 protein, human': 4,
#   'glycoproteins': 1,
#   'anesthetics, general': 1,
#   '(s)-2-ethyl-8-methyl-1-thia-4,8-diazaspiro(4.5)decan-3-one': 2,
#   'epitopes, b-lymphocyte': 2,
#   'antiemetics': 1,
#   'dna-activated protein kinase': 1,
#   'ketamine': 1,
#   'receptors, cytokine': 1,
#   'bepotastine': 1,
#   'smad2 protein, human': 1,
#   'apbb1 protein, rat': 1,
#   '8-hydroxyguanine': 1,
#   'serotonin receptor agonists': 3,
#   'poly i-c': 1,
#   'amides': 1,
#   'intercellular signaling peptides and proteins': 3,
#   'ps1 antigen': 1,
#   'minozac': 1,
#   'slc6a4 protein, human': 2,
#   'etanercept': 1,
#   "guanosine 5'-o-(3-thiotriphosphate)": 2,
#   'itsn1 protein, human': 1,
#   'picolinic acid': 1,
#   'antiparkinson agents': 12,
#   'amyloid beta-protein precursor': 270,
#   'benzothiophene': 1,
#   'benzofurans': 1,
#   'celecoxib': 2,
#   'alox5ap protein, mouse': 1,
#   'fibrinogen': 1,
#   'estrogen receptor alpha': 7,
#   'ece2 protein, human': 1,
#   'receptors, cxcr4': 1,
#   'salts': 1,
#   'anti-inflammatory agents': 15,
#   'orphan nuclear receptors': 1,
#   'flurbiprofen': 3,
#   'map-kinase-activated kinase 2': 1,
#   'cdh1 proteins': 1,
#   'shc3 protein, human': 1,
#   'anti-bacterial agents': 4,
#   'ribosomal protein s6 kinases, 70-kda': 2,
#   'prealbumin': 4,
#   "3'-o-(4-benzoyl)benzoyladenosine 5'-triphosphate": 1,
#   'biotin': 1,
#   'reagent kits, diagnostic': 1,
#   'proto-oncogene proteins c-akt': 5,
#   'pd 142505-0028': 2,
#   'macromolecular substances': 4,
#   'ala7-conantokin-g': 1,
#   'amyloid': 73,
#   'nr2a nmda receptor': 1,
#   'ophthalmic solutions': 3,
#   'slc7a11 protein, mouse': 1,
#   'type i signal peptidase': 1,
#   'dna repair enzymes': 1,
#   'aniline compounds': 4,
#   'cholinesterase inhibitors': 225,
#   'deoxyguanosine': 2,
#   'ginkgo biloba extract': 6,
#   'leptin': 1,
#   'excitatory amino acid antagonists': 39,
#   'fluoro jade': 2,
#   'leupeptins': 1,
#   'phosphotransferases': 1,
#   'glyceraldehyde 3-phosphate dehydrogenase (nadp+)': 1,
#   'aluminum': 19,
#   'multidrug resistance-associated proteins': 1,
#   'g-protein-coupled receptor kinase 2': 2,
#   'alpha 1-antitrypsin': 1,
#   'sorl1 protein, human': 3,
#   'hydrazines': 3,
#   'il1a protein, human': 1,
#   'nootropic agents': 72,
#   'antidepressive agents': 18,
#   '2-(beta-(3-iodo-4-hydroxyphenyl)ethylaminomethyl)tetralone': 1,
#   'park7 protein, human': 2,
#   'thymidine phosphorylase': 1,
#   'pin1 protein, mouse': 2,
#   'epothilones': 1,
#   'dna transposable elements': 1,
#   'benzylisoquinolines': 1,
#   'gprk5 protein, mouse': 1,
#   'adam17 protein, human': 1,
#   'hydrazino nicotinamide': 1,
#   's100a12 protein, human': 1,
#   'omeprazole': 1,
#   'heterocyclic compounds, 1-ring': 1,
#   'immunoglobulin fab fragments': 1,
#   'neurotransmitter uptake inhibitors': 1,
#   'receptors, n-methyl-d-aspartate': 26,
#   'magnesium': 2,
#   'histone deacetylase inhibitors': 1,
#   'carboxylic acids': 3,
#   'receptor, galanin, type 2': 2,
#   'acetates': 1,
#   'nogo proteins': 3,
#   'membrane glycoproteins': 11,
#   'piperazine': 1,
#   'nicotinic antagonists': 1,
#   'huperzine a': 8,
#   's100 calcium binding protein beta subunit': 6,
#   'acetylcholinesterase': 31,
#   'cdc48 protein': 1,
#   'manzamine e': 1,
#   'antigens, cd36': 1,
#   'homocystine': 2,
#   'rna, small interfering': 9,
#   'lateriflorone': 1,
#   '3,5-dibromo-4-nitrosobenzenesulfonate': 1,
#   'biomarkers, tumor': 1,
#   'tumor necrosis factor-alpha': 16,
#   'receptors, cytoplasmic and nuclear': 3,
#   'fzr1 protein, human': 1,
#   'coenzymes': 1,
#   "(3-4-(2-fluoromethyl-(1,1'-biphenyl)-4-acetyloxy)-3-methoxyphenyl)-2-propenoic acid 4-nitrooxy butyl ester": 1,
#   'alpha-crystallin b chain': 1,
#   'hsd17b10 protein, human': 1,
#   'protein-serine-threonine kinases': 17,
#   'tissue inhibitor of metalloproteinases': 1,
#   '5-lipoxygenase-activating proteins': 1,
#   'sugt1 protein, human': 1,
#   "1,1'-xylyl bis-1,4,8,11-tetraaza cyclotetradecane": 1,
#   'tubulin': 4,
#   'ubiquinone': 1,
#   'p73 protein, human': 1,
#   'immunoglobulin g': 6,
#   'enalapril': 1,
#   'dapi': 3,
#   'mitogen-activated protein kinase 8': 1,
#   'sodium': 2,
#   'death-associated protein kinases': 1,
#   'purine nucleotides': 1,
#   'chrna7 protein, mouse': 3,
#   'aluminum maltolate': 3,
#   'piracetam': 1,
#   'g-protein-coupled receptor kinase 5': 2,
#   'calcium-calmodulin-dependent protein kinase type 2': 4,
#   'fibroblast growth factor 2': 2,
#   'polymers': 7,
#   'trimethyltin compounds': 1,
#   'purinergic p1 receptor antagonists': 1,
#   'water pollutants, chemical': 1,
#   'yy1 protein, rat': 1,
#   'amyloid beta-protein (10-43)': 1,
#   'diphenyleneiodonium': 1,
#   'retinol-binding proteins, plasma': 1,
#   'drosophila proteins': 2,
#   'methemoglobin': 1,
#   'lrp1b protein, human': 1,
#   'tgfb1 protein, human': 2,
#   'ornithine decarboxylase': 1,
#   'peptidyl-dipeptidase a': 13,
#   'phenytoin': 3,
#   'integrins': 1,
#   'biopterin': 1,
#   'dyneins': 1,
#   'wnt proteins': 2,
#   'dna adducts': 1,
#   'sorl1 protein, rat': 1,
#   'dihydropyridines': 2,
#   'vascular endothelial growth factor a': 5,
#   '3-iodobenzylguanidine': 5,
#   'molecular chaperones': 14,
#   'receptors, cell surface': 16,
#   'luteinizing hormone': 4,
#   'minocycline': 1,
#   'amino acid transport systems': 1,
#   'nrep protein, human': 1,
#   'receptors, adrenergic, alpha-2': 1,
#   'proteome': 7,
#   'neuromelanin': 3,
#   'collagen type iv': 2,
#   'epothilone a': 1,
#   'ircinal a': 1,
#   'threonine': 11,
#   'acetylcarnitine': 3,
#   'mifepristone': 2,
#   'f2-isoprostanes': 2,
#   'protein-tyrosine kinases': 2,
#   'azetidines': 1,
#   'metabotropic glutamate receptor type 1': 2,
#   'free radical scavengers': 4,
#   'pctaire-3 protein kinase': 1,
#   'potassium channels': 1,
#   'tandospirone': 1,
#   'nitriles': 4,
#   'caveolin 3': 1,
#   'low density lipoprotein receptor-related protein-1': 8,
#   'complement system proteins': 1,
#   'thiones': 3,
#   'technetium tc 99m exametazime': 6,
#   'luciferases': 1,
#   'atp dependent 26s protease': 1,
#   'antimanic agents': 1,
#   'triglycerides': 6,
#   'shc signaling adaptor proteins': 1,
#   'nisoxetine': 1,
#   'testosterone congeners': 1,
#   'transcription factor chop': 2,
#   'calb1 protein, human': 1,
#   'carrier proteins': 18,
#   'enzymes, immobilized': 1,
#   'pyridines': 5,
#   'imidazo(1,2-a)pyridine': 1,
#   'quinolines': 1,
#   'oximes': 4,
#   'lipopolysaccharides': 5,
#   'src homology 2 domain-containing, transforming protein 1': 1,
#   'map kinase kinase 1': 1,
#   'cytochromes c': 3,
#   'adam10 protein, human': 2,
#   'resveratrol': 3,
#   'histones': 1,
#   'endothelin receptor antagonists': 1,
#   'map kinase kinase kinase 5': 1,
#   'potassium channels, voltage-gated': 1,
#   'pepstatin': 1,
#   'chemokines': 8,
#   'interleukin-1beta': 6,
#   '5-iodo-3-(2-azetidinylmethoxy)pyridine': 1,
#   'antigens, cd147': 2,
#   'lovastatin': 2,
#   'antigens, differentiation, myelomonocytic': 1,
#   'adam12 protein': 1,
#   'nadph oxidase': 4,
#   'alzheimer vaccines': 17,
#   'bosentan': 1,
#   'calbindins': 1,
#   'excitatory amino acid agonists': 1,
#   'heme': 3,
#   'creatinine': 1,
#   'map kinase kinase 4': 1,
#   'pituitary adenylate cyclase-activating polypeptide': 1,
#   'rivastigmine': 41,
#   'bace protein, rat': 1,
#   'immunoglobulin variable region': 2,
#   'nitrobenzenes': 1,
#   'cell adhesion molecules, neuron-glia': 1,
#   'n': 1076,
#   'p21-activated kinases': 1,
#   'calcineurin': 2,
#   'nociceptin receptor': 1,
#   '8-hydroxyadenine': 1,
#   'antigens, cd34': 1,
#   'lmp-2 protein': 1,
#   'dietary fats': 6,
#   'transmembrane protein, simian immunodeficiency virus': 1,
#   'toll-like receptor 9': 1,
#   'receptors, gaba': 4,
#   'tau proteins': 229,
#   'ppar alpha': 1,
#   'iron chelating agents': 1,
#   'indole alkaloids': 1,
#   'psn protein, drosophila': 1,
#   'mediator complex subunit 1': 1,
#   'sphingomyelins': 1,
#   'anti-ulcer agents': 1,
#   'capsules': 1,
#   'tyrosine 3-monooxygenase': 5,
#   'laminin': 2,
#   'toll-like receptor 4': 2,
#   'advanced glycosylation end product-specific receptor': 3,
#   'o': 1076,
#   'adra2c protein, human': 1,
#   'gaba antagonists': 1,
#   'tert-4-hydroxy-2-nonenal': 1,
#   'chrna7 protein, rat': 1,
#   'lrp1b protein, mouse': 1,
#   'msi1 protein, human': 2,
#   'gsto1 protein, human': 1,
#   'neuropeptide y': 4,
#   'ethionine': 1,
#   'deoxyribonucleases, type ii site-specific': 1,
#   ...},
#  'count_articles': 3318,
#  'mesh_titles': {'naphthols/blood': 1,
#   'mycobacterium tuberculosis/drug effects': 1,
#   'apoptosis': 20,
#   'steroid hydroxylases/genetics': 9,
#   'down syndrome/immunology': 1,
#   'rho-associated kinases': 3,
#   'cholesterol, ldl/blood': 3,
#   'enteral nutrition/ethics': 1,
#   'cerebral cortex/growth & development': 1,
#   'central nervous system/drug effects': 3,
#   'solvents': 1,
#   'mental disorders/complications': 2,
#   'internet': 4,
#   'palliative care/psychology': 1,
#   'immunologic factors/pharmacology': 1,
#   'intestinal polyps/diagnosis': 1,
#   'detergents': 1,
#   'antibodies, blocking/pharmacology': 1,
#   'pyrophosphatases/genetics': 1,
#   'apoptosis regulatory proteins/genetics': 1,
#   'furin/physiology': 1,
#   'immunoglobulin isotypes/biosynthesis': 1,
#   'fishes': 2,
#   'joint diseases/drug therapy': 1,
#   'phosphatidylethanolamines/metabolism': 1,
#   'personality': 3,
#   'inclusion bodies/metabolism': 3,
#   'phosphothreonine/metabolism': 2,
#   'presenilin-1/chemistry': 1,
#   'learning disorders/chemically induced': 1,
#   'axonal transport/genetics': 3,
#   'age of onset': 86,
#   'corpus striatum/cytology': 1,
#   'cell death/genetics': 1,
#   'dementia/prevention & control': 15,
#   'hygiene': 1,
#   'amyloid/metabolism': 46,
#   'nuclear medicine/methods': 2,
#   'psychometrics/economics': 1,
#   'neural inhibition/physiology': 4,
#   'antidepressive agents, tricyclic/therapeutic use': 1,
#   'image interpretation, computer-assisted': 4,
#   'memory disorders/etiology': 30,
#   'amino acids/urine': 1,
#   'mood disorders/physiopathology': 2,
#   'oxidative phosphorylation': 2,
#   'epilepsy/metabolism': 3,
#   'tauopathies/metabolism': 7,
#   'membrane proteins/genetics': 67,
#   'schizophrenia, paranoid/drug therapy': 2,
#   'atherosclerosis/physiopathology': 1,
#   'doxycycline/therapeutic use': 2,
#   'neurofilament proteins/immunology': 1,
#   'protein kinase c/physiology': 2,
#   'bryostatins': 1,
#   'food, formulated': 1,
#   'gene expression regulation/drug effects': 16,
#   'curcumin/therapeutic use': 3,
#   'fatigue/economics': 1,
#   'hippocampus/ultrastructure': 5,
#   'blood-brain barrier/pathology': 1,
#   'indans/administration & dosage': 9,
#   'sequence homology, amino acid': 3,
#   'prpsc proteins/metabolism': 1,
#   'reactive oxygen species/antagonists & inhibitors': 2,
#   'amyloid beta-peptides/pharmacology': 26,
#   'epilepsies, partial/epidemiology': 1,
#   'secretagogins': 1,
#   'jnk mitogen-activated protein kinases/metabolism': 2,
#   'patient dropouts/statistics & numerical data': 1,
#   'registries/statistics & numerical data': 4,
#   'myelin proteins/physiology': 1,
#   'thalamus/physiopathology': 1,
#   'affect/drug effects': 2,
#   'disclosure': 2,
#   'th2 cells/immunology': 1,
#   'periodicals as topic': 1,
#   'hiv infections/virology': 1,
#   'vaccines, dna/immunology': 1,
#   'evidence-based medicine': 16,
#   'glutathione transferase/antagonists & inhibitors': 1,
#   'tomography, emission-computed, single-photon': 25,
#   'catechin/analogs & derivatives': 1,
#   'somatomedins/physiology': 1,
#   'hemopexin/cerebrospinal fluid': 1,
#   'melatonin/analogs & derivatives': 1,
#   'receptors, lipoprotein/physiology': 1,
#   'melatonin/administration & dosage': 1,
#   'sequence deletion': 3,
#   'carnosine/analysis': 1,
#   'hypertension/physiopathology': 4,
#   'fluoxetine/adverse effects': 1,
#   'cholesterol/blood': 17,
#   'neurodegenerative diseases/therapy': 4,
#   'radioligand assay/methods': 1,
#   'dna, viral/genetics': 1,
#   'memory disorders/complications': 5,
#   'cell nucleus/ultrastructure': 2,
#   'environment': 7,
#   'caenorhabditis elegans/embryology': 1,
#   'sertraline/therapeutic use': 2,
#   'heat-shock proteins/physiology': 2,
#   'ribosomes/metabolism': 1,
#   'seizures/epidemiology': 2,
#   'helicobacter infections/pathology': 1,
#   'dementia/metabolism': 14,
#   'nerve tissue proteins/genetics': 33,
#   'pyruvate kinase/drug effects': 1,
#   'dementia/drug therapy': 26,
#   'vitamin b 12/therapeutic use': 2,
#   'hyperlipidemias/epidemiology': 1,
#   'intracellular signaling peptides and proteins/metabolism': 3,
#   'sleep stages/physiology': 2,
#   'amyloid/genetics': 10,
#   'dementia/diagnostic imaging': 3,
#   'adenine/chemistry': 1,
#   'entorhinal cortex/immunology': 1,
#   'adrenal medulla/physiopathology': 1,
#   'amyloid beta-peptides/immunology': 50,
#   'amyloidosis/physiopathology': 1,
#   'insulysin/physiology': 1,
#   'cell survival/immunology': 1,
#   'humans': 3047,
#   'molecular chaperones/physiology': 4,
#   'kidney diseases/physiopathology': 1,
#   'cell-free system': 1,
#   'polycyclic compounds/pharmacology': 1,
#   'amino acids/cerebrospinal fluid': 1,
#   'adam proteins/metabolism': 4,
#   'delusions/epidemiology': 5,
#   'iron regulatory protein 2/genetics': 1,
#   'tau proteins/analysis': 6,
#   'amyloid beta-peptides/chemical synthesis': 2,
#   'pineal gland/diagnostic imaging': 1,
#   'blood vessels/chemistry': 1,
#   'borrelia/pathogenicity': 1,
#   'patient-centered care/organization & administration': 1,
#   'visual pathways/physiopathology': 2,
#   'injections, intraperitoneal': 1,
#   'psychophysics': 3,
#   'mental status schedule/statistics & numerical data': 31,
#   'hla-d antigens/genetics': 1,
#   'safety management/organization & administration': 2,
#   'trichlorfon/pharmacology': 1,
#   'geriatrics': 3,
#   'neurotoxins/toxicity': 6,
#   'substance-related disorders/genetics': 1,
#   'aging/psychology': 31,
#   'calgranulin b/analysis': 1,
#   'point mutation': 14,
#   'leucine-rich repeat serine-threonine protein kinase-2': 2,
#   'genetic counseling/psychology': 2,
#   'protein kinase inhibitors/therapeutic use': 1,
#   'multimedia': 2,
#   'uracil/chemistry': 1,
#   'cerebrospinal fluid proteins/metabolism': 1,
#   'immunization': 8,
#   'borrelia infections/pathology': 1,
#   'home care services': 3,
#   'ryanodine receptor calcium release channel/metabolism': 2,
#   'lewy body disease/therapy': 2,
#   'galactose/metabolism': 1,
#   'cardiovascular diseases/diagnostic imaging': 2,
#   'trauma, nervous system/pathology': 1,
#   'nerve degeneration/complications': 1,
#   'amygdala/pathology': 13,
#   'vascular diseases/blood': 1,
#   'immunotherapy': 9,
#   'pupil/physiology': 1,
#   'glutamic acid/chemistry': 1,
#   'parietal lobe/physiology': 1,
#   'antipsychotic agents/economics': 1,
#   'respiration': 2,
#   'nursing staff/education': 2,
#   'brain/pathology': 373,
#   'amyloid precursor protein secretases/deficiency': 1,
#   'magnetoencephalography/drug effects': 1,
#   'referral and consultation': 5,
#   'alkenes/chemistry': 1,
#   'receptors, notch/genetics': 1,
#   'piperidines/analysis': 1,
#   'antibodies, monoclonal/physiology': 1,
#   'metals/metabolism': 5,
#   'retinal ganglion cells/pathology': 2,
#   'education, medical, graduate': 1,
#   'histidine/toxicity': 1,
#   'brain-derived neurotrophic factor/blood': 4,
#   'alum compounds/administration & dosage': 3,
#   'protein subunits/metabolism': 2,
#   'anxiety disorders/metabolism': 1,
#   'encephalitis, herpes simplex/metabolism': 1,
#   'databases, protein': 2,
#   'plant preparations': 1,
#   'presenilins/chemistry': 1,
#   'dementia/enzymology': 3,
#   'hsp20 heat-shock proteins/metabolism': 1,
#   'oxygen/metabolism': 2,
#   'folic acid deficiency/genetics': 2,
#   'aging/blood': 2,
#   'sequence homology, nucleic acid': 1,
#   'corticotropin-releasing hormone/metabolism': 2,
#   'caspase 1/physiology': 1,
#   'cholesterol/cerebrospinal fluid': 2,
#   'infarction, middle cerebral artery/pathology': 2,
#   'neurons/enzymology': 19,
#   'neuroprotective agents/therapeutic use': 58,
#   'auditory cortex/pathology': 1,
#   'mefenamic acid/pharmacology': 1,
#   'formates/chemistry': 2,
#   'silver staining/standards': 1,
#   'hippocampus/diagnostic imaging': 4,
#   'nerve tissue proteins/isolation & purification': 1,
#   'complement factor h/analysis': 1,
#   'peptide fragments/chemical synthesis': 1,
#   'receptors, cytokine/immunology': 1,
#   'medicare': 3,
#   'valsalva maneuver/physiology': 1,
#   'apolipoprotein a-ii/genetics': 1,
#   'homovanillic acid/blood': 1,
#   'optic nerve diseases/physiopathology': 2,
#   'basal ganglia/metabolism': 2,
#   'serine': 1,
#   'stress disorders, post-traumatic/epidemiology': 1,
#   'terminology as topic': 5,
#   'intelligence tests/statistics & numerical data': 1,
#   'curcumin/pharmacology': 2,
#   'national health programs/statistics & numerical data': 1,
#   'medical records': 2,
#   'extracellular space/physiology': 1,
#   'dna replication/drug effects': 2,
#   'phylogeny': 1,
#   'renin/antagonists & inhibitors': 1,
#   'elements': 1,
#   'synapses/genetics': 2,
#   'microtubules/metabolism': 14,
#   'mothers': 1,
#   'melanocytes/ultrastructure': 1,
#   'glycogen synthase kinase 3/drug effects': 3,
#   'hypotension, orthostatic': 1,
#   'biological transport/physiology': 4,
#   'survival rate': 6,
#   'heparin lyase/pharmacology': 1,
#   'memory disorders/classification': 3,
#   'spinal cord/cytology': 1,
#   'protein folding': 32,
#   'stress, psychological/physiopathology': 3,
#   'peptides/metabolism': 7,
#   'primary health care/organization & administration': 2,
#   'schizophrenia/epidemiology': 1,
#   'peptide mapping': 1,
#   'delirium/psychology': 1,
#   'magnetic resonance spectroscopy/methods': 5,
#   'plant extracts/chemistry': 1,
#   'zebrafish/genetics': 1,
#   'mammillary bodies/anatomy & histology': 1,
#   'fluorescent dyes/analysis': 1,
#   'interleukin-1/biosynthesis': 1,
#   'neurofilament proteins/analysis': 1,
#   'luteinizing hormone/agonists': 1,
#   'health services research': 2,
#   'neurofibrils/pathology': 2,
#   'excitatory amino acid antagonists/pharmacology': 12,
#   'brain/diagnostic imaging': 41,
#   'protease inhibitors/chemistry': 8,
#   'cystathionine beta-synthase/genetics': 1,
#   'helicobacter infections/epidemiology': 2,
#   'staining and labeling/methods': 4,
#   'ion channel gating/physiology': 1,
#   'polymorphism, restriction fragment length': 5,
#   'nerve growth factor/genetics': 4,
#   'home care services/organization & administration': 2,
#   'echocardiography, doppler/methods': 1,
#   'insulin-like growth factor ii/metabolism': 1,
#   'affinity labels/pharmacokinetics': 1,
#   'endopeptidases/secretion': 1,
#   'ocular motility disorders/etiology': 1,
#   'antiparkinson agents/pharmacology': 4,
#   'indans/analysis': 1,
#   'dendrimers/pharmacology': 1,
#   'central nervous system agents/pharmacology': 2,
#   'extracellular matrix/chemistry': 1,
#   'tumor cells, cultured/metabolism': 1,
#   'submitochondrial particles/drug effects': 1,
#   'sesquiterpenes/therapeutic use': 5,
#   'netherlands': 6,
#   'odorants': 2,
#   'cell differentiation/physiology': 6,
#   'transfection/methods': 7,
#   'neural pathways/drug effects': 1,
#   'superoxide dismutase/blood': 1,
#   'long-term potentiation/genetics': 1,
#   'dronabinol/chemistry': 1,
#   'stress, psychological/immunology': 1,
#   'bone marrow transplantation': 1,
#   'permeability': 3,
#   'apolipoproteins e/biosynthesis': 2,
#   'exoribonucleases/metabolism': 1,
#   'focus groups': 1,
#   'automobile driving': 2,
#   'axons/physiology': 8,
#   'repetitive sequences, nucleic acid': 1,
#   'ppar gamma/physiology': 1,
#   'brain/metabolism': 311,
#   'musculoskeletal diseases/rehabilitation': 1,
#   'second messenger systems/drug effects': 1,
#   'demyelinating diseases/metabolism': 1,
#   'dentate gyrus/pathology': 1,
#   'huntington disease/drug therapy': 2,
#   'psychometrics': 25,
#   'dementia/blood': 8,
#   'tissue inhibitor of metalloproteinases/genetics': 1,
#   'speech perception': 4,
#   'estrogens, conjugated (usp)/therapeutic use': 1,
#   'prosopagnosia/etiology': 1,
#   'neuroglia/physiology': 4,
#   'inflammation mediators/immunology': 2,
#   'flow cytometry': 5,
#   'hypoxia-inducible factor 1, alpha subunit/biosynthesis': 1,
#   'stress, physiological/pathology': 1,
#   'insurance coverage': 1,
#   'alcohol drinking/epidemiology': 2,
#   'research/organization & administration': 1,
#   'inflammation/drug therapy': 4,
#   'apolipoprotein e3': 4,
#   'postmenopause/drug effects': 1,
#   'osteoporosis/complications': 2,
#   'amino acids/therapeutic use': 4,
#   'continental population groups': 1,
#   'crotalid venoms/pharmacology': 1,
#   'frontal bone/pathology': 1,
#   'australia': 2,
#   'helicobacter infections/complications': 2,
#   'lipoprotein lipase/genetics': 1,
#   'blood-brain barrier/physiopathology': 5,
#   'chemokines, cc/metabolism': 1,
#   'coloring agents': 2,
#   'teaching/methods': 1,
#   'oxidoreductases acting on ch-ch group donors/genetics': 1,
#   'biolistics/methods': 1,
#   'mouth diseases/etiology': 1,
#   'language disorders/history': 1,
#   'protein-serine-threonine kinases/physiology': 1,
#   'drug carriers': 1,
#   'hippocampus/immunology': 2,
#   'cell culture techniques': 7,
#   'supranuclear palsy, progressive/psychology': 1,
#   'models, chemical': 15,
#   'synapses/pathology': 15,
#   'endostatins/chemistry': 1,
#   'enzyme-linked immunosorbent assay': 30,
#   'genes/genetics': 1,
#   'benzodiazepines/therapeutic use': 7,
#   'neurodegenerative diseases/classification': 2,
#   'amnesia, retrograde/physiopathology': 1,
#   'thiazoles/pharmacokinetics': 2,
#   'protease inhibitors/pharmacology': 11,
#   'colforsin/pharmacology': 2,
#   'vegetables': 3,
#   'blotting, southern': 1,
#   'anxiety': 1,
#   'subcellular fractions/pathology': 2,
#   'neural pathways/pathology': 7,
#   'anxiety/epidemiology': 2,
#   'social distance': 1,
#   'cell adhesion molecules/metabolism': 4,
#   'program evaluation/statistics & numerical data': 1,
#   'lewy body disease/drug therapy': 7,
#   'depression/drug therapy': 5,
#   'multivariate analysis': 12,
#   'mads domain proteins/genetics': 1,
#   'mental status schedule': 80,
#   'buspirone/therapeutic use': 1,
#   'cytosol/metabolism': 3,
#   'disulfides/therapeutic use': 1,
#   'vitamin b 12/administration & dosage': 2,
#   'cadherins/metabolism': 3,
#   'synaptic membranes/genetics': 1,
#   'field dependence-independence': 1,
#   'chemokine ccl3': 1,
#   'home care services/utilization': 1,
#   'clonidine/pharmacology': 1,
#   'cisplatin/pharmacology': 1,
#   'founder effect': 2,
#   'obesity': 1,
#   'hand/innervation': 1,
#   'illinois': 1,
#   'dronabinol/pharmacology': 1,
#   'presenilins/immunology': 1,
#   'education': 13,
#   'proteasome inhibitors': 4,
#   'serotonin/biosynthesis': 1,
#   'microscopy, immunoelectron': 1,
#   'coronary disease/genetics': 2,
#   'professional-family relations': 9,
#   'metals/analysis': 1,
#   'alzheimer disease/metabolism': 843,
#   'organelles/immunology': 1,
#   'carotid stenosis/etiology': 1,
#   'computers, handheld': 1,
#   'cholesterol/metabolism': 43,
#   'prealbumin/analysis': 2,
#   'france/epidemiology': 1,
#   'cyclooxygenase 2 inhibitors/adverse effects': 1,
#   'social isolation': 3,
#   'matrix metalloproteinase 9/metabolism': 2,
#   'low density lipoprotein receptor-related protein-1/genetics': 7,
#   'zebrafish': 1,
#   'neurons/secretion': 3,
#   'anxiety/prevention & control': 2,
#   'leukoaraiosis/complications': 2,
#   'continuous positive airway pressure/statistics & numerical data': 1,
#   'hydrocephalus, normal pressure/cerebrospinal fluid': 2,
#   'huntington disease/therapy': 1,
#   'excitatory postsynaptic potentials/drug effects': 5,
#   'reproducibility of results': 114,
#   'serotonin uptake inhibitors/pharmacology': 1,
#   'carbon isotopes/metabolism': 1,
#   'aptitude': 1,
#   'antineoplastic agents, phytogenic/therapeutic use': 1,
#   'cytokines/cerebrospinal fluid': 1,
#   'pharmacoepidemiology/statistics & numerical data': 1,
#   'interleukin-8/biosynthesis': 1,
#   'tyrosine 3-monooxygenase/genetics': 1,
#   'tacrine/pharmacokinetics': 1,
#   'choline o-acetyltransferase/antagonists & inhibitors': 1,
#   'databases as topic': 2,
#   'classification': 3,
#   'cell cycle proteins/biosynthesis': 1,
#   'encephalopathy, bovine spongiform/metabolism': 1,
#   'muscular dystrophy, duchenne/immunology': 1,
#   'sodium channel blockers/therapeutic use': 2,
#   'amyloid precursor protein secretases/biosynthesis': 1,
#   'complement system proteins/immunology': 1,
#   'corticosterone/blood': 3,
#   'neuropeptides/biosynthesis': 1,
#   'mifepristone/metabolism': 1,
#   'ischemia/complications': 1,
#   'neprilysin/drug effects': 1,
#   'volunteers/education': 1,
#   'frontal lobe/blood supply': 3,
#   'interleukin-10/metabolism': 2,
#   'vitamin e/therapeutic use': 5,
#   'interdisciplinary communication': 2,
#   'transcription initiation site': 1,
#   'perceptual disorders/physiopathology': 2,
#   'public health': 2,
#   'myelin basic protein/metabolism': 1,
#   'proteome/analysis': 1,
#   'prion diseases/etiology': 2,
#   'simvastatin/pharmacology': 1,
#   'muscular atrophy/pathology': 2,
#   'respiratory function tests/methods': 1,
#   'carbon radioisotopes/metabolism': 1,
#   'heart diseases/physiopathology': 1,
#   'korea/epidemiology': 2,
#   'lewy body disease': 1,
#   'epilepsy/epidemiology': 2,
#   'heart rate/drug effects': 2,
#   'frontal lobe/physiopathology': 24,
#   'nitric oxide synthase type iii/drug effects': 1,
#   'mental health': 6,
#   'hydrocephalus, normal pressure/physiopathology': 1,
#   'cognition disorders/physiopathology': 88,
#   'transaminases/metabolism': 1,
#   'drug utilization/statistics & numerical data': 3,
#   'brain/drug effects': 68,
#   'withholding treatment/ethics': 3,
#   'european continental ancestry group/statistics & numerical data': 2,
#   'mitochondrial diseases/physiopathology': 3,
#   'alcohol dehydrogenase/genetics': 1,
#   'estrogens/deficiency': 2,
#   'triticum': 1,
#   'iron metabolism disorders/diagnosis': 1,
#   'nerve degeneration/epidemiology': 1,
#   'neurofibrillary tangles': 5,
#   'astrocytes/drug effects': 11,
#   'apolipoproteins e': 2,
#   'phosphorylation': 108,
#   'anticholesteremic agents/therapeutic use': 2,
#   'aging': 48,
#   'pituitary-adrenal system/physiopathology': 2,
#   'alzheimer disease/diagnosis': 510,
#   'biological clocks': 1,
#   'cognition': 45,
#   'cholinesterase inhibitors/isolation & purification': 1,
#   'orientation': 8,
#   'ischemia/mortality': 1,
#   'factor xa inhibitors': 1,
#   'central nervous system diseases/diagnostic imaging': 1,
#   'alanine/chemistry': 1,
#   'social behavior disorders/drug therapy': 1,
#   'clusterin/genetics': 1,
#   'memory disorders/physiopathology': 27,
#   'receptors, retinoic acid/genetics': 1,
#   'glial fibrillary acidic protein/metabolism': 14,
#   'diarrhea/chemically induced': 1,
#   'sweden': 5,
#   'allyl compounds/administration & dosage': 1,
#   'parity/physiology': 1,
#   'nursing homes/ethics': 1,
#   'nursing homes/standards': 5,
#   'equipment safety': 1,
#   'neuroblastoma/pathology': 10,
#   'peripheral nervous system diseases/epidemiology': 1,
#   'estrogens/biosynthesis': 1,
#   'psychiatric status rating scales/statistics & numerical data': 4,
#   'dementia/immunology': 2,
#   'photic stimulation/methods': 12,
#   'lymphocyte activation': 1,
#   'plaque, amyloid/enzymology': 2,
#   'pyridines/therapeutic use': 1,
#   'tumor necrosis factor-alpha/pharmacology': 1,
#   'narcotics/administration & dosage': 1,
#   'psychomotor agitation/prevention & control': 1,
#   'mental recall/drug effects': 1,
#   'glycogen synthase kinases/metabolism': 1,
#   'amyloid beta-peptides/antagonists & inhibitors': 46,
#   'basal ganglia diseases/genetics': 1,
#   'rhode island': 1,
#   'nerve degeneration/prevention & control': 7,
#   'antibody specificity/immunology': 3,
#   'glycosylation end products, advanced': 1,
#   'malvaceae/toxicity': 1,
#   'imaging, three-dimensional/methods': 17,
#   'protein kinase c-alpha/metabolism': 3,
#   'giant cell arteritis/microbiology': 1,
#   'lipoproteins, hdl/metabolism': 1,
#   'protein processing, post-translational/genetics': 3,
#   'narration': 1,
#   'neurotoxicity syndromes/pathology': 1,
#   'memantine': 1,
#   'spices': 2,
#   'chromones/pharmacology': 1,
#   'substantia nigra/cytology': 1,
#   'transcription factors/blood': 1,
#   'endoplasmic reticulum/pathology': 2,
# ...
#   'mass spectrometry': 15,
#   'united kingdom': 17,
#   'hla-dr antigens/metabolism': 1,
#   'amyloid neuropathies/metabolism': 1,
#   'fluorescent dyes': 1,
#   'lung neoplasms/therapy': 1,
#   'nitric oxide/biosynthesis': 2,
#   'neurons/classification': 1,
#   'dopamine antagonists/therapeutic use': 1,
#   'neural pathways/metabolism': 1,
#   'subcellular fractions/enzymology': 1,
#   'psychomotor agitation/genetics': 1,
#   'amyloid/analysis': 3,
#   'plaque, amyloid/chemistry': 14,
#   'parkinson disease/mortality': 1,
#   'oncogene proteins/deficiency': 1,
#   'wine/analysis': 1,
#   'proto-oncogene proteins c-bcl-2/metabolism': 5,
#   'pregnanolone/physiology': 2,
#   'beverages': 4,
#   'receptors, cholinergic/metabolism': 3,
#   'libido': 1,
#   'dura mater/pathology': 1,
#   'capillaries/ultrastructure': 1,
#   'gene expression regulation, developmental/drug effects': 1,
#   'vitamin e/administration & dosage': 2,
#   'oxygen/chemistry': 1,
#   'epitopes/metabolism': 2,
#   'thiazoles/pharmacology': 2,
#   'chromatography, liquid/methods': 1,
#   'protein isoforms': 4,
#   'myeloid progenitor cells/immunology': 1,
#   'benzoxazoles/chemistry': 1,
#   'receptors, pituitary adenylate cyclase-activating polypeptide, type i/agonists': 1,
#   'putrescine/metabolism': 1,
#   'lewy bodies/genetics': 4,
#   'basal ganglia diseases/metabolism': 1,
#   'behavior, animal/drug effects': 6,
#   'nursing assessment': 12,
#   'cohort studies': 90,
#   'rehabilitation/methods': 1,
#   'home nursing/economics': 2,
#   'trinucleotide repeat expansion/genetics': 1,
#   'lewy body disease/etiology': 1,
#   'multiple sclerosis/physiopathology': 1,
#   'copper/blood': 5,
#   'acetylcholine/biosynthesis': 3,
#   'pirenzepine/pharmacokinetics': 2,
#   'protease inhibitors/adverse effects': 2,
#   'antigens, cd40/metabolism': 1,
#   'basal nucleus of meynert/surgery': 1,
#   'ubiquitin thiolesterase/metabolism': 5,
#   'apolipoproteins e/genetics': 167,
#   'multiple sclerosis/diet therapy': 1,
#   'research/history': 3,
#   'data collection/statistics & numerical data': 1,
#   'temporal lobe/diagnostic imaging': 4,
#   'caenorhabditis elegans proteins/genetics': 1,
#   'arthritis/diagnosis': 1,
#   'nitrates/metabolism': 4,
#   'animals, domestic': 1,
#   'leucine/genetics': 2,
#   'intracranial arteriosclerosis/physiopathology': 1,
#   'publishing': 7,
#   'microscopy, electron, scanning': 2,
#   'mental recall': 21,
#   'theology': 1,
#   'signal transduction/immunology': 2,
#   'isoflavones/therapeutic use': 1,
#   'cd4-positive t-lymphocytes/metabolism': 1,
#   'organic chemicals': 2,
#   'diagnosis': 2,
#   'threonine/metabolism': 7,
#   'lipids/pharmacology': 1,
#   'guanine/chemistry': 1,
#   'personality assessment/statistics & numerical data': 2,
#   'microscopy, electron': 16,
#   'medical records/statistics & numerical data': 1,
#   'aryldialkylphosphatase/genetics': 4,
#   'perceptual disorders/psychology': 3,
#   'cognition disorders/prevention & control': 15,
#   'adenine/metabolism': 1,
#   'ki-67 antigen/metabolism': 2,
#   'gene expression regulation, enzymologic/genetics': 3,
#   'peptide hydrolases/chemistry': 2,
#   'health promotion': 6,
#   'risk reduction behavior': 4,
#   'antigens, cd147/metabolism': 1,
#   'alleles': 82,
#   'dietary fats/administration & dosage': 2,
#   'immunoglobulin g/immunology': 1,
#   'bradycardia/chemically induced': 1,
#   'receptors, ldl/genetics': 8,
#   'amnesia/complications': 4,
#   'heparitin sulfate/physiology': 1,
#   'pharmacoepidemiology': 1,
#   'cephalometry': 1,
#   'blood physiological phenomena': 1,
#   'aquaporin 4/metabolism': 2,
#   'proteome/metabolism': 2,
#   'amyloid precursor protein secretases/drug effects': 5,
#   'receptors, cell surface/administration & dosage': 1,
#   'hydrostatic pressure': 1,
#   'oocytes/metabolism': 1,
#   'emotions/physiology': 6,
#   'protein-serine-threonine kinases/antagonists & inhibitors': 1,
#   'mice, mutant strains': 7,
#   'cerebrovascular circulation/drug effects': 10,
#   'huntington disease/pathology': 7,
#   'gyrus cinguli/physiology': 2,
#   'psychomotor agitation/epidemiology': 4,
#   'muscle rigidity/complications': 1,
#   'brain-derived neurotrophic factor/chemistry': 1,
#   'genomic instability': 1,
#   'dehydroepiandrosterone sulfate/pharmacology': 1,
#   'diabetes complications': 6,
#   'oligopeptides/therapeutic use': 2,
#   'skull fractures/pathology': 1,
#   'isoenzymes/physiology': 2,
#   'research support as topic/classification': 1,
#   'pyrrolidines/pharmacology': 1,
#   'golgi apparatus/metabolism': 5,
#   'memantine/adverse effects': 11,
#   'catechol o-methyltransferase/genetics': 4,
#   'microscopy, confocal/methods': 5,
#   'cyclin-dependent kinase inhibitor p27/genetics': 1,
#   'omeprazole/therapeutic use': 1,
#   'microglia/pathology': 10,
#   'galanin/pharmacology': 2,
#   'oscillometry': 1,
#   'piperidines/therapeutic use': 75,
#   'surface plasmon resonance/methods': 1,
#   'lactams/chemical synthesis': 1,
#   'antibodies, monoclonal/chemistry': 4,
#   'nitrates/pharmacology': 1,
#   'fibroblasts/enzymology': 3,
#   'disorders of excessive somnolence/prevention & control': 1,
#   'database management systems': 1,
#   'asthma/metabolism': 2,
#   'cognition disorders/diagnostic imaging': 9,
#   'iron/toxicity': 1,
#   "nurses' aides": 1,
#   'extracellular matrix/metabolism': 2,
#   'hla-dr antigens/analysis': 1,
#   'systems integration': 1,
#   'needs assessment': 1,
#   'depressive disorder, major/metabolism': 1,
#   'taurine/analogs & derivatives': 4,
#   'atrophy/genetics': 1,
#   'nerve growth factors/genetics': 3,
#   'solutions/chemistry': 1,
#   'coronary artery disease/metabolism': 1,
#   'fibrinolytic agents/therapeutic use': 1,
#   'affinity labels/pharmacology': 1,
#   'indomethacin/pharmacokinetics': 1,
#   'stereotypic movement disorder/drug therapy': 1,
#   'signal transduction/genetics': 5,
#   'stress, psychological/diagnosis': 4,
#   'dinoprostone/metabolism': 1,
#   'paraquat/toxicity': 1,
#   'transforming growth factor beta1': 3,
#   'heparin/analogs & derivatives': 1,
#   'fatty acids, monounsaturated/therapeutic use': 1,
#   's100 proteins/biosynthesis': 1,
#   "practice patterns, physicians'": 3,
#   'african continental ancestry group/statistics & numerical data': 3,
#   'phloroglucinol/pharmacology': 1,
#   'biopolymers': 2,
#   'oral hygiene': 1,
#   'insulin/blood': 1,
#   'antibodies, monoclonal/metabolism': 3,
#   'pregnancy': 10,
#   'amino acid transport systems/physiology': 1,
#   'anomia/complications': 2,
#   'hormone replacement therapy/trends': 1,
#   'allyl compounds/pharmacology': 1,
#   'anti-ulcer agents/therapeutic use': 1,
#   'antigens, cd/blood': 1,
#   'genes, dominant': 6,
#   'drug evaluation, preclinical/economics': 1,
#   'antihypertensive agents/therapeutic use': 11,
#   'atherosclerosis/metabolism': 6,
#   'age distribution': 12,
#   'skull': 1,
#   'hypercholesterolemia/drug therapy': 2,
#   'pre-eclampsia/physiopathology': 1,
#   'chromosomes, human, pair 8/genetics': 1,
#   'publication bias/statistics & numerical data': 1,
#   'recognition (psychology)/drug effects': 1,
#   'morpholines/pharmacology': 1,
#   'entorhinal cortex/chemistry': 1,
#   'magnetic resonance imaging': 116,
#   'virus diseases/therapy': 1,
#   'peptide fragments/antagonists & inhibitors': 21,
#   'schwann cells/metabolism': 1,
#   'nonverbal communication/psychology': 1,
#   'diabetes complications/psychology': 1,
#   'postoperative complications/etiology': 1,
#   'tumor necrosis factor-alpha/blood': 2,
#   'fluorodeoxyglucose f18/metabolism': 4,
#   'ischemia/pathology': 1,
#   'neurons/virology': 1,
#   'amino acids/administration & dosage': 1,
#   'palmitic acid/pharmacology': 1,
#   'tropanes/pharmacokinetics': 1,
#   'head': 1,
#   'glutathione reductase/metabolism': 2,
#   'electrophoresis, polyacrylamide gel': 10,
#   'cardiomyopathy, dilated/genetics': 1,
#   'cyclic amp/pharmacology': 1,
#   'cholinergic agonists/administration & dosage': 1,
#   'skin window technique': 1,
#   'riboflavin/therapeutic use': 1,
#   'hospice care/methods': 2,
#   'acetylglucosaminidase/metabolism': 1,
#   'receptors, nicotinic/biosynthesis': 1,
#   'dynamin i/metabolism': 2,
#   'computational biology': 5,
#   'receptor, serotonin, 5-ht1a/metabolism': 1,
#   'neuropil threads/pathology': 3,
#   'aspirin/chemistry': 1,
#   'dental plaque/complications': 1,
#   'italy/ethnology': 1,
#   'abdominal fat/physiology': 1,
#   'neurofibrillary tangles/enzymology': 6,
#   'receptors, muscarinic/metabolism': 4,
#   'proteins/administration & dosage': 1,
#   'peptidyl-dipeptidase a/cerebrospinal fluid': 1,
#   'nursing homes/economics': 1,
#   'nerve tissue proteins/blood': 1,
#   'cerebellar cortex/virology': 1,
#   'antiparkinson agents/adverse effects': 1,
#   'cathepsin b/metabolism': 2,
#   'quillaja saponins': 1,
#   'magnetoencephalography': 6,
#   'health surveys': 7,
#   'hydroxyl radical/metabolism': 1,
#   'intracellular membranes/immunology': 1,
#   'atherosclerosis/genetics': 2,
#   'cognition disorders/economics': 3,
#   'nursing assessment/methods': 3,
#   'coronary artery disease/drug therapy': 1,
#   'homocysteine/metabolism': 6,
#   'species specificity': 10,
#   'atherosclerosis/etiology': 4,
#   'drug resistance, viral': 1,
#   'environment design': 1,
#   'butyrylcholinesterase/chemistry': 2,
#   'parkinson disease/complications': 10,
#   'life change events': 5,
#   'ppar alpha/therapeutic use': 1,
#   'alkynes/pharmacology': 1,
#   'butyrylcholinesterase/physiology': 1,
#   'vitamins': 1,
#   'vesicular glutamate transport proteins/biosynthesis': 1,
#   'phosphodiesterase i/genetics': 1,
#   'concanavalin a/pharmacology': 1,
#   'electric stimulation': 1,
#   'research support as topic/trends': 1,
#   'receptors, adrenergic, alpha-1/genetics': 1,
#   'brain damage, chronic/epidemiology': 1,
#   'cholinesterase inhibitors/metabolism': 1,
#   'hospitals, university': 1,
#   'vitamin e deficiency/pathology': 1,
#   'tetralones/metabolism': 1,
#   'bacterial typing techniques': 1,
#   'protein kinase c/drug effects': 1,
#   'health services for the aged/organization & administration': 3,
#   'cytokines/metabolism': 9,
#   'histidine/metabolism': 1,
#   'rabies/immunology': 1,
#   'cytokines/immunology': 7,
#   'risk assessment/statistics & numerical data': 1,
#   'tau proteins/metabolism': 145,
#   'postoperative complications/pathology': 1,
#   'problem solving/physiology': 4,
#   'dinoprost/urine': 1,
#   'peptide fragments/toxicity': 21,
#   'mutation': 73,
#   'aniline compounds/therapeutic use': 1,
#   'amyloid beta-protein precursor': 1,
#   'muscle cells/metabolism': 1,
#   'amyloidosis/etiology': 3,
#   'pineal gland/physiopathology': 2,
#   'insulysin/chemistry': 1,
#   'chronic disease/drug therapy': 1,
#   'melatonin/physiology': 2,
#   'mitochondrial proteins/chemistry': 1,
#   'huntington disease/epidemiology': 4,
#   'spiro compounds/therapeutic use': 1,
#   'thapsigargin/pharmacology': 1,
#   'rna, small interfering/pharmacology': 1,
#   'art therapy': 1,
#   'research support as topic/history': 2,
#   'multiple sclerosis/epidemiology': 1,
#   'inflammation/metabolism': 8,
#   'factor analysis, statistical': 5,
#   'folic acid deficiency/physiopathology': 2,
#   'risperidone/adverse effects': 7,
#   'organometallic compounds': 1,
#   'biotin/chemistry': 1,
#   'phosphoserine/metabolism': 1,
#   'oligonucleotides, antisense/pharmacology': 1,
#   'cathepsin b/physiology': 1,
#   'vascular diseases/genetics': 1,
#   'thyrotropin-releasing hormone/metabolism': 1,
#   'hypoxia-ischemia, brain/complications': 1,
#   'familial mediterranean fever/genetics': 1,
#   'tissue extracts': 1,
#   'neurologic examination': 7,
#   'ophthalmic solutions': 3,
#   'leg/physiology': 1,
#   'supranuclear palsy, progressive/etiology': 1,
#   'enzyme inhibitors/pharmacology': 28,
#   'genetic vectors/administration & dosage': 1,
#   'receptors, g-protein-coupled/metabolism': 2,
#   'cholinesterase inhibitors': 2,
#   'oxidative stress/physiology': 53,
#   'animals, newborn': 19,
#   'astrocytes/chemistry': 2,
#   'interleukins/therapeutic use': 1,
#   'chlorpyrifos/analogs & derivatives': 1,
#   'cell adhesion molecules/genetics': 1,
#   'sesquiterpenes/pharmacokinetics': 2,
#   'boston': 2,
#   'thiazoles/metabolism': 3,
#   'retinoblastoma protein/analysis': 1,
#   'mental disorders/pathology': 2,
#   'clergy/statistics & numerical data': 1,
#   'transcriptional activation/genetics': 4,
#   'sleep initiation and maintenance disorders/etiology': 1,
#   'hydrazines': 2,
#   'proprioception': 1,
#   'dna, intergenic/genetics': 1,
#   'paroxetine/adverse effects': 1,
#   'dental care for disabled': 1,
#   'vacuoles/ultrastructure': 2,
#   'th2 cells/drug effects': 1,
#   'glutamates/toxicity': 1,
#   'zinc/adverse effects': 1,
#   'cyclooxygenase 1/drug effects': 1,
#   'dietary fats/therapeutic use': 1,
#   'dipeptides/chemistry': 1,
#   'autolysis/physiopathology': 1,
#   'optic nerve diseases/etiology': 3,
#   'steroid hydroxylases/metabolism': 1,
#   'interneurons/cytology': 1,
#   'aquaporin 1/immunology': 1,
#   'chlamydophila pneumoniae/pathogenicity': 1,
#   'tyrosine/analogs & derivatives': 6,
#   'immunologic factors/genetics': 1,
#   'membrane lipids/metabolism': 3,
#   'apolipoprotein a-i/analysis': 1,
#   'health services needs and demand/organization & administration': 1,
#   'feedback, physiological': 1,
#   'flurbiprofen/pharmacology': 2,
#   'phosphatidylcholines/blood': 1,
#   'diabetes mellitus, experimental/enzymology': 1,
#   'pastoral care/education': 1,
#   'prion proteins': 2,
#   'dopamine agonists/adverse effects': 1,
#   'cognition disorders/diagnosis': 188,
#   'flavonoids/administration & dosage': 1,
#   'psychotic disorders/classification': 1,
#   'zebrafish proteins/deficiency': 1,
#   'gliosis/physiopathology': 7,
#   'folic acid/administration & dosage': 2,
#   'mycelium/chemistry': 1,
#   'guanosine/analogs & derivatives': 2,
#   'ldl-receptor related proteins/genetics': 1,
#   'databases, nucleic acid': 1,
#   'learning/drug effects': 9,
#   'galactose': 2,
#   'depressive disorder/epidemiology': 10,
#   'endothelium, vascular/drug effects': 1,
#   'immunization, passive/methods': 4,
#   'activation analysis/methods': 1,
#   'cricetulus': 6,
#   'alzheimer disease/rehabilitation': 20,
#   'protein kinases/genetics': 4,
#   'fever/chemically induced': 1,
#   'empirical research': 1,
#   'electrophoresis, polyacrylamide gel/methods': 2,
#   'ppar gamma/agonists': 3,
#   'acetamides/therapeutic use': 1,
#   'retroviridae proteins, oncogenic/chemistry': 1,
#   'choline o-acetyltransferase/metabolism': 9,
#   'antidepressive agents/economics': 1,
#   'exocytosis/physiology': 1,
#   'agnosia/diagnosis': 4,
#   'insulysin/biosynthesis': 1,
#   'discrimination learning/physiology': 6,
#   'color': 1,
#   'proteomics/statistics & numerical data': 1,
#   'venous thrombosis/diagnostic imaging': 1,
#   'liver x receptors': 1,
#   'insulin-like growth factor i/physiology': 1,
#   'gtp cyclohydrolase/genetics': 1,
#   'cardiac pacing, artificial': 1,
#   'death-associated protein kinases': 1,
#   'cd-rom': 1,
#   'life expectancy': 1,
#   'home care services/economics': 1,
#   'affective symptoms/etiology': 1,
#   'heme oxygenase-1/genetics': 2,
#   'nf-kappa b/metabolism': 7,
#   'borrelia infections/diagnosis': 1,
#   'cognition disorders/history': 2,
#   'stem cell transplantation/ethics': 1,
#   'neurobiology/methods': 3,
#   'cognition/physiology': 61,
#   's100 proteins/analysis': 1,
#   'positron-emission tomography/methods': 21,
#   'chromatography, high pressure liquid/methods': 3,
#   'patient care management': 1,
#   'acids/pharmacology': 1,
#   'divorce': 1,
#   'endopeptidases/metabolism': 48,
#   'central nervous system/physiology': 6,
#   'adrenergic agonists/therapeutic use': 1,
#   'peptides/deficiency': 1,
#   'fetal alcohol spectrum disorders/etiology': 1,
#   'caprylates/therapeutic use': 2,
#   'neoplasms/prevention & control': 4,
#   'monoamine oxidase inhibitors/pharmacokinetics': 1,
#   'glutathione/drug effects': 1,
#   'hypothalamo-hypophyseal system/physiopathology': 2,
#   'antibody formation': 1,
#   'hypercapnia/complications': 1,
#   'memantine/pharmacokinetics': 2,
#   'olfactory bulb/physiology': 1,
#   'molecular chaperones': 1,
#   'silver staining/methods': 2,
#   'skilled nursing facilities': 1,
#   'chemokine cxcl10': 2,
#   'pyrimidines/adverse effects': 1,
#   'amyloid beta-protein precursor/adverse effects': 1,
#   'intraocular pressure/drug effects': 1,
#   'caenorhabditis elegans/genetics': 3,
#   'beta-adrenergic receptor kinases/genetics': 2,
#   'electrophoresis, agar gel': 1,
#   'frontal lobe/metabolism': 13,
#   'stroke/therapy': 1,
#   ...}}

# %%
# m_term = 'proteins'
# m_term = 'alcoholism genetics'
# m_term = 'alzheimer disease'
# m_term = 'Alcoholism/genetics'
# m_term = 'kcnq1'
# m_term = 'amyloid beta peptides'
# m_term = 'potassium channels'
# m_term = 'Alzheimer'
# m_term = 'Pharmacologic Substance'
m_term = 'n(6)-cyclohexyladenosine'

m_dict_uis = {m_term: []} # term : ui
m_dict_ui_by_name = {}    # ui : term
m_dict_term_by_ui = {}

# res = data.askTerm(m_term, pageSize=100000, searchType='approximate')
res = data_umls.askTerm(m_term, pageSize=100000, searchType='exact')
# res = data.askTerm(m_term, pageSize=100000, inputType='tty', searchType='exact')

for i in res:
    print(i)
    ui = i['ui']
    name = i['name']
    if ui not in m_dict_ui_by_name:
        m_dict_ui_by_name[ui] = []
    m_dict_ui_by_name[ui].append(name)

    m_dict_uis[m_term].append(ui)
    if ui not in m_dict_term_by_ui:
        m_dict_term_by_ui[ui] = []
    m_dict_term_by_ui[ui].append(m_term)

print('--> m_dict_uis')
print(m_dict_uis)
print()

print('--> m_dict_term_by_ui')
print(m_dict_term_by_ui)
print()

print('--> m_dict_ui_by_name')
print(m_dict_ui_by_name)
print()

m_cui = CUI()

m_dict_sem_types = {} # ui : [name1, name2, ...]
m_dict_uis_by_st = {} # sem_type : [ui1, ui2, ...]

for ui in m_dict_uis[m_term]:
    query_res = m_cui.CUIGeneral(ui)
    print('----> ui: {}'.format(ui))
    for sem_type in query_res['result']['semanticTypes']:
        st_name = sem_type['name']

        if st_name not in m_dict_uis_by_st:
            m_dict_uis_by_st[st_name] = []
        m_dict_uis_by_st[st_name].append(ui)

        if ui not in m_dict_sem_types:
            m_dict_sem_types[ui] = []
        m_dict_sem_types[ui].append(st_name)
        print(sem_type)

print()
print('-----> m_dict_sem_types')
print(m_dict_sem_types)

print()
print('-----> m_dict_uis_by_st')
print(m_dict_uis_by_st)
# Out:
# {'uri': 'https://uts-ws.nlm.nih.gov/rest/content/2016AB/CUI/C0067223', 'name': 'N(6)-cyclohexyladenosine', 'ui': 'C0067223', 'rootSource': 'MSH'}
# --> m_dict_uis
# {'n(6)-cyclohexyladenosine': ['C0067223']}
#
# --> m_dict_term_by_ui
# {'C0067223': ['n(6)-cyclohexyladenosine']}
#
# --> m_dict_ui_by_name
# {'C0067223': ['N(6)-cyclohexyladenosine']}
#
# ----> ui: C0067223
# {'name': 'Nucleic Acid, Nucleoside, or Nucleotide', 'uri': 'https://uts-ws.nlm.nih.gov/rest/semantic-network/2016AB/TUI/T114'}
#
# -----> m_dict_sem_types
# {'C0067223': ['Nucleic Acid, Nucleoside, or Nucleotide']}
#
# -----> m_dict_uis_by_st
# {'Nucleic Acid, Nucleoside, or Nucleotide': ['C0067223']}
